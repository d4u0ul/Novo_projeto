# %% [markdown]
# <a href="https://colab.research.google.com/github/d4u0ul/Novo_projeto/blob/master/Spacy_com_NER2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U spacy
# Out:
# Requirement already up-to-date: spacy in /usr/local/lib/python3.6/dist-packages (2.3.2)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.5)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (50.3.2)
# Requirement already satisfied, skipping upgrade: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.1)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.8.0)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (2.0.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.0)

# %% [markdown]
# Numero dos arquivos escolhidos randomicamente para mostrar a acurácia do modelo no teste final
#
#
# *import random*<br>
# *for x in range (130):* <br>
#   *print(random.randint(1,652))*<br>
#
# 198
# 295
# 382
# 608
# 187
# 80
# 127
# 62
# 506
# 529
# 59
# 315
# 628
# 35
# 274
# 222
# 452
# 58
# 613
# 629
# 324
# 73
# 345
# 42
# 113
# 616
# 180
# 61
# 446
# 416
# 651
# 165
# 172
# 614
# 82
# 70
# 95
# 348
# 288
# 347
# 455
# 605
# 137
# 208
# 114
# 431
# 39
# 91
# 534
# 28
# 120
# 43
# 122
# 332
# 108
# 538
# 405
# 309
# 305
# 521
# 450
# 286
# 87
# 357
# 518
# 605
# 3
# 325
# 364
# 250
# 113
# 639
# 429
# 70
# 488
# 514
# 456
# 209
# 38
# 595
# 49
# 157
# 126
# 335
# 522
# 324
# 102
# 53
# 97
# 333
# 534
# 589
# 219
# 65
# 475
# 173
# 179
# 264
# 625
# 378
# 494
# 127
# 629
# 645
# 345
# 341
# 567
# 147
# 338
# 317
# 637
# 310
# 157
# 396
# 565
# 400
# 246
# 407
# 577
# 378
# 528
# 640
# 325
# 217
# 581
# 538
# 159
# 550
# 191
# 14
#
# 4/5wFnEiljtx93u9C25s5VVRJhAFZ89xzhEBVeiIh8FIrDGGaYKUecSUk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Recuperando os arquivos restantes na pasta

# %%
from os import chdir, getcwd, listdir
path= r'/content/drive/My Drive/ner_itens_medicamentos/'
listaNum=[]
listaDeArqEnt=[]
listaDeArqText=[]
chdir(path)
print(getcwd()) #print caminho 

for c in listdir(): #listdir são os arquivos dentro da pasta  
 if "text" in str(c) and "entities" not in str(c):
   listaNum.append(int(c[4:c.index(".")])) #add numero dos textos 



for n in listaNum: #listdir são os arquivos dentro 
  listaDeArqText.append("text"+str(n)+".txt") #add numero dos textos 
  listaDeArqEnt.append("text"+str(n)+"_entities.txt")



print(len(listaNum))
# Out:
# /content/drive/My Drive/ner_itens_medicamentos
# 534

# %%
for x in range(5):
#for x in range(len(listaNum)):
  print("o texto de numero %s é o %s e suas entidades estão em %s" %(listaNum[x],listaDeArqText[x],listaDeArqEnt[x]))
# Out:
# o texto de numero 207 é o text207.txt e suas entidades estão em text207_entities.txt
# o texto de numero 390 é o text390.txt e suas entidades estão em text390_entities.txt
# o texto de numero 588 é o text588.txt e suas entidades estão em text588_entities.txt
# o texto de numero 45 é o text45.txt e suas entidades estão em text45_entities.txt
# o texto de numero 139 é o text139.txt e suas entidades estão em text139_entities.txt

# %% [markdown]
# **Versão**
# https://medium.com/@manivannan_data/how-to-train-ner-with-custom-training-data-using-spacy-188e0e508c6

# %%
def impListaRange(lista):
  for x in range(len(lista)):
    print(str(x) +"-->> " + str(lista[x]))

def preparaTexto(texto):
  a=texto
  a=a.replace("art.","art#").replace("pag.","pag#").replace("arts.","arts#").replace("num.","num#").replace("fls.","fls#")
  a=a.replace(" . ", " ").replace("<permisc>"," ").replace("<idnum>","").replace("< < rmisc> rmisc> ","").replace("rmisc"," ").replace(">"," ").replace("<","").replace(".<", "<").replace("Código Texto","")
  a=a.split(". ")
  for i in range(len(a)):
    a[i]=a[i].replace("art#","art.").replace("pag#","pag.").replace("arts#","arts.").replace("num#","num.").replace("fls#","fls.")
    while "  " in a[i]:
      a[i]=a[i].replace("  "," ")
  return a
  
def impListaRange2(lista,ranges):
  for x in range(len(lista)):
    if x>=ranges:
      break
    print(lista[x],end="")
    if x!=ranges-1:
      print(",")

def impListaRange(lista):
  ranges=len(lista)
  for x in range(len(lista)):
    if x>=ranges:
      break
    print(lista[x],end="")
    if x!=ranges-1:
      print(",")

# %%
textoEntComp=[]
textoEntPars=[]
nEntPars=[]
ltrain_data=[]
train_data=[]
print(listaDeArqEnt[0])
print(listaDeArqEnt[1])
print(listaDeArqEnt[2])
sentencas=[]

for t in range(len(listaNum)):
  if t>500:
   break
  textoTxt=str((open(path+listaDeArqText[t],"r").read()))
 #textoTxt.append(()
  textoEntComp=open(path+listaDeArqEnt[t],"r")
  for x in textoEntComp:
    y=x[:x.index("\n")]
    z=y.split(",")
    nEntPars.append((int(z[0]),int(z[1]),"Item"))
  train_data.append((textoTxt,{'entities':list(nEntPars)}))
  print("appending text[%s]"%(t))  
  nEntPars.clear()
  
print('train_data carregado')
# Out:
# text207_entities.txt
# text390_entities.txt
# text588_entities.txt
# appending text[0]
# appending text[1]
# appending text[2]
# appending text[3]
# appending text[4]
# appending text[5]
# appending text[6]
# appending text[7]
# appending text[8]
# appending text[9]
# appending text[10]
# appending text[11]
# appending text[12]
# appending text[13]
# appending text[14]
# appending text[15]
# appending text[16]
# appending text[17]
# appending text[18]
# appending text[19]
# appending text[20]
# appending text[21]
# appending text[22]
# appending text[23]
# appending text[24]
# appending text[25]
# appending text[26]
# appending text[27]
# appending text[28]
# appending text[29]
# appending text[30]
# appending text[31]
# appending text[32]
# appending text[33]
# appending text[34]
# appending text[35]
# appending text[36]
# appending text[37]
# appending text[38]
# appending text[39]
# appending text[40]
# appending text[41]
# appending text[42]
# appending text[43]
# appending text[44]
# appending text[45]
# appending text[46]
# appending text[47]
# appending text[48]
# appending text[49]
# appending text[50]
# appending text[51]
# appending text[52]
# appending text[53]
# appending text[54]
# appending text[55]
# appending text[56]
# appending text[57]
# appending text[58]
# appending text[59]
# appending text[60]
# appending text[61]
# appending text[62]
# appending text[63]
# appending text[64]
# appending text[65]
# appending text[66]
# appending text[67]
# appending text[68]
# appending text[69]
# appending text[70]
# appending text[71]
# appending text[72]
# appending text[73]
# appending text[74]
# appending text[75]
# appending text[76]
# appending text[77]
# appending text[78]
# appending text[79]
# appending text[80]
# appending text[81]
# appending text[82]
# appending text[83]
# appending text[84]
# appending text[85]
# appending text[86]
# appending text[87]
# appending text[88]
# appending text[89]
# appending text[90]
# appending text[91]
# appending text[92]
# appending text[93]
# appending text[94]
# appending text[95]
# appending text[96]
# appending text[97]
# appending text[98]
# appending text[99]
# appending text[100]
# appending text[101]
# appending text[102]
# appending text[103]
# appending text[104]
# appending text[105]
# appending text[106]
# appending text[107]
# appending text[108]
# appending text[109]
# appending text[110]
# appending text[111]
# appending text[112]
# appending text[113]
# appending text[114]
# appending text[115]
# appending text[116]
# appending text[117]
# appending text[118]
# appending text[119]
# appending text[120]
# appending text[121]
# appending text[122]
# appending text[123]
# appending text[124]
# appending text[125]
# appending text[126]
# appending text[127]
# appending text[128]
# appending text[129]
# appending text[130]
# appending text[131]
# appending text[132]
# appending text[133]
# appending text[134]
# appending text[135]
# appending text[136]
# appending text[137]
# appending text[138]
# appending text[139]
# appending text[140]
# appending text[141]
# appending text[142]
# appending text[143]
# appending text[144]
# appending text[145]
# appending text[146]
# appending text[147]
# appending text[148]
# appending text[149]
# appending text[150]
# appending text[151]
# appending text[152]
# appending text[153]
# appending text[154]
# appending text[155]
# appending text[156]
# appending text[157]
# appending text[158]
# appending text[159]
# appending text[160]
# appending text[161]
# appending text[162]
# appending text[163]
# appending text[164]
# appending text[165]
# appending text[166]
# appending text[167]
# appending text[168]
# appending text[169]
# appending text[170]
# appending text[171]
# appending text[172]
# appending text[173]
# appending text[174]
# appending text[175]
# appending text[176]
# appending text[177]
# appending text[178]
# appending text[179]
# appending text[180]
# appending text[181]
# appending text[182]
# appending text[183]
# appending text[184]
# appending text[185]
# appending text[186]
# appending text[187]
# appending text[188]
# appending text[189]
# appending text[190]
# appending text[191]
# appending text[192]
# appending text[193]
# appending text[194]
# appending text[195]
# appending text[196]
# appending text[197]
# appending text[198]
# appending text[199]
# appending text[200]
# appending text[201]
# appending text[202]
# appending text[203]
# appending text[204]
# appending text[205]
# appending text[206]
# appending text[207]
# appending text[208]
# appending text[209]
# appending text[210]
# appending text[211]
# appending text[212]
# appending text[213]
# appending text[214]
# appending text[215]
# appending text[216]
# appending text[217]
# appending text[218]
# appending text[219]
# appending text[220]
# appending text[221]
# appending text[222]
# appending text[223]
# appending text[224]
# appending text[225]
# appending text[226]
# appending text[227]
# appending text[228]
# appending text[229]
# appending text[230]
# appending text[231]
# appending text[232]
# appending text[233]
# appending text[234]
# appending text[235]
# appending text[236]
# appending text[237]
# appending text[238]
# appending text[239]
# appending text[240]
# appending text[241]
# appending text[242]
# appending text[243]
# appending text[244]
# appending text[245]
# appending text[246]
# appending text[247]
# appending text[248]
# appending text[249]
# appending text[250]
# appending text[251]
# appending text[252]
# appending text[253]
# appending text[254]
# appending text[255]
# appending text[256]
# appending text[257]
# appending text[258]
# appending text[259]
# appending text[260]
# appending text[261]
# appending text[262]
# appending text[263]
# appending text[264]
# appending text[265]
# appending text[266]
# appending text[267]
# appending text[268]
# appending text[269]
# appending text[270]
# appending text[271]
# appending text[272]
# appending text[273]
# appending text[274]
# appending text[275]
# appending text[276]
# appending text[277]
# appending text[278]
# appending text[279]
# appending text[280]
# appending text[281]
# appending text[282]
# appending text[283]
# appending text[284]
# appending text[285]
# appending text[286]
# appending text[287]
# appending text[288]
# appending text[289]
# appending text[290]
# appending text[291]
# appending text[292]
# appending text[293]
# appending text[294]
# appending text[295]
# appending text[296]
# appending text[297]
# appending text[298]
# appending text[299]
# appending text[300]
# appending text[301]
# appending text[302]
# appending text[303]
# appending text[304]
# appending text[305]
# appending text[306]
# appending text[307]
# appending text[308]
# appending text[309]
# appending text[310]
# appending text[311]
# appending text[312]
# appending text[313]
# appending text[314]
# appending text[315]
# appending text[316]
# appending text[317]
# appending text[318]
# appending text[319]
# appending text[320]
# appending text[321]
# appending text[322]
# appending text[323]
# appending text[324]
# appending text[325]
# appending text[326]
# appending text[327]
# appending text[328]
# appending text[329]
# appending text[330]
# appending text[331]
# appending text[332]
# appending text[333]
# appending text[334]
# appending text[335]
# appending text[336]
# appending text[337]
# appending text[338]
# appending text[339]
# appending text[340]
# appending text[341]
# appending text[342]
# appending text[343]
# appending text[344]
# appending text[345]
# appending text[346]
# appending text[347]
# appending text[348]
# appending text[349]
# appending text[350]
# appending text[351]
# appending text[352]
# appending text[353]
# appending text[354]
# appending text[355]
# appending text[356]
# appending text[357]
# appending text[358]
# appending text[359]
# appending text[360]
# appending text[361]
# appending text[362]
# appending text[363]
# appending text[364]
# appending text[365]
# appending text[366]
# appending text[367]
# appending text[368]
# appending text[369]
# appending text[370]
# appending text[371]
# appending text[372]
# appending text[373]
# appending text[374]
# appending text[375]
# appending text[376]
# appending text[377]
# appending text[378]
# appending text[379]
# appending text[380]
# appending text[381]
# appending text[382]
# appending text[383]
# appending text[384]
# appending text[385]
# appending text[386]
# appending text[387]
# appending text[388]
# appending text[389]
# appending text[390]
# appending text[391]
# appending text[392]
# appending text[393]
# appending text[394]
# appending text[395]
# appending text[396]
# appending text[397]
# appending text[398]
# appending text[399]
# appending text[400]
# appending text[401]
# appending text[402]
# appending text[403]
# appending text[404]
# appending text[405]
# appending text[406]
# appending text[407]
# appending text[408]
# appending text[409]
# appending text[410]
# appending text[411]
# appending text[412]
# appending text[413]
# appending text[414]
# appending text[415]
# appending text[416]
# appending text[417]
# appending text[418]
# appending text[419]
# appending text[420]
# appending text[421]
# appending text[422]
# appending text[423]
# appending text[424]
# appending text[425]
# appending text[426]
# appending text[427]
# appending text[428]
# appending text[429]
# appending text[430]
# appending text[431]
# appending text[432]
# appending text[433]
# appending text[434]
# appending text[435]
# appending text[436]
# appending text[437]
# appending text[438]
# appending text[439]
# appending text[440]
# appending text[441]
# appending text[442]
# appending text[443]
# appending text[444]
# appending text[445]
# appending text[446]
# appending text[447]
# appending text[448]
# appending text[449]
# appending text[450]
# appending text[451]
# appending text[452]
# appending text[453]
# appending text[454]
# appending text[455]
# appending text[456]
# appending text[457]
# appending text[458]
# appending text[459]
# appending text[460]
# appending text[461]
# appending text[462]
# appending text[463]
# appending text[464]
# appending text[465]
# appending text[466]
# appending text[467]
# appending text[468]
# appending text[469]
# appending text[470]
# appending text[471]
# appending text[472]
# appending text[473]
# appending text[474]
# appending text[475]
# appending text[476]
# appending text[477]
# appending text[478]
# appending text[479]
# appending text[480]
# appending text[481]
# appending text[482]
# appending text[483]
# appending text[484]
# appending text[485]
# appending text[486]
# appending text[487]
# appending text[488]
# appending text[489]
# appending text[490]
# appending text[491]
# appending text[492]
# appending text[493]
# appending text[494]
# appending text[495]
# appending text[496]
# appending text[497]
# appending text[498]
# appending text[499]
# appending text[500]
# train_data carregado

# %%
impListaRange2(train_data,10) #impressão padrão para entrada no spacy
# Out:
# ('processo <permisc> 1o grau: https://pje.tjpe.jus.br/1g/painel/painel_usuario/documentohtml.seam... intimacao do <permisc> para cumprir a decisao judicial, visto ser ele o responsavel na regiao pelo fornecimento de medicamentos a populacao. ademais, restou demonstrado nos autos que o ilustre magistrado, ato continuo, determinou a citacao do estado de sao paulo para os termos da acao, bem como do teor do despacho que deferiu aliminar, conforme se depreende da carta precatoria juntada as fls.52. nesse contexto, evidente que nao houve violacao ao principio do contraditorio e, por conseguinte, inexiste a nulidade aventada." (tjsp - <idnum> <permisc> / prestacao <permisc> publico; relator(a): <permisc> ; comarca: ilha solteira; orgao julgador: 12a camara de direito publico; data do julgamento: 24/06/ <idnum> ; data de registro: 06/08/ <idnum> ; outros numeros: <idnum> [1]) assinado eletronicamente por: <permisc> dias ribeiro de lavigne https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam id do documento: <idnum> <permisc> de <idnum> /12/ <idnum> 12:06 \x0cprocesso <permisc> 1o grau: <permisc> <permisc> https://pje.tjpe.jus.br/1g/painel/painel_usuario/documentohtml.seam... <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> dias r. de lavigne <permisc> oab\\pe: 897-b <permisc> <permisc> <permisc> <permisc> <permisc> r. da costa <permisc> - <permisc> / <permisc> ] <permisc> no 80/94 estatuto do defensor publico <permisc> e <permisc> prerrogativas <permisc> iii <permisc> garantias e das <permisc> art. 128. sao prerrogativas dos <permisc> membros da defensoria publica do estado, dentre outras que a lei estabelecer: i - receber intimacao <permisc> pessoal em qualquer processo e grau de jurisdicao, contando-se-lhe em dobro todos os prazos (...) <permisc> - <permisc> representar a parte, em feito administrativo ou judicial, independentemente de mandato, ressalvados os <permisc> casos para os quais a lei exija poderes especiais; <permisc> <permisc> <permisc> <permisc> [2]alexy, <permisc> . teoria dos direitos fundamentais. sao paulo: malheiros, <idnum> , p. 499. <permisc> <permisc> <permisc> <permisc> [3] <permisc> , <permisc> . direito constitucional e teoria da constituicao. coimbra: almedina, <idnum> , <permisc> p. <idnum> .op. cit, p. 478 <permisc> <permisc> [4] <permisc> , <permisc> . direito a saude. salvador: editora podvm, <idnum> , p. 35. <permisc> <permisc> [5]note-se que o pleito antecipatorio de tutela e tambem delineado no <permisc> e do <permisc> adolescente, em dispositivos de acentuada similitude ao <permisc> , sendo aplicaveis os <permisc> mesmos fundamentos acima expostos, a saber, a disciplina consta do art. 213 e sssss do eca. <permisc> <permisc> [6] <permisc> : <permisc> e obrigacao de fazer - <permisc> fornecimento de medicamentos - <permisc> da tutela antecipada - intimacao do diretor regional de <permisc> saude de aracatuba - alegacao de violacao ao principio do contraditorio - inocorrencia - tratando-se de <permisc> medida emergencial, que envolve a vida de um ser humano, justificavel a intimacao do diretor regional <permisc> para cumprir a decisao - <permisc> de citacao do estado de sao paulo efetivada em seguida e posterior <permisc> apresentacao de tempestiva contestacao - inocorrencia de prejuizo - <permisc> mantida - recurso <permisc> improvido." <permisc> <permisc> (...) <permisc> <permisc> cuidando-se de medida emergencial, que envolve a vida e a saude de um ser humano - in casu, uma <permisc> crianca de cinco anos de idade -, justificavel a ordem do <permisc> singular, que determinou a <permisc> <permisc> 10 de 11 <permisc> <permisc> 19/12/ <idnum> 12:06 <permisc> <permisc> \x0cprocesso <permisc> 1o grau: <permisc> <permisc> https://pje.tjpe.jus.br/1g/painel/painel_usuario/documentohtml.seam... <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> exmo(a) sr(a) juiz(a) de direito da vara da fazenda publica da <permisc> de petrolina - pernambuco <permisc> <permisc> ...
# ('assinado eletronicamente por: myrta < <permisc> rmisc> rodolfo de farias - 18/01/ <idnum> 13:47:17 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 1 < <permisc> rmisc> da comarca de olinda/ <permisc> - a quem couber < <permisc> rmisc> legal         < <permisc> rmisc> - < <permisc> rmisc> - saude       < <permisc> rmisc> das neves silva, brasileira, solteira, autonoma, portadora do rg no <idnum> sds/ <permisc> <permisc> no <idnum> , residente e domiciliada a rua do dendezeiro, no 117- a, <permisc> , olinda - <permisc> , cep: <idnum> , , declara que nao possui endereco eletronico, vem,telefone: (81) <idnum> respeitosamente, perante <permisc> , por meio da defensoria publica abaixo-assinada, com fulcronos arts. 5o, 196 e ss. da constituicao federal, art. 2o da <permisc> e demais disposicoes pertinentes aespecie, expor e propor a presente acao de obrigacao de <permisc> com <permisc> dido < <permisc> rmisc> em face do , cnpj <idnum> / <idnum> , situado na rua do sol, no 143,estado de <permisc> rnambucosanto antonio, recife - <permisc> , cep.: <idnum> , pelo que passa a expor e requerer o que segue:   i-da gratuidade da justica inicialmente, requer , nos termos doa <permisc> beneficios da <permisc> . 98 e 99 da do <permisc> , por nao poder arcar com as despesas processuais ehonorarios advocaticios sem prejuizo de sua subsistencia e de sua familia, conforme declaracao anexa. <permisc> assinado eletronicamente por: myrta <permisc> - 18/01/ <idnum> 13:47:17 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 3 <permisc> intervencao da defensoria publica do estado de pernambuco, pois sofre muito com a doenca e temesperanca que tal medicamento venha a diminuir toda a angustia e venha trazer alivio para seguir umavida digna.conforme atesta laudo medico acostado aos autos, a melhor opcao terapeutica para esse quadroclinico e a utilizacao da medicacao <permisc> 150mg de 12/12 horas, do qual se espera bons resultados,e continuando apos novo laudo.dessa forma, se quer e espera do estado de pernambuco uma resposta positiva para a concessaodo medicamento descrito acima e, sobretudo, em razao dos problemas apresentados pela autora e com acerteza da obrigacao do estado de pernambuco, nao restou alternativa a nao ser recorrer as viasjudiciais para requerer a concessao do presente pedido com pedido liminar, para fazer valer o seu direito.a presente acao judicial visa obter a total cobertura do medicamento necessario para tornar o tratamentomais resolutivo, sendo esta a concessao da medicacao <permisc> 150mg de 12/12 horas,do qual se esperabons resultados, e continuando apos novo laudo. sabendo que o estado nao possui o referido farmaco, verificando que o menor valor do farmaco,conforme orcamentos anexados, e de r$ <idnum> ,00 (dezesseis mil quinhentos e cinquenta reais), requero bloqueio das contas do estado e a consequente expedicao de alvara para a compra da medicacao orapleiteada. eis as razoes pelas quais busca a tutela jurisdicional do estado.  <permisc> esta e a sintese do problema, mm juizo e acreditamos que nada mais precisa ser dito. espera-se apenasque <permisc> lhe assegure o direito de continuar vivendo, deferindo a antecipacao de tutelapleiteada, nos moldes preconizados no artigo 294, do novo codigo de processo civil, art. 294 - a tutela provisoria pode fundamentar-se em urgencia ou evidencia.paragrafo unico.  a tutela provisoria de urgencia, cautelar ou antecipada, pode ser concedida em caraterantecedente ou incidental. esta mais do que claro - e expressamente declarado em receituario medico- que a demora no provimentojudicial acarretara a perda da qualidade d vida da parte autora.pensando nisso e que o autor recorre ao poder judiciario, pois ante o disposto nos diversos dispositivosconstitucionais que abaixo elenca, nao ha como se negar o pleito aqui apresentad ...
# ('assim, <permisc> <permisc> <permisc> a <permisc> <permisc> <permisc> parte <permisc> <permisc> <permisc> autora <permisc> <permisc> <permisc> pleiteia <permisc> <permisc> <permisc> medida <permisc> <permisc> <permisc> de <permisc> <permisc> <permisc> urgencia, <permisc> <permisc> <permisc> a <permisc> <permisc> <permisc> ser <permisc> <permisc> <permisc> concedida <permisc> <permisc> <permisc> liminarmente, <permisc> <permisc> <permisc> para <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> que <permisc> <permisc> <permisc> o <permisc> <permisc> <permisc> demandado <permisc> <permisc> <permisc> empreenda <permisc> <permisc> <permisc> todos <permisc> <permisc> <permisc> os <permisc> <permisc> <permisc> esforcos <permisc> <permisc> <permisc> e <permisc> <permisc> <permisc> promova <permisc> <permisc> <permisc> as <permisc> <permisc> <permisc> medidas <permisc> <permisc> <permisc> necessarias <permisc> <permisc> <permisc> para <permisc> <permisc> <permisc> a <permisc> <permisc> <permisc> realizacao <permisc> <permisc> <permisc> de <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> uma <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> ressonancia <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> magnetica <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> de <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> cranio <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> com <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> contraste <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> e <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> sedacao <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> conforme <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> prescricao <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> medica, <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> sem <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> demora, <permisc> <permisc> <permisc> para <permisc> <permisc> <permisc> que <permisc> <permisc> <permisc> tenha <permisc> <permisc> <permisc> tratamento <permisc> <permisc> <permisc> adequado. <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> 6. <permisc> <permisc> <permisc> dos <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> diante <permisc> <permisc> <permisc> de <permisc> <permisc> <permisc> todo <permisc> <permisc> <permisc> o <permisc> <permisc> <permisc> exposto, <permisc> <permisc> <permisc> requer <permisc> <permisc> <permisc> a <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> o <permisc> <permisc> <permisc> seguinte: <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> a) <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> a <permisc> <permisc> <permisc> concessao <permisc> <permisc> <permisc> da <permisc> <permisc> <permisc> gratuidade <permisc> <permisc> <permisc> da <permisc> <permisc> <permisc> justica, <permisc> <permisc> <permisc> na <permisc> <permisc> <permisc> forma <permisc> <permisc> <permisc> do <permisc> <permisc> <permisc> art. <permi ...
# ('assinado eletronicamente. a certificacao digital pertence a: fabiana maria freitas https://pje.tjpe.jus.br/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 6 <permisc> para a efetivacao da tutela especifica ou a obtencao de tutela pelo resultadopratico equivalente, determinar as medidas necessarias a satisfacao doexequente.(...)art. 537.  a multa independe de requerimento da parte e podera ser aplicada nafase de conhecimento, em tutela provisoria ou na sentenca, ou na fase deexecucao, desde que seja suficiente e compativel com a obrigacao e que sedetermine prazo razoavel para cumprimento do preceito.(...)  conforme explanacao supra, apos ser intensamente investigado,                    o autor foradiagnosticado com baixa estatura por ser pequeno para a idade gestacional ( <permisc> ), tendo como recomendacao medica para o restabelecimento da sua saude a utilizacao dosfarmacos <permisc> <idnum> mg somatropina 12 ui/2ml (ou somatropina 4ui/ml), por prazoeindeterminado. convem observar que a familia do menor nao possui condicoes financeiras para                   arcar com os custos das referidas medicacoes e, o retardamento do tratamento prescrito pelamedica que o acompanha fara com que o menor atinja a estatura final muito abaixo do padraopopulacional, frise-se, trazendo repercussoes psicossociais negativas significativas. da <permisc> bom direito  vislumbra-se no caso em deslinde todos os elementos viaveis a comprovar a                   verossimilhanca das alegacoes, pois se trata de direito liquido e certo, devendo a pretensao <permisc> ser julgada totalmente procedente em todos os seus termos, tendo em vista que estaamparada em fundado receio de dano irreparavel ou de dificil reparacao. busca o demandante a prestacao jurisdicional do estado no sentido de tutelar a                   sua propria saude, nao havendo que se falar em inexistencia da fumaca do bom direito. ademais, nao se demonstra qualquer duvida, nebulosidade ou a necessidade de                   producao de qualquer tipo de prova diversos dos ja produzidos nos presentes autos, dessemodo, presentes estao os elementos viaveis a concessao da liminar pleiteada pelo autor, bemcomo se tratar de provas aptas a permitir a procedencia final dos pedidos. <permisc> do periculum in mora                     excelencia, no caso em apreco verifica-se o perigo na demora da concessao daliminar ora requerida, pois trata-se de prova evidente da vulnerabilidade do autor, tendo emvista que e, frise-se, portador de baixa estatura por ser pequeno para a idadegestacional ( <permisc> ), cuja patologia coloca em risco seu desenvolvimento fisico epsicossocial. <permisc> 29/11/ <idnum> <permisc> <permisc> - <permisc> consulta processual numero: <idnum> <permisc> : procedimento comum orgao julgador: 4a vara da fazenda publica da capital ultima distribuicao : 19/11/ <idnum> <permisc> da causa: <permisc> <idnum> assuntos: obrigacao de <permisc> / nao <permisc> <permisc> de justica? nao <permisc> gratuita? sim pedido de liminar ou antecipacao de tutela? nao <permisc> advogado <permisc> autor advogado <permisc> partes nome fabiana maria <permisc> estado de pernambuco d. v. d. s. <permisc> <permisc> lucicleide maria ferreira documentos id. <idnum> data da assinatura documento 19/11/ <idnum> 18:37 <permisc> <permisc> assinado eletronicamente. a certificacao digital pertence a: fabiana maria freitas https://pje.tjpe.jus.br/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 5 <permisc> controle, devendo sua execucao ser feita diretamente ou atraves de terceiros e,tambem, por pessoa fisica ou juridica de direito privado.  os textos legais supramencionados nao deixam margem para duvidas de que a                   saude e direito de todos e e um dever juridico a ser prestado pelo estado.              excelencia, no caso em tela, evidente a necessidade do menor em ter seu ...
# ('<permisc> https://pje.jfpe.jus.br/pje/painel/painel_usuario/documentohtml.sea... <permisc> determinar o fornecimento de tratamento, cirurgia ou medicamentos a uma pessoa, ira criar um verdadeiro caos na administracao publica, uma vez que faltarao verbas para serem aplicadas nos programas previamente criados e aprovados. <permisc> <permisc> o stf tambem ja firmou entendimento no sentido de que as alegacoes de falta de recursos do <permisc> para aquisicao dos medicamentos nao podem se sobrepor a importancia dos direitos a saude e a vida. segundo o tribunal, a realizacao destes direitos fundamentais merece absoluta prioridade do estado, pois, <permisc> <permisc> "entre proteger a inviolabilidade do direito a vida, que se qualifica como direito subjetivo inalienavel assegurado pela propria constituicao da republica (art. 5o caput), ou fazer prevalecer, contra essa prerrogativa fundamental, um interesse financeiro e secundario do estado, entendo - uma vez configurado esse dilema, que razoes de ordem etico-juridica impoe ao julgador uma so e possivel opcao: o respeito indeclinavel a vida" (stf, <permisc> <idnum> /sc, rel. min. <permisc> ) <permisc> <permisc> <permisc> ademais, as verbas destinadas a saude e, com isto, ao fornecimento de medicamentos, existem. todavia, ha o contingenciamento destas por parte do ministerio da fazenda para reduzir o deficit publico, invertendo a razao da existencia do estado, que e servir ao cidadao. <permisc> <permisc> desta forma, em sendo premente a necessidade de medicamentos que atendam a saude e a necessidade da populacao, e, no caso em tela a saude da parte, tem por dever constitucional e legal o estado (uniao federal e estado de pernambuco) de disponibilizar o medicamento indispensavel referido alhures. <permisc> <permisc> <permisc> 4.3 do principio da reserva do possivel <permisc> <permisc> e argumentacao frequente, nas acoes similares a esta em comento, a impossibilidade do estado de arcar com o tratamento que nao estava previsto ante o principio da reserva do possivel, bem como que a judicializacao das demandas de saude tem levado a inviabilizacao da manutencao do proprio sus, que passaria a atender apenas aos cidadaos que ingressaram com acao judicial. <permisc> <permisc> contudo, nao se pode imputar ao cidadao os onus decorrentes do aglomerado processual que demanda o estado, especialmente porque este decorre especialmente da falta de investimento da <permisc> na area de saude, o que decorrente da visivel deficiencia da gestao. <permisc> 9 de 15 <permisc> 21/07/ <idnum> 08:04 <permisc> \x0c < <permisc> rmisc> https://pje.jfpe.jus.br/pje/painel/painel_usuario/documentohtml.sea... <permisc> <permisc> defensoria publica da uniao <permisc> <permisc> excelentissimo(a) senhor(a) < <permisc> rmisc> ) federal da ___ < <permisc> rmisc> subsecao judiciaria de < <permisc> rmisc> - <permisc> <permisc> <permisc> doenca grave <permisc> <permisc> marleide <permisc> , brasileira, casada, portadora do rg no <idnum> , <permisc> inscrita no cpf sob o no <idnum> , <permisc> no <idnum> , residente e <permisc> domiciliada no sitio curitiba, no 600, zona rural, petrolina- <permisc> , cep <idnum> , telefones (87) <permisc> <idnum> e (87) <idnum> , vem, a presenca de <permisc> , por intermedio da <permisc> , propor acao de saude com <permisc> dido <permisc> em face da uniao, com endereco a rua dr. geraldo estrela, <permisc> no 35, centro - petrolina- <permisc> , cep <idnum> , e do estado de <permisc> rnambuco, com <permisc> endereco a rua pacifico da luz, no 276, centro - petrolina- <permisc> , cep <idnum> , pelas razoes a <permisc> seguir expostas. <permisc> <permisc> <permisc> <permisc> <permisc> <permisc> 1. <permisc> fatos <permisc> <permisc> <permisc> <permisc> a autora, atualmente com 46 anos de idade, sofre de neoplasia de mama ( <permisc> <idnum> ). em <permisc> decorrencia da patologia que a acomete, necessita utilizar, por tempo indeterminado, o seguinte <permisc> medicamento: <permisc> (perjeta) <perm ...
# ('8/16 art. 6.o a educacao, , o trabalho, o lazer, a seguranca, a previdencia social, asao direitos sociaisa saudeprotecao a maternidade e a infancia, a assistencia aos desamparados, na forma desta constituicao.o direito a saude tambem encontra protecao em normas internacionais pactuadas pela <permisc> :    <permisc> internacional dos direitos economicos, sociais e culturais artigo 12. 1. os <permisc> partes no presente <permisc> reconhecem o direito de toda a pessoa de desfrutar o e mental.mais elevado nivel de saude fisica2. as medidas que os <permisc> partes no presente <permisc> deverao adotar, com o fim de assegurar o plenoexercicio desse direito, incluirao as medidas que se facam necessarias de assegurar:d) a criacao de condicoes que assegurem a todos, assistencia medica e servicos medicos em caso deenfermidade.  <permisc> ( <permisc> de san jose da costa rica).artigo 4o - direito a vida.1. . toda pessoa tem o direito de que se respeite sua vidaesse direito deve ser protegido pela lei e, . "em geral, desde o momento da <permisc> destacar que as normas acima transcritasnao podem ser interpretadas pelo operador do , sob pena de, conforme assentado pelodireito como uma promessa constitucional inconsequentesupremo tribunal federal :[5] o poder publico, fraudando justas expectativas nele depositadas pela coletividade, substituir, de maneirailegitima, o cumprimento de seu impostergavel dever, por um gesto irresponsavel de infidelidadegovernamental ao que determina a propria <permisc> .assim, deve a uniao propiciar todos os meios possiveis para o integral atendimento do direitofundamental a saude de todas as pessoas, utilizando-se da ou a de rede propriaoutros entes federativos, com repasse dos recursos do sus e, ainda, no caso de total impossibilidade de atendimento, na utilizacao da rede privada de saude. \x0c5/16 o fato de existir <permisc> ( <permisc> ) que disciplina a atuacao dos entes da federacao naexecucao das politicas publicas de saude nao afasta referida solidariedade, pois a <permisc> e aplicavel arelacao dos financiadores ou prestadores entre si, sem, contudo, reger a relacao dos financiadoresou prestadores com o cidadao usuario. pensamento diverso levaria a inconstitucionalidade da ditalei, pois a solidariedade no ambito da saude, ja se demonstrou, tem sede constitucional.  neste sentido, a jurisprudencia amplamente majoritaria do superior tribunal de justica e do trf da 5aregiao, conforme ilustram os julgados abaixo colacionados:constitucional. administrativo. medicamento. alto <permisc> . <permisc> . sentenca proferida por juiz impedido. anulacao. julgamento do feitopor esta corte, com <permisc> no <permisc> 4o, do art. 515, do <permisc> .aplicacao da teoria da <permisc> . direito a saude. responsabilidadesolidaria dos entes da federacao. ocorrencia. <permisc> , do estado do rio grande do norte e do municipio de guamare/rn.comprovacao da necessidade do medicamento. comprovacao.1. trata-se de remessa oficial e apelacao da uniao, em face da sentenca que, julgou procedente o pedidoformulado na inicial para que o estado do rio grande do norte, a uniao e o municipio de guamare/rnfornecam a autora, menor, enquanto durar o seu tratamento, o medicamento <permisc> 62,5 mg.2. o juiz que proferiu a sentenca participou do julgamento do <permisc> , julgado por <permisc> na <permisc> , o que ensejaria, a principio, a aplicacao do art. 134, <permisc> , do <permisc> . a despeito disto, nao se pode olvidar a celeridade, como valor constitucionalmente garantido. paratanto, o ordenamento juridico implementou normas legais que possibilitam a efetivacao deste valor.sendo assim, a despeito do reconhecimento de julgamento por juiz impedido, afasta-se a necessidade deretorno dos autos ao juizo de origem, por aplicacao, ao caso, o disposto no art. 515, paragrafo 4o, do <permisc> ,que cuida da teoria da causa madura. precedente: <permisc> <idnum> /es, <permisc> . <permisc> , <permisc> , julgado em 17/11/ <idnum> , <permisc> 02/12/ <idnu ...
# ('< <permisc> rmisc> assinado eletronicamente por: joao < <permisc> rmisc> de araujo - 08/02/ <idnum> 08:49:45 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> < <permisc> rmisc> num. <idnum> - pag. 1 < <permisc> rmisc>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ministeriopublicodoestadode <permisc> rnambuco3apr                                                                                                                                                                                promotoriadejusticaciveledacidadaniadacomarcadevitoriadesantoantaocuradoriadoidoso, < <permisc> rmisc> , < <permisc> rmisc> , < <permisc> rmisc> , < <permisc> rmisc> <permisc>       oministeriopublicodoestadodepernambuco,porseurepresentanteinfra-assinado,curador do deficiente fisico,comfulcronoartigo129,incisoiii,daconstituicaodarepublicafederativadobrasil,enodispostona < <permisc> rmisc> no <idnum> - < <permisc> rmisc> organicanacionaldoministeriopublico,ena < <permisc> rmisc> complementarno12,atualizadapela < <permisc> rmisc> < <permisc> rmisc> , e < <permisc> rmisc> c/c oart. 11 da < <permisc> rmisc> , < <permisc> rmisc> ndeg <idnum> /90 e ainda c/c arts. 18 e 19, ambos do < <permisc> rmisc> no <idnum> de 20 de dezembro de <idnum> e, por fim tudo c/c arts. 18/26 e art. 79, ss 3o, ambos da < <permisc> rmisc> no <idnum> / <idnum> (estatuto da pessoa com < <permisc> rmisc> cidadaodeficiente fisico, com paralisia cerebral distonica, tetraplegico,o senhordaniel < <permisc> rmisc> ,brasileiro, solteiro,naturaldevitoria de santo antao- <permisc> ,nascidoem <idnum> , com 25 anos de idade, < <permisc> rmisc> no <idnum> -sds/ <permisc> , cpf no <idnum> ,filhodeseverino <permisc> santos junior e <permisc> ,residentenarua papa paulo vi, no 24 - ao lado da escola arco-iris - bairro sao vicente de paulo - cep: <idnum> - vitoria de santo antao/ <permisc> ,vemproporacaocivilpublica,compedidodeantecipacaodatutela,"inauditaalterapars",emfacedoestadode <permisc> rnambuco,pessoajuridicadedireitopublicointerno,quedeverasercitadonapessoadeseugovernador, <permisc> .paulohenriquesaraivacamara,no"palaciodocampodasprincesas",comenderecoapracadarepublica, <permisc> , recife- <permisc> ,\x0cassinado eletronicamente por: joao <permisc> de araujo - 08/02/ <idnum> 08:49:45 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 7 <permisc> fundamental,uminteressefinanceiroesecundariodoestado,entendo-umavezconfiguradoessedilema-querazoesdeordemetico-juridicaimpoemaojulgadorumasoepossivelopcao:aquelaqueprivilegiaorespeitoindeclinavelavidaeasaudehumanas.(...)". (stf, <permisc> .min. <permisc> , <permisc> ) ocasosobanaliseconsubstanciasituacaoemergencial,enquadravelnoartigo24,incisoiv,dalei <idnum> /93,comocausadedispensadelicitacao. 3.dopedidodetutelaantecipada. notocanteaantecipacaodetutela,encontram-sepresentesosrequisitosindispensaveisasuaconcessao,quaissejam,ofumusbonisiuriseopericuluminmora.convemressaltar,desdelogo,que,emacaocivilpublica,oditoinstrumentoprocessualrege-sepeladiccaodoart.461,ss3odocodigodeprocessocivil,normaaplicavelasacoesquetenhamporobjetoocumprimentodeobrigacaodefazerounaofazer,inverbis:  "art.461.naacaoquetenhaporobjetoocumprimentodeobrigacaodefazerounaofazer,ojuizconcederaatutelaespecificadaobrigacaoou,seprocedenteopedido,determinaraprovidenciasqueasseguremoresultadopraticoequivalenteaodoadimplemento.(...) ss3o.sendorelevanteofundamentodademandaehavend ...
# ('assinado eletronicamente por: <permisc> - 19/02/ <idnum> 08:15:32 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 11 <permisc> assinado eletronicamente por: <permisc> - 19/02/ <idnum> 08:15:32 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6  os honorarios advocaticios devem ser arbitrados, consoante a regra do ss4o do art. 20 do <permisc> , devendoter como parametros o grau de zelo do profissional, o lugar da prestacao do servico, a natureza eimportancia da causa, o trabalho realizado e o tempo exigido para sua realizacao. ( <permisc> - <permisc> / <permisc> -0/001, relator(a): des.(a) <permisc> , 2acamara civel, julgamento em 09/10/ <idnum> , publicacao da sumula em 17/10/ <idnum> ). ( <permisc> ). apelacao civel e reexame necessario. direito publico nao especificado.saude <permisc> . <permisc> - prelixafor ( <permisc> <permisc> ).parte autora <permisc> de <permisc> (cid-10 c <idnum> ). responsabilidadedo estado pelo encaminhamento da paciente ao cacon. tratamentooncologico. recomendacao medica. suficiencia. 1. descabe o reexame necessario,porquanto a sentenca que determinou o fornecimento de medicamentos esta fundada em decisao doplenario do stf. 2. incumbe ao municipio, aos estados e a uniao, solidariamente, fornecer tratamentomedico aos cidadaos, o que inclui os medicamentos necessarios para tratar suas enfermidades. 3. a saude e direito de todos e dever doestado, garantidopelo art. 196 da cf. por tal razao, questoes deordem principiologica e/ou orcamentaria nao podem se sobrepor as disposicoes constitucionais. ainda que <permisc> tenha rubrica orcamentaria especifica para o tratamento, e dever dosentes publicos fornece-lo, bastando, para a constatacao de sua necessidade, o atestado emitido pelo. 4. ainda que o tratamento deva ser fornecidomedico que acompanha o tratamento da parte autorapela uniao, atraves de um dos cacons, e dever dos entes publicos providenciar o devidoencaminhamento da parte autora ao cacon ou unacon, para que receba a droga indicada,garantindo-lhe as condicoes de saude e sobrevivencia dignas, com amparo nos artigos 196 e 197 daconstituicao federal, porquanto demonstrada a necessidade dos medicamentos para o cancer queacomete a autora, bem como sua carencia financeira para adquiri-los. apelo desprovido.reexame necessario. nao conhecido. (apelacao e reexame necessario no <idnum> ,segunda camara civel, tribunal de justica do rs, relator: <permisc> , <permisc> ). (realces acrescidos).     <permisc> , diante dos fatos acima narrados no laudo  psiquiatrico   acostado, verifica-se que a <permisc> ser submetido com urgencia ao tratamento com os medicamentos   ritalina - lamitor, nas dosagens e quantidades descritas no laudo e receituarios medicos, inclusos ae depakotepresente demanda judicial,  por mes, por  periodo  indeterminado,  de modo continuo,   para  controle dopeso, decorrente dos efeitos   das doencas   epilepsia focal idiopatica e transtorno,  impondo-se, assim, o reconhecimento judicial da obrigacao do reu emde deficit de <permisc> -lhe gratuitamente os  remedios  pleiteados.  <permisc> tutela de urgenciadessa maneira, caso estes medicamentos,   nao seja fornecidos em curto prazo, a   paciente pode vir a enlouquecer rapidamente  e se escapar ter sequelas em definitivas, ficando  com  marcas profundas, quetrara para o resto da vida  com gravissimo  transtorno de comportamento, mesmo antes de atingir amaioridade civil, com certeza,  abaixo da alta estima para o padrao populacional, trazendo repercussoespsicossociais negativas e significativas. <permisc> assinado eletronicamente por: <permisc> - 19/02/ <idnum> 08:15:32 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 8 (...)" dessa forma, verificado que a pretensao autoral encontra amplo respaldo no  ...
# ('assinado eletronicamente por: elo <permisc> sa <perm <permisc> sc> rodr <permisc> gues - 06/09/ <idnum> 11:43:25 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 7  esta mais do que claro <perm <permisc> sc> e expressamente declarado em receituario medico - que a parterequerente necessita de ressonancia magnetica de cranio com contraste e sedacao.  <perm <permisc> sc> nisso e que a parte autora recorre ao <perm <permisc> sc> , pois ante o previsto nosdiversos dispositivos constitucionais que abaixo elenca, nao ha como se negar o pleito aqui apresentado. vejamos o que dispoe a nossa <perm <permisc> sc> :  <perm <permisc> sc> . 1o - a republica federativa do brasil, formada pela uniao indissoluvel dosestados e municipios e do distrito federal, constitui-se em estado democraticode direito e tem como fundamentos:[...] <permisc> <permisc> <permisc> - a dignidade da pessoa humana; <perm <permisc> sc> . 3o - constituem objetivos fundamentais da republica federativa do brasil:[...] <permisc> v - promover o bem de todos, sem preconceitos de origem, raca, sexo, cor, idadee quaisquer outras formas de discriminacao.  <perm <permisc> sc> . 5o - <perm <permisc> sc> sao iguais perante a lei, sem distincao de qualquer natureza,garantindo-se aos brasileiros e aos estrangeiros residentes no pais ainviolabilidade do direito a vida, a liberdade, a igualdade, a seguranca e apropriedade, nos termos seguintes: <permisc> - homens e mulheres sao iguais em direitos e obrigacoes, nos termos desta <permisc> ;[...]xxxv - a lei nao excluira da apreciacao do <perm <permisc> sc> lesao ou ameaca adireito;xxxv <permisc> - a lei nao prejudicara o direito adquirido, o ato juridico perfeito e a coisa julgada;[...]ss 1o - as normas definidoras dos direitos e garantias fundamentais tem aplicacaoimediata.  <perm <permisc> sc> . 6.o sao direitos sociais a educacao, a saude, o trabalho, a moradia, o lazer, aseguranca, a previdencia social, a protecao a maternidade e a infancia, aassistencia aos desamparados, na forma desta <permisc> . <permisc> assinado eletronicamente por: eloisa <permisc> rodrigues - 06/09/ <idnum> 11:43:25 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 14 <permisc> invocada, pelo estado, com a finalidade de exonerar-se do cumprimento de suasobrigacoes constitucionais, notadamente quando, dessa conduta governamentalnegativa, puder resultar nulificacao ou, ate mesmo, aniquilacao de direitosconstitucionais impregnados de um sentido de essencial fundamentalidade"(ministro <permisc> de <permisc> /stf no 345/ <idnum> )". as limitacoes oudificuldades orcamentarias nao se prestam, por si so, como pretexto para negar odireito a saude e a vida garantidos no artigo 196 da constituicao cidada. 3-apelo e <permisc> e <permisc> . (tjce -ap-rn <idnum> - <permisc> . <permisc> - <permisc> <idnum> - p. 25)  <permisc> - acao ordinaria com pedido deantecipacao <permisc> - recusa no <permisc> de tratamentomedico pelo ente publico - dever de ordem constitucional -descumprimento - <permisc> indisponiveis que <permisc> - <permisc> . 6o e 196 da cf/88 -remessa obrigatoria conhecida <permisc> - sentencamantida - precedentes desta corte - <permisc> o reexame necessario e cabivelquando concedida a ordem em desfavor da fazenda publica. i <permisc> os apelantesrecorreram ao <permisc> , por meio de acao de obrigacao de fazer compedido de <permisc> , requerendo o custeio, por parte do instituto deprevidencia do municipio de fortaleza - ipm, de todo o tratamento medicosolicitado por profissional credenciado na referida autarquia. ii <permisc> acerca dotema, preconizam os arts. 6o e 196 da lex fundamentalis que e dever do <permisc> o direito a saude "mediante politicas sociais e economicas que visem areducao do risco de doenca e de outros agravos e ao acesso universal eigualitario as acoes e servicos para  ...
# ('assinado eletronicamente por: maciel da silva fonseca - 20/06/ <idnum> 17:01:32 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6 <permisc> . administrativo. <permisc> de <permisc> , <permisc> . <permisc> a portador de doenca grave.tratamento adequado. promocao, <permisc> e recuperacao da saude. deverdo <permisc> . o municipio do recife - pe, juntamente com uniao e o estado de pernambuco, tem legitimidade adcausam para figurar no polo passivo de acao ordinaria em que a autora, ora agravado, representado peladefensoria <permisc> e beneficiario da assistencia judiciaria gratuita, portador de mal grave, nocaso a doenca de <permisc> , necessita fazer uso do medicamento <permisc> (adcetris).2. "o funcionamento do <permisc> (sus) e de responsabilidade solidaria da uniao,estados-membros e municipios, de modo que qualquer dessas entidades tem legitimidade adcausam para figurar no polo passivo de demanda que objetiva a garantia do acesso a medicacao." (stj - <permisc> no <idnum> /rj, <permisc> , rel.para pessoas desprovidas de recursos <permisc> . <permisc> , dj de 03/10/ <idnum> , <permisc> . e de se ressaltar que o direito a saude, assim como a educacao, ao trabalho, a moradia, ao lazer, aseguranca, a previdencia social, a protecao a maternidade e a infancia e a assistencia aos desamparadosesta posicionado no rol dos direitos sociais (art. 6o da cf) e pode ser encontrado em varios outrosdispositivos constitucionais.4. <permisc> rejeitada. <permisc> de instrumento improvido.(processo: <idnum> , <permisc> , <permisc> , <permisc> , julgamento: 04/10/ <idnum> , <permisc> : dje 11/10/ <idnum> -pagina 184)                     <permisc> . possibilidade de <permisc> de verbaspublicas para garantia. ratificacao da jurisprudencia firmada por estasuprema <permisc> . existencia de <permisc> , relator(a): min. <permisc> , julgado em 13/08/ <idnum> , <permisc> - <idnum> public <idnum> ement vol- <idnum> <permisc> lexstf v. 32, n. 381, <idnum> , p. <idnum> )                            <permisc> destacar, ainda, que o egregio tribunal de justica de pernambuco, apos reiterados julgamentosnesse sentido, pacificou entendimento a respeito da responsabilidade estatal na assistencia a saude dapopulacao carente, editando a sumula 018, cuja transcricao torna-se extremamente oportuna:  <permisc> 018. e <permisc> -membro <permisc> , <permisc> para este, medicamento essencial <permisc> <permisc> , <permisc> que nao <permisc> em <permisc> . sendo assim, nao resta duvida de que a assistencia a saude e dever do estado, devendo sua execucao se dade forma universal e integral, abrangendo os tratamentos terapeuticos e farmaceuticos, em todos os seusniveis de complexidade. <permisc> assinado eletronicamente por: maciel da silva fonseca - 20/06/ <idnum> 17:01:32 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 5 <permisc> do estado de pernambuco nucleo regional em sao jose do egito centro de cultura professor bernardo juca - rua joao pessoa, s/no, centro, sao jose do egito/pe. cep <idnum> dever de prestacao da saude, aqui incluidos o fornecimento de medicamentos e a realizacao de cirurgias/procedimentos medicos. sendo solidaria a responsabilidade dos entes publicos pela prestacao do servico de saude, podera a parte constante do polo ativo dessa relacao juridica de saude acionar qualquer um deles (ou todos) para cumprimento da obrigacao, sendo desnecessario o acionamento de todos: <permisc> extraordinario com <permisc> (lei no <idnum> / <idnum> ) - <permisc> de declaracao recebi <permisc> como <permisc> de <permisc> - responsabilidade solidaria das pessoas politicas que integram o estado federal brasileiro, no contexto do <permisc> (sus) - competencia comum <permisc> entes federa <permisc> (uniao, esta <permisc> - <permisc> , distrito federal e municipios) em <permisc> de <permisc> e assistencia a saude ...

# %%
#Descobrindo o nome dos Itens
nomeDosMedicamentos=[]
cont=0
for i in range(len(train_data)):
  print("##################################################################################################################################################")
  print("Analisando o texto de numero %s que é o %s e que suas entidades estão em %s, temos" %(str(cont+1),listaDeArqText[i],listaDeArqEnt[i]))
  print("%s: %s"%(listaDeArqText[i],str(train_data[i][0])))
  listaEntidades=list((train_data[i][1].get("entities")))
  print("Lista de entidades do texto %s de %i caracteres são %s"%(listaDeArqText[i],len(str(train_data[i][0])),listaEntidades))
  listaMed=list([])
  for j in range(len(listaEntidades)):
    print()
    print("A palavra procurada em %s que "%(str(listaEntidades[j])),end=" ")
    print("deve estar entre %i" %(listaEntidades[j][0]),end=" ")
    print(listaEntidades[j][1],end=" é a palavra ")
    print(train_data[i][0][listaEntidades[j][0]:listaEntidades[j][1]])
    listaMed.append(train_data[i][0][listaEntidades[j][0]:listaEntidades[j][1]])
            #train_data.append((textoTxt,{'entities':list(nEntPars)}))
    print()
    for k in range(len(listaMed)):
      if k==0:continue
      if listaMed[k]==listaMed[k-1]:
        del listaMed[k-1]
  nomeDosMedicamentos.append((listaDeArqText[i],{'Medicamentos':list(listaMed)}))
   # for k in 
    
   # print(j,end=" -> ")
    #print(train_data[i][0][j[0][0listaEntidades[j][1]]])
  #   sentecas.append([list(preparaTexto(i[0][0]))][j])
  cont+=1


print("")
a=train_data[0][1]
b=train_data[1][1]
c=train_data[2][1]
d=train_data[3][1]
e=train_data[4][1]
f=train_data[5][1]

#print(a[8071:8082])
#print(len(a))
print(a)
print(train_data[1][1].get("entities"))
print(c['entities'])
print(d['entities'][0][0])
print(e['entities'])
print(f['entities'])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  é a palavra somatropina
#
#
# A palavra procurada em (26688, 26699, 'Item') que  deve estar entre 26688 26699 é a palavra somatropina
#
# ##################################################################################################################################################
# Analisando o texto de numero 81 que é o text599.txt e que suas entidades estão em text599_entities.txt, temos
# text599.txt: 8/11 dr. mario manoel de amorim dr. jose neto de <perm <permisc> sc> pagina 8 de 11 avenida josemar batista da silva, no <perm <permisc> sc> , cep: <idnum> , centro, petrolina - pe. www.amorimadv.adv.br / e-mail: contato@amorimadv.adv.br tel.: 87 <idnum> / <idnum> descab <permisc> da. reje <permisc> cao <perm <permisc> sc> embargos.- trata-se de embargos de declaracao interpostos em face de acordao exarado nos autos do mandado de seguranca no <idnum> (fls. 116/116-v), de lavra desta <perm <permisc> sc> . o <perm <permisc> sc> fundamenta seu recurso no art. <idnum> , <permisc> e <permisc> <permisc> do <permisc> . <permisc> ndica como objetivo recursal fins de prequestionamento e suprimento de omissoes.- o acordao embargado se encontra fulcrado no pacificado e sumulado entendimento deste tribunal de justica no sentido de que, comprovada a necessidade do tratamento e a falta de condicoes de adquiri-lo, legitimado esta o direito do cidadao prejudicado em buscar a tutela jurisdicional, impondo-se ao estado a obrigacao de disponibilizar os meios necessarios ao custeio do medicamento/tratamento adequado ao <permisc> , o fato de o tratamento em questao nao ser disponibilizado pelo sus e insuficiente para afastar a responsabilidade dos entes federativos quanto ao seu fornecimento, tendo em vista que, no caso concreto, o laudo medico atesta a sua necessidade. portanto, as eventuais determinacoes por parte do <permisc> que visam a assegurar o direito a saude nao possuem o condao de malferir os principios da separacao dos poderes, legalidade, e da eficiencia, nem implicam a quebra das normas de direito administrativo e financeiro, vez que o implemento dessas medidas se destina tao somente a garantir um minimo existencial.- no que diz respeito a compatibilidade da multa diaria com a obrigacao imposta, esta <permisc> manifestou-se explicitamente, nos seguintes termos: "quanto a aplicacao da multa diaria, entendo que o seu objetivo e fazer com que a parte impetrada cumpra a obrigacao que lhe foi imposta. ou seja, a multa nao e um fim em si mesmo, senao um instrumento destinado a compelir o seu destinatario ao cumprimento forcado da obrigacao que lhe foi imposta. assim, a quantia fixada nao pode ser irrisoria a ponto de parecer mais vantajoso paga-la do que cumprir a obrigacao. nesta senda, tenho que o valor fixado, no montante de r$ <idnum> ,00 (mil reais) por dia de atraso, esta condizente com a finalidade da multa, bem como com o interesse em questao, qual seja, a saude e vida do <permisc> mpetrante; tampouco se mostra exiguo o prazo de 10 (dez) dias para seu cumprimento" (fls.116-v).- por fim, no que tange aos dispositivos apontados pelo <perm <permisc> sc> (arts. 2deg, 5o, 37, caput e 196, todos da <permisc> ; e art. 537, 2a parte, do <permisc> ), e em relacao aos quais se deseja o prequestionamento da materia, nao entrevejo omissao, obscuridade ou contradicao apta a embasar os presentes aclaratorios. de fato, o simples interesse em prequestionar nao conduz a que se dispense a demonstracao de existencia de qualquer das causas que ensejam os embargos de declaracao, inteligencia do disposto no art. <idnum> do <permisc> . - <permisc> , a <permisc> rejeitou os <permisc> , nos termos do voto do <permisc> . ( <permisc> . embargos de declaracao nos embargos de declaracao <idnum> ( <idnum> ); orgao julgador: <permisc> de direito publico; <permisc> : des. <permisc> ; julgado em: 29/11/ <idnum> ; djpe: 21/12/ <idnum> ) 6/11 dr. mario manoel de amorim dr. jose neto de <permisc> pagina 6 de 11 avenida josemar batista da silva, no <permisc> , cep: <idnum> , centro, petrolina - pe. www.amorimadv.adv.br / e-mail: contato@amorimadv.adv.br tel.: 87 <idnum> / <idnum> <permisc> ( <permisc> <idnum> -rn, des. <permisc> , julgado em 27 de novembro de <idnum> ). <permisc> <permisc> no <permisc> extraordinario com <permisc> . constitucional. direito <permisc> . <permisc> medicamento e <permisc> . <permisc> do estado. <permisc> solidaria <permisc> e ...
# Lista de entidades do texto text599.txt de 29534 caracteres são [(5105, 5119, 'Item'), (5740, 5754, 'Item'), (12777, 12791, 'Item'), (20338, 20352, 'Item'), (23337, 23351, 'Item'), (23578, 23592, 'Item'), (23652, 23666, 'Item'), (23807, 23821, 'Item'), (24018, 24032, 'Item'), (26568, 26582, 'Item'), (27046, 27060, 'Item'), (28722, 28736, 'Item')]
#
# A palavra procurada em (5105, 5119, 'Item') que  deve estar entre 5105 5119 é a palavra prostatectomia
#
#
# A palavra procurada em (5740, 5754, 'Item') que  deve estar entre 5740 5754 é a palavra prostatectomia
#
#
# A palavra procurada em (12777, 12791, 'Item') que  deve estar entre 12777 12791 é a palavra prostatectomia
#
#
# A palavra procurada em (20338, 20352, 'Item') que  deve estar entre 20338 20352 é a palavra prostatectomia
#
#
# A palavra procurada em (23337, 23351, 'Item') que  deve estar entre 23337 23351 é a palavra prostatectomia
#
#
# A palavra procurada em (23578, 23592, 'Item') que  deve estar entre 23578 23592 é a palavra prostatectomia
#
#
# A palavra procurada em (23652, 23666, 'Item') que  deve estar entre 23652 23666 é a palavra prostatectomia
#
#
# A palavra procurada em (23807, 23821, 'Item') que  deve estar entre 23807 23821 é a palavra prostatectomia
#
#
# A palavra procurada em (24018, 24032, 'Item') que  deve estar entre 24018 24032 é a palavra prostatectomia
#
#
# A palavra procurada em (26568, 26582, 'Item') que  deve estar entre 26568 26582 é a palavra prostatectomia
#
#
# A palavra procurada em (27046, 27060, 'Item') que  deve estar entre 27046 27060 é a palavra prostatectomia
#
#
# A palavra procurada em (28722, 28736, 'Item') que  deve estar entre 28722 28736 é a palavra prostatectomia
#
# ##################################################################################################################################################
# Analisando o texto de numero 82 que é o text516.txt e que suas entidades estão em text516_entities.txt, temos
# text516.txt: assinado eletronicamente por: <permisc> - 18/07/ <idnum> 08:50:44 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - <permisc> . 18 <permisc> domperidona 1 mg/ml; depakote splinkler 125 mg e <permisc> mg, todos de uso continuo, a pacientediagnosticada com (paralisia cerebral), junto a <permisc> cronica nao <permisc> e estadual de saude, ate ulterior substituicao e ou suspensao por outro farmaco que se fizer necessarioalterar durante o tratamento da enfermidade, mediante pericia medica ou receituario medico atualizado.  <permisc> , recebida a presente, seja o municipio de serra talhada e o estado de pernambuco citado na pessoa de seurepresentante legal para, querendo, contestar a presente acao civil publica.  <permisc> por todos os meios de prova em direito admitidos. da-se a causa o valor de <permisc> <idnum> ,00 (um mil reais)  nestes termos,pede deferimento.  serra talhada, 18 de julho de <idnum> . (assinatura digital) <permisc> promotordejustica assinado eletronicamente por: <permisc> - 18/07/ <idnum> 08:50:44 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - <permisc> . 17 <permisc> 1. 1. - <permisc> , os estados, o distrito federal e os municipios sao solidariamenteresponsaveis pela saude publica, sendo perfeitamente possivel exigir-se do <permisc> a concessao de medicamentos aos cidadaos necessitados.- por se tratar de dever do estado, o tratamento de paciente carente nao caracterizalesao aos cofres publicos.(tjpr, <permisc> - <idnum> , <permisc> . des. <permisc> , 2a camara civel,unanime, dj 18/02/ <idnum> ). lamentavelmente, e de observar que ela pode ter um agravamento de sua saude ante a inercia da secretariamunicipal e estadual de saude em propiciar o tratamento adequado, o que robustece, ainda mais, o suporte juridicoensejador da antecipacao de tutela.posto isso, requer o <permisc> , com fulcro no art. 300 do <permisc> , arts. 11 e 12 da <permisc> , arts. 196 e 198 da cf, arts. 2 e 6 da <permisc>  a concessao da tutela de urgencia determinando-se ao municipio de serra talhada e ao estado depernambuco o fornecimento gratuito do suplemento nutricional pediasure, 14 (quatorze) latas mensais, de <permisc> e equipos para nutricao enteral, 30 (trinta) e 60 (sessenta) unidades respectivamente, bem comodos seguintes medicamentos: ranitidina 15 mg/ml; <permisc> 1 mg/ml; depakote splinkler 125mg e <permisc> mg, todos de uso continuo, a paciente diagnosticada com <permisc> (paralisia cerebral), na forma e apresentacao prescritas por medico.nao progressiva que seja fixada multa cominatoria de r$ <idnum> ,00 (um mil reais) diaria em caso de descumprimento damedida, que com certeza, sera concedida, cujos valores deverao ser revertidos ao fundo municipal e <permisc> . do pedido or todo o exposto, requer o ministerio publico de pernambuco, seja o municipio depserra talhada e o estado de pernambuco, condenado ao fornecimento gratuito do suplemento nutricionalpediasure, 14 (quatorze) latas mensais, de <permisc> e equipos para nutricao enteral, 30 por mes, 30 (trinta) e60 (sessenta) unidades respectivamente, bem como dos seguintes medicamentos: ranitidina 15 mg/ml; <permisc> assinado eletronicamente por: <permisc> - 18/07/ <idnum> 08:50:44 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - <permisc> . 3 <permisc> todos os medicamentos acima sao de uso continuo, a fim de garantir o devido o devido tratamento de saude dapaciente.  <permisc> que a familia nao dispoe de condicoes financeiras para arcar com os custosdo tratamento medicamentoso, necessitando assim ajuizar a presente acao. deste modo, visando garantir o direito do cidadao ao medicamento, a 3a <permisc> - curadoria da cidadania - serra talhada expediu os oficios n. 04/ <idnum> e 137/ <idnum> , solicitando,re ...
# Lista de entidades do texto text516.txt de 35059 caracteres são [(2448, 2458, 'Item'), (3268, 3278, 'Item'), (15063, 15073, 'Item')]
#
# A palavra procurada em (2448, 2458, 'Item') que  deve estar entre 2448 2458 é a palavra ranitidina
#
#
# A palavra procurada em (3268, 3278, 'Item') que  deve estar entre 3268 3278 é a palavra ranitidina
#
#
# A palavra procurada em (15063, 15073, 'Item') que  deve estar entre 15063 15073 é a palavra ranitidina
#
# ##################################################################################################################################################
# Analisando o texto de numero 83 que é o text500.txt e que suas entidades estão em text500_entities.txt, temos
# text500.txt: assinado eletronicamente por: rouse cleide cristina correia barbosa - 16/05/ <idnum> 14:57:12 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 7 <permisc> tribunal de justica de pernambuco <permisc> <permisc> - processo judicial eletronico <permisc> <permisc> 25/07/ <idnum> <permisc> <permisc> numero: <idnum> <permisc> <permisc> <permisc> <permisc> classe: peticao civel <permisc> <permisc> 8a <permisc> publica da capital <permisc> ultima distribuicao : 16/05/ <idnum> <permisc> <permisc> da causa: r$ <idnum> ,00 <permisc> <permisc> : tratamento medico- <permisc> e/ou <permisc> / nao <permisc> <permisc> <permisc> de justica? nao <permisc> justica gratuita? <permisc> <permisc> pedido de liminar ou antecipacao de tutela? <permisc> <permisc> <permisc> <permisc> partes <permisc> <permisc> procurador/terceiro vinculado <permisc> <permisc> <permisc> (requerente) <permisc> estado de pernambuco (requerido) <permisc> <permisc> (requerido) <permisc> <permisc> rouse cleide cristina correia barbosa (advogado) <permisc> <permisc> <permisc> s <permisc> <permisc> id. <permisc> <permisc> <idnum> <permisc> <permisc> <idnum> <permisc> 229 <permisc> <idnum> <permisc> 231 <permisc> <idnum> <permisc> 084 <permisc> <idnum> <permisc> 086 <permisc> <idnum> <permisc> 090 <permisc> <idnum> <permisc> 091 <permisc> <idnum> <permisc> 092 <permisc> <permisc> data da <permisc> <permisc> assinatura <permisc> <permisc> <permisc> <permisc> <permisc> 16/05/ <idnum> 14:57 peticao inicial <permisc> <permisc> 16/05/ <idnum> 14:57 peticao inicial <permisc> <permisc> tipo <permisc> <permisc> peticao inicial <permisc> <permisc> termo <permisc> <permisc> 16/05/ <idnum> 14:57 comprovante de <permisc> <idnum> <permisc> <permisc> outros ( <permisc> ) <permisc> <permisc> 16/05/ <idnum> 14:57 <permisc> . do <permisc> <permisc> <permisc> <permisc> de <permisc> ificacao <permisc> <permisc> 16/05/ <idnum> 14:57 <permisc> e dp <idnum> <permisc> <permisc> 16/05/ <idnum> 14:57 <permisc> . <idnum> <permisc> <permisc> 16/05/ <idnum> 14:57 <permisc> . <idnum> <permisc> <permisc> 16/05/ <idnum> 14:57 <permisc> . do <permisc> <idnum> <permisc> <permisc> outros ( <permisc> ) <permisc> <permisc> outros ( <permisc> ) <permisc> <permisc> outros ( <permisc> ) <permisc> <permisc> outros ( <permisc> ) <permisc> <permisc> assinado eletronicamente por: rouse cleide cristina correia barbosa - 16/05/ <idnum> 14:57:12 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 7 recomendado para tratamento na forma da receita medica, sob pena de multa diaria, nos termos do art. 497 e 537 do <permisc> , a ser determinada por este juizo; c) seja deferido ao autor os beneficios da <permisc> , por nao reunir condicoes de arcar com as custas e despesas processuais, expedindo-se afinal, a competente certidao de honorarios em favor de sua patrona, conforme valor a ser arbitrado por <permisc> ; d) a citacao dos reus, na forma do art. 246, ii do <permisc> atraves de oficial de justica para que os requeridos apresentem sua defesa dentro do prazo legal, sob pena de confissao e revelia nos termos do art. 344 do <permisc> ; e) nos termos do art. 334, ss 5o do <permisc> , o autor manifesta desde ja, pela natureza do litigio, seu desinteresse em auto composicao, tendo em vista se tratar de acao de <permisc> . <permisc> provas f) protesta provar o alegado por todos os meios de prova em direito admitidos, se necessario for na forma do art. 369 e seguintes do <permisc> . <permisc> da causa da-se a causa o valor de <permisc> (um <permisc> ). nestes termos, <permisc> . recife, 15 de maio de <idnum> assinatura digital assinado eletronicamente por: rouse cleide cristina correia barbosa - 16/05/ <idnum> 14:57:12 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 6 < ...
# Lista de entidades do texto text500.txt de 36395 caracteres são [(18256, 18276, 'Item'), (19687, 19707, 'Item'), (33085, 33105, 'Item'), (34531, 34551, 'Item')]
#
# A palavra procurada em (18256, 18276, 'Item') que  deve estar entre 18256 18276 é a palavra palbociclibe (ibranc
#
#
# A palavra procurada em (19687, 19707, 'Item') que  deve estar entre 19687 19707 é a palavra palbociclibe (ibranc
#
#
# A palavra procurada em (33085, 33105, 'Item') que  deve estar entre 33085 33105 é a palavra palbociclibe (ibranc
#
#
# A palavra procurada em (34531, 34551, 'Item') que  deve estar entre 34531 34551 é a palavra palbociclibe (ibranc
#
# ##################################################################################################################################################
# Analisando o texto de numero 84 que é o text233.txt e que suas entidades estão em text233_entities.txt, temos
# text233.txt: assinado eletronicamente. a certificacao digital pertence a: <permisc> silvestre <permisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 7 <permisc> no <idnum> , <permisc> ,tribunal de justica do rs, relator: <permisc> , <permisc> 29/05/ <idnum> ).  <permisc> - <permisc> -se que a requerente nao dispoe nem mesmo de medicamentos, econsiderada a forte prova documental juntada aos autos a comprovar os padecimentos dasmolestias e a recomendacao dos medicamentos, que seja, entao, deferida <permisc> a com fulcro no art. , do , para determinarantecipacao <permisc> de merito300cpcque a requerida os medicamentos descritos, doc anexos, os alimentosforneca mensalmentedescritos no programa alimentar e as consultas necessarias pelo <permisc> que deve ser afastada, qualquer alusao de que nao se pode conceder tutelaantecipada contra a fazenda publica. e isso porque, embora o art. , , da <permisc> /921oss 3o <idnum> proiba, nas acoes contra o <permisc> , a concessao de liminar que esgote no todo ou emparte o objeto da acao, ha situacoes em que os requisitos legais para antecipacao de tutela saotao presentes, que o e o , e ate o interesse publico, naofumus boni jurispericulum in moraso recomenda como impoe a concessao de liminar para cumprimento pelo poder publico,mesmo sem a sua manifestacao previa. assim ocorre quando ha preponderancia de principiosconstitucionais, no caso presente o direito a saude, a vida e a dignidade da pessoa humana.ainda assim, tem a parte o direito - e a oportunidade - de resguardar seus direitospor meio do <permisc> , como se sabe, garantido pelo art. , incisos e , da <permisc> , tratando-se a saude e a vida como bens de dificil reparacao, deve serconcedida a tutela antecipada. neste passo preciso sao os acordaos: ementa: agravo de instrumento. municipio dejaguarao. <permisc> . <permisc> solidariados entes federat <permisc> os. direito constitucional asaude. <permisc> do possivel e <permisc> poderes. <permisc> . <permisc> . 1. presentes os requisitosdo artigo do , deve ser concedida a tutela antecipada273cpcpostulada. 2. a responsabilidade pelo fornecimento dosmedicamentos postulados e solidaria entre uniao, estados emunicipios. eventual deliberacao a respeito da reparticao deresponsabilidade compete unicamente aos entes federativos, a serrealizada em momento oportuno, nao podendo o particular terlimitado seu direito a saude, garantido constitucionalmente, por atoda administracao. 3. ocasionais limitacoes ou dificuldadesorcamentarias nao podem servir de pretexto para negar o direito asaude e a vida, dada a prevalencia do direito reclamado. 4.inocorrente violacao ao principio da separacao dos poderes,porquanto ao <permisc> compete fazer cumprir as leis. . bloqueio de5 <permisc> assinado eletronicamente. a certificacao digital pertence a: <permisc> silvestre <permisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 10 dra. <permisc> / <permisc>  dra. <permisc> /pe <idnum> assinado eletronicamente. a certificacao digital pertence a: <permisc> silvestre <permisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 6 <permisc> tendo-se em vista que os servicos publicos de saude integram uma rederegionalizada e hierarquica, o sus, amparando-se no principio da co-gestao, com aparticipacao simultanea dos entes estatais dos tres niveis (art. da e o art. da lei 198cf/887o/90) cabe, contudo, ao estado, municipio, distrito federal e uniao promoverem as <idnum> condicoes indispensaveis ao seu pleno exercicio. portanto, e obrigacao do estado darassistencia a saude e dar os meios indispensaveis para o tratamento medico.assim sendo, vale mencionar a posicao jurisprudencial do tjrs:  <permisc> : apelacao reexame necessario. direitopublico nao especificado. consti ...
# Lista de entidades do texto text233.txt de 24174 caracteres são [(11191, 11198, 'Item')]
#
# A palavra procurada em (11191, 11198, 'Item') que  deve estar entre 11191 11198 é a palavra centrum
#
# ##################################################################################################################################################
# Analisando o texto de numero 85 que é o text343.txt e que suas entidades estão em text343_entities.txt, temos
# text343.txt: assinado eletronicamente por: <permisc> - 05/10/ <idnum> 10:33:18 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 4 <permisc> d) ao final, que seja julgado procedente o pedido a fim de condenar o reu a fornecer mensalmente, de forma continua e permanente,a medicacao e a alimentacao <permisc> 10mgfortini 400g, 14 latas/mes,oficiando-se diretamente a secretaria de saude e a <permisc> para;fornecimento imediato do medicamento a parte autora ou alguem ao seu rogoe) a gratuidade da justica, na forma do art. 98 e seguintes da cpc/ <idnum> porquanto a autora e pessoabeneficiaria da assistencia juridica gratuita prestada pela <permisc> , nos moldes do art.5o, incisos <permisc> e <permisc> e lxxvii, da constituicao da republica. <permisc> pela promovente, em anexo;f) que seja garantida a observancia das prerrogativas previstas no art. 128 da <permisc> federaln.o 80/94, notadamente a contagem de todos os prazos em dobro e intimacao pessoal com vista dos autosem qualquer processo e grau de jurisdicao, e representacao da parte independentemente de mandato,ressalvados os casos para os quais a lei exija poderes especiais; protesta provar o alegado por todos os meios de provas em direito admissiveis, em especial provadocumental.  <permisc> a causa o valor de r$ <idnum> ,00 (quatro mil reais).nesses termos, pede deferimento.  <permisc> , 05 de <permisc> de <idnum> .  <permisc>     <permisc>   < <permisc> rmisc> assinado eletronicamente por: < <permisc> rmisc> - 05/10/ <idnum> 10:33:18 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> < <permisc> rmisc> num. <idnum> - pag. 1 < <permisc> rmisc> excelentissimo(a) senhor(a) < <permisc> rmisc> ) de direito da vara _____ da comarcade <permisc> squeira - <permisc> rnambuco.  urgente - < <permisc> rmisc> - saude  luan < <permisc> rmisc> , brasileiro, menor impubere, portador dorg. no <idnum> -sds- <permisc> e cpf\ <permisc> no <idnum> , neste ato representado porseu genitor: brasileiro, solteiro, vendedor, < <permisc> rmisc> leal de souza,filho de < <permisc> rmisc> e < <permisc> rmisc> , portador da cedula deidentidade rg n. < <permisc> rmisc> / <permisc> , inscrito no cpf/ <permisc> sob o no <idnum> , , residente e domiciliado na rua presidentefone: (81) <idnum> # (87) <idnum> medici, no 31, pedra redonda, pesqueira/ <permisc> , vem, por meio da defensoria, <permisc> / <permisc> ,publica do estado de <permisc> rnambucorepresentada pela defensora publica abaixo subscrita, respeitosamente, a presenca devossa excelencia, requerer a presente,  contra o , pessoa juridica de direito publico interno, com sede na pracaestado de <permisc> rnambucoda republica, santo antonio, recife/ <permisc> , (rua julio tavares de lima, 185 - cel. siqueira campos,), pelas razoes de fato e de direitoarcoverde - <permisc> , <idnum> , sede da procuradoria regional do estadoque passa a expor:acao de obrigacao de <permisc> com <permisc> dido <permisc> de urgencia            pelo procedimento comum, em face de (que por meio da estado de <permisc> rnambuco detem a gestao estadual do sistema unico de saude), pessoasecretaria de estado de saudejuridica de direito publico, representado pelo seu procurador geral, o qual pode ser encontrado na rua dosol, 143, santo antonio, recife/ <permisc> , consoante razoes de fato e de direito que passa a expor: da gratuidade da justica inicialmente, requer os beneficios da gratuidade da justica na sua integralidade, com esteio nos incisos i aix, do ss1o do art. 98, face sua insuficiencia de recursos, nao tendo a minima condicao de arcar com opagamento das custas, despesas processuais e os honorarios advocaticios, conforme reza o art. 98 e 99, <permisc> , indicando a defensoria publica do estado da pernambuco para o patrocinio dacausa. i - dos <permisc> e portador de <permisc> + <permisc> ( <permisc> : <permisc> + g <idnum> ),cons ...
# Lista de entidades do texto text343.txt de 10853 caracteres são [(391, 398, 'Item')]
#
# A palavra procurada em (391, 398, 'Item') que  deve estar entre 391 398 é a palavra fortini
#
# ##################################################################################################################################################
# Analisando o texto de numero 86 que é o text261.txt e que suas entidades estão em text261_entities.txt, temos
# text261.txt: < <permisc> rmisc> meio para obter a satisfacao de um interesse primario lesado pelo comportamento da parte < <permisc> rmisc> contraria, ou, mais genericamente, pela situacao de fato objetivamente existente.1 < <permisc> rmisc> tres aspectos sao fundamentais para a correta analise do interesse agir no ambito da < <permisc> rmisc> acao: a utilidade, verificada quando o processo puder propiciar ao demandante o resultado < <permisc> rmisc> favoravel; a necessidade, que diz respeito a falta de meios para a satisfacao voluntaria, hipotese em < <permisc> rmisc> que surge a necessidade de jurisdicao; e, por fim, a adequacao, que indica ao autor o dever de < <permisc> rmisc> demonstrar o procedimento e o tipo de provimento adequados a sua situacao juridica. < <permisc> rmisc> < <permisc> rmisc> < <permisc> rmisc> < <permisc> rmisc> e observada quando o processo puder propiciar ao < <permisc> rmisc> demandante o resultado favoravel pretendido. assim, a providencia jurisdicional reputa-se util na < <permisc> rmisc> medida em que, "por sua natureza, verdadeiramente se revele - sempre em tese - apta a tutelar, de < <permisc> rmisc> maneira tao completa quanto possivel, a situacao juridica do requerente <permisc> .2 < <permisc> rmisc> no caso em tela, a utilidade da acao e verificada pela necessidade urgente de realizacao < <permisc> rmisc> de um procedimento cirurgico, conforme laudo, em anexo, emitido pela dra. < <permisc> rmisc> (crm- < <permisc> rmisc> <permisc> <idnum> ). < <permisc> rmisc> < <permisc> rmisc> <permisc> casu, o autor, enquanto titular de um direito constitucionalmente assegurado, qual < <permisc> rmisc> seja, o direito a vida e a saude, e amplamente considerado um bem de dimensao supralegal e de < <permisc> rmisc> natureza suprapositiva, necessita de um tratamento para resguardar o seu delicado estado de saude. < <permisc> rmisc> < <permisc> rmisc> < <permisc> rmisc> por fim, o interesse-adequacao indica ao autor o dever de demonstrar o procedimento < <permisc> rmisc> e o tipo de provimento adequados a solucao de sua situacao juridica; o contrario resultaria na < <permisc> rmisc> impossibilidade de analise meritoria da pretensao formulada. assim, o procedimento constitui-se < <permisc> rmisc> como a espinha dorsal da relacao juridica posta na acao, sendo o processo, em seu aspecto formal, < <permisc> rmisc> procedimento. < <permisc> rmisc> < <permisc> rmisc> portanto, e notorio o interesse de agir no presente caso, principalmente se ponderadas < <permisc> rmisc> < <permisc> rmisc> as questoes abaixo, veja-se: < <permisc> rmisc> < <permisc> rmisc> a uma, porque a ineficacia do estado no cumprimento do seu mister e causa direta da < <permisc> rmisc> intervencao do <permisc> , uma vez que, em tal hipotese, estarao presentes a pretensao, que < <permisc> rmisc> e o bom funcionamento do <permisc> publico de saude, bem como a correspectiva resistencia, que e < <permisc> rmisc> observada na falha da administracao. assim, demonstradas a pretensao e a resistencia, encontram- < <permisc> rmisc> se preenchidos os fundamentos do interesse de agir, seja na acao em que se pleiteie a prestacao < <permisc> rmisc> eficiente do <permisc> , seja em eventual demanda direcionada a responsabilidade civil do estado, < <permisc> rmisc> < <permisc> rmisc> < <permisc> rmisc> 1 <permisc> , <permisc> . <permisc> . 2. <permisc> rio de janeiro: forense, <idnum> , v.1, p. < <permisc> rmisc> <idnum> . < <permisc> rmisc> 2 moreira, <permisc> . "acao declaratoria e interesse <permisc> . <permisc> (ensaios e < <permisc> rmisc> pareceres). rio de janeiro: <permisc> , <idnum> , p. 17. <permisc> , <permisc> . <permisc> . 2. < <permisc> rmisc> <permisc> rio de janeiro: forense, <idnum> , v.1, p. 155. < <permisc> rmisc> < <permisc> rmisc> ________________________________________________________________________________ < <permisc> rmisc> 3 < <permisc> rmisc> a < <permisc> rmisc> n < <permisc> rmisc> i < <permisc> rmisc> g < <permisc> rmisc> a < < ...
# Lista de entidades do texto text261.txt de 471798 caracteres são [(290114, 290133, 'Item')]
#
# A palavra procurada em (290114, 290133, 'Item') que  deve estar entre 290114 290133 é a palavra uretrotomia interna
#
# ##################################################################################################################################################
# Analisando o texto de numero 87 que é o text134.txt e que suas entidades estão em text134_entities.txt, temos
# text134.txt: assinado eletronicamente. a certificacao digital pertence a: eloisa <permisc> rodrigues https://pje.tjpe.jus.br/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 7 <permisc> rg <idnum> sds/ <permisc> assinado eletronicamente. a certificacao digital pertence a: eloisa <permisc> rodrigues https://pje.tjpe.jus.br/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 5 <permisc> de lombociatalgia - saude - direito constitucionalmentegarantido - assistencia integral - comprovacao danecessidade - multa - cabimento. - <permisc> a necessidade doprocedimento pretendido por pessoa necessitada, em se tratando de molestiagrave, este deve ser fornecido, sob pena de ofensa ao direito a saude, garantidoconstitucionalmente. - sendo razoavel a multa arbitrada, descabe a reducao. -sentenca confirmada no reexame necessario. - <permisc> voluntario prejudicado. tj-sp - <permisc> de instrumento ai <idnum> sp <idnum> (tj-sp)data de publicacao: 02/11/ <idnum> ementa:  <permisc> .   encefalica comressonanciamagneticacontraste e espectroscopia. paciente acometida de glioblastoma multiformecerebral. 1. verossimilhanca das alegacoes. a autora demonstrou que passou porcirurgia encefalica em decorrencia de neoplasia cerebral maligna e necessita do complementar para monitoramento pos-operatorio de recidiva. 2. <permisc> deexamedano grave. em caso de neoplasia maligna, evidencia-se a necessidade dediagnostico precoce para aumentar as chances de sucesso no tratamento em casode recidiva. <permisc> provido. aplicacao do art. 557, ss 1o-a do <permisc> .  <permisc> demonstrada, por via da prova documental, a presenca dos requisitos que daoensejo a concessao da tutela de urgencia.  <permisc> requerimentos diante do exposto e com base na legislacao vigente, requer, de <permisc> :  <permisc> a concessao dos beneficios da assistencia judiciaria gratuita, preceituados noart.5o, <permisc> , da <permisc> , na <permisc> <idnum> /50 e no artigo 98 do <permisc> , por serem orequerente e sua <permisc> pobres, na acepcao juridica do termo, nao reunindo condicoes dearcar com os encargos decorrentes do processo, sem prejuizo se seu sustento e de sua familia; a concessao da tutela de urgencia, obrigando o reu, solidariamente, a fornecer tudoque for necessario para a realizacao do seguinte procedimento: a realizacao do exame de: ressonanciamagnetica do ombro direito, ressonancia magnetica da coluna cervical, ressonancia magnetica dacoluna lombar e colonoscopia.. <permisc> bem como os demais procedimentos que venham se fazer necessarios;   <permisc> a <permisc> , apos concedida a tutela de urgencia para, querendo, no prazolegal, contestar a presente acao, sob pena de ser reputado como verdadeiro os fatos aqui relatados; seja julgado integralmente procedente o pedido, cominando-se as demandadas a obrigacao de fazer a fornecerem tudo que for necessario para a realizacao do seguinte procedimento: aassinado eletronicamente. a certificacao digital pertence a: eloisa <permisc> rodrigues https://pje.tjpe.jus.br/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> <permisc> num. <idnum> - pag. 4 <permisc> tj-rs - reexame necessario reex <idnum> rs (tj- <permisc> de publicacao: 08/04/ <idnum> ementa:  <permisc> . direito a saude.fornecimento dede. nao <permisc>    <permisc>   <permisc> de reexame necessario quando estiver a sentenca fundada emjurisprudencia do plenario do stf, tal como ocorre em relacao aopronunciamento que reconhece o dever do estado de fornecer aexame quem nao tem condicoes financeiras de honra-lo. no caso, alem do ss 3odo art. 475, incide tambem, o ss 2o, poisde r$ <idnum> ,00, inferior a exame 60 salarios minimos. <permisc> nao conhecido.(reexame necessario no <idnum> , <permisc> ,tribunal de justica do rs, <permisc> , <permisc> 02/04/ <idnum> ) tj-rs - <permisc> (tj- <permisc> de publicacao: 02/03/  ...
# Lista de entidades do texto text134.txt de 16008 caracteres são [(2483, 2504, 'Item'), (2525, 2546, 'Item'), (8752, 8773, 'Item'), (8791, 8812, 'Item'), (8833, 8854, 'Item'), (9150, 9171, 'Item'), (9190, 9211, 'Item'), (9231, 9252, 'Item'), (14295, 14316, 'Item'), (14335, 14356, 'Item'), (14376, 14397, 'Item')]
#
# A palavra procurada em (2483, 2504, 'Item') que  deve estar entre 2483 2504 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (2525, 2546, 'Item') que  deve estar entre 2525 2546 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (8752, 8773, 'Item') que  deve estar entre 8752 8773 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (8791, 8812, 'Item') que  deve estar entre 8791 8812 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (8833, 8854, 'Item') que  deve estar entre 8833 8854 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (9150, 9171, 'Item') que  deve estar entre 9150 9171 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (9190, 9211, 'Item') que  deve estar entre 9190 9211 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (9231, 9252, 'Item') que  deve estar entre 9231 9252 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (14295, 14316, 'Item') que  deve estar entre 14295 14316 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (14335, 14356, 'Item') que  deve estar entre 14335 14356 é a palavra ressonancia magnetica
#
#
# A palavra procurada em (14376, 14397, 'Item') que  deve estar entre 14376 14397 é a palavra ressonancia magnetica
#
# ##################################################################################################################################################
# Analisando o texto de numero 88 que é o text316.txt e que suas entidades estão em text316_entities.txt, temos
# text316.txt: assinado eletronicamente por: raissa de oliveira santos lima - 14/08/ <idnum> 16:54:47 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6              de mais a mais, ainda que ditos medicamentos nao estejam incluidos na <permisc> , cedico que talcircunstancia nao constitui impeditivo ao estado quanto ao seu fornecimento, ja que cabe a qualquer dosentes publicos integrantes da federacao a prestacao de servicos e/ou medicamentos necessarios aconservacao da saude do cidadao, constituindo dever de todos promover a saude da populacao.             a proposito, o <permisc> no. <idnum> /pe, de <permisc> . do <permisc> . <permisc> , 1acamara <permisc> - <permisc> , tribunal de justica do estado de pernambuco: "tjpe: administrativo e constitucional. <permisc> medicamentoimprescindivel <permisc> do demandante portador deglioblastoma multiforme (tumor cerebral primario). sentenca que julgaprocedente o pedido da inicial para determinar que o estado forneca omedicamento temozolamida- <permisc> 100mg. <permisc> do estado. preliminarde <permisc> . merito: <permisc> <permisc> daseparacao dos poderes, <permisc> medicamento de alto custo naoconstante na <permisc> e <permisc> comprovacao daeficacia exclusiva do medicamento solicitado. <permisc> <permisc> . 1. notocante a alegacao do estado de pernambuco de que a responsabilidade em fornecer o medicamentoindicado para o restabelecimento da saude da apelada e da uniao, atraves de seus centros de assistenciade alta complexidade em oncologia - cacons, entendo que a mesma nao merece prosperar, pois <permisc> tem entendido que, nesses casos, a responsabilidade entre os entes publicos, municipio,estado e uniao, e solidaria, uma vez que constitui dever do poder publico, em qualquer de suas esferas,assegurar a todas as pessoas o direito a manutencao da saude, consequencia indissociavel do direito avida. 2. a ausencia do referido medicamento na lista padronizada do sus, estabelecida pelo <permisc> , nao pode subtrair dos cidadaos carentes a medicacao necessaria a cura de suas enfermidades,tampouco pode impedir o judiciario de conceder um provimento para viabilizar o tratamento adequado eeficaz para o paciente. 3. no caso nao ha violacao ao principio da isonomia/igualdade, da reserva dopossivel e da separacao dos poderes, como alega o apelante, visto que, o que se pretende com a presentedecisao, e o cumprimento pelo estado, do seu dever de proteger e recuperar a saude da populacao.quando ha um conflito entre exigencias constitucionais formais e o direito a saude, de regra, deveprevalecer este ultimo. 4. no tocante a alegacao de que o medicamento indicado pelo medico do enfermopara combater a doenca pode ser substituido por outros medicamentos contemplados na listagem oficial,que podem ser fornecidos pelo estado de pernambuco em substituicao ao que foi indicado pelo medico,entendo que o mesmo nao deve prosperar, uma vez que o medicamento a ser utilizado e a dosagemadequada para o restabelecimento da saude da autora inserem-se no "merito-medicinal-terapeutico". 5.decisao unanime". (grifei)  4. do pedido de <permisc> :             no tocante a antecipacao de tutela, encontram-se presentes os requisitos indispensaveis a suaconcessao, quais sejam, o fumus bonis iuris e o periculum in mora. assinado eletronicamente por: ra <permisc> ssa de ol <permisc> ve <permisc> ra santos l <permisc> ma - 14/08/ <idnum> 16:54:47 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 7             no mais, convem ressaltar desde logo que, em acao civil publica, o instrumento processual emcomento rege-se pela diccao do artigo 300, do <perm <permisc> sc> , norma aplicavel as acoes quetenham por objeto o cumprimento de obrigacao de fazer ou nao fazer, o qual assim preconiza:  <perm <permisc> sc> . 300. a tutela de urgencia sera concedida quando houver elemento ...
# Lista de entidades do texto text316.txt de 20028 caracteres são [(19653, 19674, 'Item')]
#
# A palavra procurada em (19653, 19674, 'Item') que  deve estar entre 19653 19674 é a palavra corticoide inalatorio
#
# ##################################################################################################################################################
# Analisando o texto de numero 89 que é o text278.txt e que suas entidades estão em text278_entities.txt, temos
# text278.txt: assinado eletronicamente. a certificacao digital pertence a: eudes <permisc> de <permisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6 <permisc> p. deferimento.        <permisc> , 16 de fevereiro de <idnum> . bel. <permisc> : <idnum> oab-pe <idnum>   assinado eletronicamente. a certificacao digital pertence a: eudes < <permisc> rmisc> de < <permisc> rmisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 1 exmo.sr.dr.juiz de direito da ____vara  da comarca dosalgueiro - < <permisc> rmisc> <permisc> rnambuco.    urgente   acao de obrigacao de fazer com pedido de tutela de urgenciaa. - < <permisc> rmisc> de < <permisc> rmisc> - estado de pernambucopeca inicial                liodete < <permisc> rmisc> ,brasileira, solteira, do lar, portadora do rg no <idnum> ssp/ <permisc> . inscrito no , residente e domiciliada na avenida antonio angelim,ecpf(mf) sob o no. <idnum> no.551, bairro santo antonio, salgueiro/ <permisc> .,  , vem, por meio do telefone (87) <idnum> defensor, com endereco para recepcao de intimacoes e notificacoes de estilopublico do estado de pernambucosituado na rua ermirio ribeiro, 357, bairro nossa senhora das gracas, salgueiro/ <permisc> ., constituido nostermos do art. 128, <permisc> , da <permisc> no 80/94, prescindindo da apresentacao deprocuracao e com prerrogativa de intimacao pessoal, consoante os arts. 185 e 186 do <permisc> , muirespeitosamente a augusta presenca de <permisc> ., com fulcro nos artigos 5o. e 196 e seguintes <permisc> , artigo 300 do <permisc> e nos artigos 2o e 6o da <permisc> <idnum> /90, propora presente  <permisc> de <permisc> com <permisc> dido <permisc> em face do , pessoa juridica de direito publico, com sede noestado de <permisc> rnambucopalacio do campo das princesas, praca da republica, s/n, bairro santo antonio, recife/ <permisc> , pelos fatos efundamentos a seguir expostos. da gratuidade da justicaassinado eletronicamente. a certificacao digital pertence a: eudes <permisc> de <permisc> https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 5 <permisc> dessa forma, verificado que a pretensao autoral encontra amplo respaldo no ordenamento juridicopatrio, impoe-se o deferimento do pedido aduzido na exordial, inclusive em sede de antecipacao dosefeitos da tutela.do pedido             ante o exposto, a <permisc> :requer            a) os beneficios da , em conformidade com os arts. 98 e 99 do <permisc> , ja quegratuidade da justicanao possui condicoes financeiras para arcar com o pagamento das custas judiciais e honorariosadvocaticios, sem prejuizo do proprio sustento e de sua familia, conforme <permisc> em anexo.            b)  a concessao, da tutela de urgencia, a fim de determinar que o <permisc> altera pars,forneca o medicamento <permisc> 200mgpor , e se for o acaso ate quando necessario,6 (seis) mesesdeterminando-se, em caso de descumprimento, o pagamento pelo estado de multa diaria na importanciade r$ <idnum> ,00 (cinco mil reais) ou outro valor arbitrado por <permisc> , sem prejuizo daresponsabilidade civil e criminal.            c) a citacao do , na pessoa de seu representante legal, para, querendo, <permisc> resposta a pretensao do <permisc> d)  seja julgada procedente a presente acao, concedendo-se de forma definitiva o pedido contidona alinea "b".            e) a intimacao pessoal da a. para todos os atos processuais, consoante o art. 186, ss2o, do <permisc> .            f)  seja o reu condenado ao pagamento das custas e honorarios advocaticios, equivalente a15% (quinze por cento) sobre o valor da causa, revertendo-se em beneficio da <permisc> do estado de pe, conta corrente no <idnum> , <permisc> , agencia <idnum> ,caixa economica federal.            <permisc> , em razao da extrema urgencia de ver o seu direito tu ...
# Lista de entidades do texto text278.txt de 13123 caracteres são [(5461, 5471, 'Item'), (5632, 5642, 'Item'), (6278, 6288, 'Item'), (10545, 10555, 'Item')]
#
# A palavra procurada em (5461, 5471, 'Item') que  deve estar entre 5461 5471 é a palavra sorafenibe
#
#
# A palavra procurada em (5632, 5642, 'Item') que  deve estar entre 5632 5642 é a palavra sorafenibe
#
#
# A palavra procurada em (6278, 6288, 'Item') que  deve estar entre 6278 6288 é a palavra sorafenibe
#
#
# A palavra procurada em (10545, 10555, 'Item') que  deve estar entre 10545 10555 é a palavra sorafenibe
#
# ##################################################################################################################################################
# Analisando o texto de numero 90 que é o text365.txt e que suas entidades estão em text365_entities.txt, temos
# ...
# Lista de entidades do texto text153.txt de 323478 caracteres são [(288314, 288324, 'Item'), (290326, 290336, 'Item')]
#
# A palavra procurada em (288314, 288324, 'Item') que  deve estar entre 288314 288324 é a palavra tomografia
#
#
# A palavra procurada em (290326, 290336, 'Item') que  deve estar entre 290326 290336 é a palavra tomografia
#
# ##################################################################################################################################################
# Analisando o texto de numero 103 que é o text527.txt e que suas entidades estão em text527_entities.txt, temos
# text527.txt: assinado eletronicamente por: <permisc> de almeida - 10/09/ <idnum> 12:13:29 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 5 <permisc> . a antecipacao dos efeitos da tutela, , para determinar que os reus, por meio de suas <permisc> , noinaudita altera parsprazo maximo de 02 (dois) dias, procedam ao fornecimento do medicamento acima elencado, na forma descrita nos documentosanexados a exordial, bem como de outros insumos, exames, tratamentos e/ou medicamentos futuramente ministrados, sob pena demulta diaria na forma do art. 537, ss 3o, do <permisc> ; 3. em caso de inercia, seja determinado o bloqueio , ou a transferencia direta para conta de deposito judicial a ordem desseonlinemm. juizo, da quantia necessaria a aquisicao dos insumos/medicamentos/exames/tratamentos em questao; 4. seja julgado procedente o pedido, para condenar os reus, solidariamente, ao fornecimento do medicamento acima descrito,inclusive aqueles resultantes de futuras alteracoes na prescricao, reconhecendo-se, assim, o dever dos demandados de zelar pelasaude do cidadao; 5. a condenacao dos reus ao pagamento das custas processuais e honorarios advocaticios, fixados conforme o disposto no art. 85,ss 3o, do <permisc> e recolhidos em favor da defensoria publica do estado de pernambuco, de acordo com os seguintes dados bancarios-cef (104), agencia no <idnum> , c/c no <idnum> .    <permisc> pela producao de todos os meios de prova admitidos, em especial documental e pericial.    <permisc> -se a causa o valor de <permisc> .   nestes termos,  <permisc> . recife, 10 de setembro de <idnum> . assinado eletronicamente por: <permisc> de almeida - 10/09/ <idnum> 12:13:29 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 2    em face do pessoa juridica de direito publico interno, cnpj no <idnum> / <idnum> , com sede na av.municipio do recife,cais do apolo, no 925, recife, pe, cep. <idnum> e do pessoa juridica de direito publicoestado de pernambuco,interno, cnpj no <idnum> / <idnum> , com sede na praca da republica, s/n, palacio do campo das princesas, cep. <idnum> ,recife, pe, presentados por suas respectivas procuradorias, pelas razoes de fato e de direito que passa a expor:   da gratuidade da justica inicialmente, afirma, de acordo com os arts. 98 e 99, ambos do <permisc> , nao ter condicoes de arcar com custasjudiciais, despesas processuais e honorarios advocaticios, sem prejuizo do proprio sustento ou de sua familia, razao pela qual fazjus aos beneficios de <permisc> , indicando a defensoria publica para o patrocinio de seus interesses. dessa forma,informa, desde ja, que utilizara a prerrogativa do prazo em dobro conferida pelo art. 186 do <permisc> .    <permisc> -mail e desinteresse na <permisc>  o autor nao possui endereco eletronico. apesar da ausencia de elementos de qualificacao, ha de preponderar o acesso a justica,conforme ressai do disposto nos arts. 6o e 319, ss3o, ambos do <permisc> . ainda, o demandante manifesta desinteresse na composicaoconsensual.    <permisc> fatos o autor e crianca de tres anos portadora de neoplasia , tendo feito variosleucemia <permisc> <permisc> desde maio de <idnum> que apontam esse diagnostico, conforme relata detalhadamente laudo medico exarado pela dra. <permisc> , do hospital oswaldo cruz, onde ele deu entrada no final de agosto. assinado eletronicamente por: <permisc> de almeida - 10/09/ <idnum> 12:13:29 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6    <permisc> de almeida defensora publica    <permisc>   <permisc>   assinado eletronicamente por: <permisc> de almeida - 10/09/ <idnum> 12:13:29 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - pag. 3 desse modo, o autor, atualmente, possui  ...
# Lista de entidades do texto text527.txt de 9918 caracteres são [(4109, 4120, 'Item'), (5362, 5373, 'Item')]
#
# A palavra procurada em (4109, 4120, 'Item') que  deve estar entre 4109 4120 é a palavra azacitidina
#
#
# A palavra procurada em (5362, 5373, 'Item') que  deve estar entre 5362 5373 é a palavra azacitidina
#
# ##################################################################################################################################################
# Analisando o texto de numero 104 que é o text258.txt e que suas entidades estão em text258_entities.txt, temos
# text258.txt: <permisc> <permisc> - <permisc> consulta processual 15/05/ <idnum> numero: <idnum> <permisc> : carta precatoria civel orgao julgador: <permisc> , <permisc> e <permisc> da capital <permisc> distribuicao : 29/03/ <idnum> assuntos: citacao <permisc> de justica? nao <permisc> gratuita? <permisc> pedido de liminar ou antecipacao de tutela? nao <permisc> deprecante deprecado partes nome rafaela goncalves da <permisc> estado de pernambuco documentos id. <idnum> data da assinatura documento 29/03/ <idnum> 23:35 inicial <idnum> tipo expediente <permisc> assinado eletronicamente. a certificacao digital pertence a: gilson da silva cruz https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 1 excelentissimo senhor doutor juiz de direito da ___ vara da < <permisc> rmisc> ( <permisc> )liminar - saudesophia rafaelly goncalves do nascimento, brasileira, representada por sua genitora sra. < <permisc> rmisc> goncalves da silva, brasileira, casada, do lar, portadora da cedula de identidade < <permisc> rmisc> no. <idnum> sds/ <permisc> e do cpf no. <idnum> , residente na rua 20, no93, <permisc> , fone: <idnum> , por ser pobre na forma da lei, vem respeitosamente perante <permisc> , por meio <permisc> , com fulcro nos arts. 5o, 196 e ss. da constituicao federal, art. 2o dalei <idnum> /90 e demais disposicoes pertinentes a especie, expor e propor a presenteacao de obrigacao de <permisc> / <permisc> o estado de <permisc> rnambuco, pessoa juridica de direito publico interno, com sede situada <permisc> do campo das princesas, praca da republica, s/n, cep <idnum> , recife- <permisc> , pelo que passa aexpor e requerer o que segue: preliminarmente, requer os beneficios da <permisc> , por ser pobre na forma da lei, nao tendo comoprover as despesas do processo sem prejuizo do sustento proprio ou de sua familia (art. 98, ncpc).i. <permisc> :a autora e portadora de alergia a proteina ao leite de vaca, conforme diagnostico constante no laudomedico anexo.ela e acompanhada pelo <permisc> que solicitou o uso do suplemento alimentar <permisc> , naquantidade de 12 latas ao mes, por um periodo de 03 meses, ou ate a progressao da doenca, conformerequisicao medica, uma vez que a assistida precisa do referido suplemento alimentar de forma imediata,sob pena de agravamento de sua patologia, conforme , prescrito pela medica, dra. <permisc> , crm <idnum> .em requerimento feito pela defensoria publica de pernambuco, encaminhado a secretaria de saude doestado, foi solicitado o fornecimento do suplemento, porem, a paciente recebeu resposta negativa quantoao fornecimento do referido suplemento, haja vista que a secretaria ate o momento nao respondeu aooficio enviado pela defensoria (oficio em anexo);feita uma breve introducao a respeito da enfermidade da autora desta acao, conforme documentos emprocesso <permisc> : https://pje.tjpe.jus.br/1g/painel/painel_usuario/documentohtml.seam...1 de 729/03/ <idnum> 14:22 <permisc> assinado eletronicamente. a certificacao digital pertence a: gilson da silva cruz https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?nd= <idnum> numero do documento: <idnum> num. <idnum> - pag. 6 vejamos: <permisc> - obrigacao de nao <permisc> - <permisc> -concessao <permisc> altera parte - possibilidade - <permisc> fumus boni iurise periculum in mora. o paragrafo terceiro do art. 461 do <permisc> admite a possibilidade de concessaoda liminar inaudita altera parte. sendo a hipotese de obrigacao de nao fazer, autoriza o ss 3o do art. 461 do <permisc> a concessao da tutela especifica em carater liminar, desde que presentes a existencia do justificadoreceio de ineficacia do provimento final - periculum in mora - e o relevante fundamento da demanda -fumus boni iuris. <permisc> - acao de obrigacao de <permisc> - adiantamento <permisc> especifica - <permisc> demonstra <permisc> para o seu deferimento. para queocorra o adiantamento da tutela especifica e su ...
# Lista de entidades do texto text258.txt de 26050 caracteres são [(16998, 17005, 'Item')]
#
# A palavra procurada em (16998, 17005, 'Item') que  deve estar entre 16998 17005 é a palavra neocate
#
# ##################################################################################################################################################
# Analisando o texto de numero 105 que é o text543.txt e que suas entidades estão em text543_entities.txt, temos
# text543.txt: assinado eletronicamente por: myrta <perm <permisc> sc> - 12/09/ <idnum> 12:45:13 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> <perm <permisc> sc> num. <idnum> - <perm <permisc> sc> . 6 <perm <permisc> sc> (...)ss 4 a multa sera devida desde o dia em que se configurar o descumprimento daodecisao e incidira enquanto nao for cumprida a decisao que a tiver cominado.(...)" dessa forma, verificado que a pretensao autoral encontra amplo respaldo no ordenamento juridico patrio,impoe-se o deferimento do pedido aduzido na exordial, inclusive em sede de antecipacao dos efeitos datutela.     <permisc> v- <perm <permisc> sc> ped <permisc> <perm <permisc> sc>   diante de todo o exposto, requer a <perm <permisc> sc> o seguinte:     a)  <perm <permisc> sc> , por ser pobre na forma das <perm <permisc> sc> no. <idnum> /50 e <idnum> /83,uma vez nao dispondo de meios para prover as despesas do processo sem prejuizo do sustento proprio ouda familia; b)  seja o estado de pernambuco citado, por meio de <perm <permisc> sc> (art. 247, <perm <permisc> sc> ), na pessoa deseu representante legal, para contestar o feito, sob pena de aplicacao dos efeitos da revelia; c)  <perm <permisc> sc> o deferimento da <perm <permisc> sc> , conforme faculta o inciso <permisc> e <permisc> <permisc> do artigo 294do <permisc> , condenando a empresa re, a cobrir o pagamento <perm <permisc> sc> med <permisc> camentos quetiaina 100mg; <permisc> 300mg; e <permisc> 10mg c/60 comprimidos, tendo para assegurar um tratamento dea paciente que fazer uso de duas caixas por mes de cada medicacao,forma adequada, tendo como finalidade tratar o disturbio que acomete o autor da presente acao no prazode 48 (quarenta e oito) horas, com fixacao de mula diaria em caso de descumprimento da ordem judicial aser arbitrada por esse juizo, nao inferior a r$ <idnum> ,00 (mil reais). d)  a procedencia da acao, a fim de tornar definitiva a liminar, devendo a parte autora receber osmedicamentos descritos acima, por periodo indeterminado. <permisc> provar o alegado por todos os meios de provas em direito admissiveis, em especial provadocumental e testemunhal, cujo rol sera apresentado oportunamente.  da a causa o valor de r$ <idnum> ,56 (onze mil, quatrocentos e quatro mil e cinquenta e seis centavos). <permisc> assinado eletronicamente por: myrta < <permisc> rmisc> rodolfo de farias - 12/09/ <idnum> 12:45:13 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - < <permisc> rmisc> . 1 < <permisc> rmisc> (a) < <permisc> rmisc> (a) < <permisc> rmisc> (a) juiz (a) de direito da fazendapublica comarca de olinda/ < <permisc> rmisc> < <permisc> rmisc> - < <permisc> rmisc> - saude         < <permisc> rmisc> batista de santana de lira, brasileira, solteira, do lar, portadora do rg no <idnum> sds/ <permisc> , inscrito no cpf sob o no <idnum> , residente e domiciliado a av. <permisc> , no655, b5, apartamento 307, residencial rio doce, rio doce, olinda/ <permisc> , cep <idnum> , telefone:(81) <idnum> , por ser pobre na forma da lei conforme declaracao anexa, vem, respeitosamente,perante <permisc> , por meio da defensoria publica abaixo-assinada, com fulcro nos arts. 5o, 196 ess. da constituicao federal, art. 2o da <permisc> e demais disposicoes pertinentes a especie, expor epropor a presente  <permisc> de <permisc> com <permisc> dido < <permisc> rmisc>  em face do estado de <permisc> rnambuco,situado na rua do sol, no 143, santo antonio, recife - <permisc> ,cep: <idnum> , pelo que passa a expor e requerer o que segue: i- da gratuidade da justica assinado eletronicamente por: <permisc> <permisc> - 12/09/ <idnum> 12:45:13 https://pje.tjpe.jus.br:443/1g/processo/consultadocumento/listview.seam?x= <idnum> numero do documento: <idnum> num. <idnum> - <permisc> . 7    <permisc>  olinda, 12 de <permisc> <idnum> .   <permisc> <permisc> defensora publica  allisson meloes ...
# Lista de entidades do texto text543.txt de 14922 caracteres são [(11888, 11895, 'Item')]
#
# A palavra procurada em (11888, 11895, 'Item') que  deve estar entre 11888
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#teste lista de nomes de medicamentos
impListaRange2(nomeDosMedicamentos,len(nomeDosMedicamentos))
# Out:
# ('text207.txt', {'Medicamentos': ['beclometasona']}),
# ('text390.txt', {'Medicamentos': ['ofev 150mg ']}),
# ('text588.txt', {'Medicamentos': ['ressonancia magnetica de cranio com contraste e sedacao']}),
# ('text45.txt', {'Medicamentos': ['somatropina 12 ui']}),
# ('text139.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text287.txt', {'Medicamentos': ['temozolomida']}),
# ('text413.txt', {'Medicamentos': ['cadeira de rodas']}),
# ('text425.txt', {'Medicamentos': ['ritalina']}),
# ('text548.txt', {'Medicamentos': ['ressonancia magnetica de cranio com contraste e sedacao']}),
# ('text298.txt', {'Medicamentos': ['xeralto 20 mg']}),
# ('text75.txt', {'Medicamentos': ['fabrazyme']}),
# ('text89.txt', {'Medicamentos': ['lucentis']}),
# ('text131.txt', {'Medicamentos': ['cardiaca']}),
# ('text245.txt', {'Medicamentos': ['infliximabe', 'infliximab)']}),
# ('text266.txt', {'Medicamentos': ['oxibutinina']}),
# ('text372.txt', {'Medicamentos': ['rivaroxabana']}),
# ('text118.txt', {'Medicamentos': ['nivolumabe']}),
# ('text427.txt', {'Medicamentos': ['tiotropio']}),
# ('text201.txt', {'Medicamentos': ['rituximabe']}),
# ('text240.txt', {'Medicamentos': ['neocate']}),
# ('text54.txt', {'Medicamentos': ['alenia']}),
# ('text302.txt', {'Medicamentos': ['pregomin']}),
# ('text481.txt', {'Medicamentos': ['enlite sensor - caixa com 5 unidades']}),
# ('text63.txt', {'Medicamentos': ['benicar 20mg']}),
# ('text498.txt', {'Medicamentos': ['brentuximabe 50 mg']}),
# ('text404.txt', {'Medicamentos': ['aparelho optico']}),
# ('text457.txt', {'Medicamentos': ['colonoscopia']}),
# ('text356.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text373.txt', {'Medicamentos': ['lenvatinibe (lenvima']}),
# ('text85.txt', {'Medicamentos': ['cardiaca', 'cardiaco', 'cardiaca']}),
# ('text443.txt', {'Medicamentos': ['tiotropio']}),
# ('text350.txt', {'Medicamentos': ['acitretina 10mg']}),
# ('text394.txt', {'Medicamentos': ['fludarabina']}),
# ('text119.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text623.txt', {'Medicamentos': ['ressonancia magnetica de ombro esquerdo']}),
# ('text509.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text90.txt', {'Medicamentos': ['alenia']}),
# ('text141.txt', {'Medicamentos': ['pediasure']}),
# ('text177.txt', {'Medicamentos': ['dnu', 'dna', 'dnu', 'dna', 'dnu', 'dna', 'dnu']}),
# ('text569.txt', {'Medicamentos': ['anagrelide']}),
# ('text71.txt', {'Medicamentos': ['infliximabe']}),
# ('text432.txt', {'Medicamentos': ['bleomicina']}),
# ('text559.txt', {'Medicamentos': ['abiraterona']}),
# ('text440.txt', {'Medicamentos': ['spiriva']}),
# ('text486.txt', {'Medicamentos': ['rituximabe']}),
# ('text81.txt', {'Medicamentos': ['ranibizumabe', 'ranibizumab ', 'ranibizumabe', 'ranibizumab ']}),
# ('text220.txt', {'Medicamentos': ['alenia']}),
# ('text336.txt', {'Medicamentos': ['ultrassonografia']}),
# ('text540.txt', {'Medicamentos': ['pomada ilex']}),
# ('text526.txt', {'Medicamentos': ['histeroscopia diagnostica']}),
# ('text573.txt', {'Medicamentos': ['abiraterona']}),
# ('text596.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text603.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text253.txt', {'Medicamentos': ['zytiga (abiraterona) 250mg']}),
# ('text239.txt', {'Medicamentos': ['keppra 750mg']}),
# ('text214.txt', {'Medicamentos': ['vesicula biliar']}),
# ('text136.txt', {'Medicamentos': ['aripiprazol']}),
# ('text300.txt', {'Medicamentos': ['temodal']}),
# ('text495.txt', {'Medicamentos': ['enoxaparina 40mg,']}),
# ('text617.txt', {'Medicamentos': ['bleomicina']}),
# ('text480.txt', {'Medicamentos': ['aplicador do sensor enlite (one press serter']}),
# ('text354.txt', {'Medicamentos': ['eletroneuromiografia']}),
# ('text50.txt', {'Medicamentos': ['escitalopram 20 mg']}),
# ('text491.txt', {'Medicamentos': ['cystagon']}),
# ('text138.txt', {'Medicamentos': ['pregomin pepti']}),
# ('text229.txt', {'Medicamentos': ['bortezomib ', 'bortezomibq', 'bortezomib ', 'bortezomibr', 'bortezomib ']}),
# ('text479.txt', {'Medicamentos': ['clenia', 'clenil']}),
# ('text515.txt', {'Medicamentos': ['pediasure']}),
# ('text276.txt', {'Medicamentos': ['biotina']}),
# ('text517.txt', {'Medicamentos': ['carvedilol']}),
# ('text308.txt', {'Medicamentos': ['noripurum']}),
# ('text597.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text296.txt', {'Medicamentos': ['alentuzumab,']}),
# ('text304.txt', {'Medicamentos': ['metotrexado']}),
# ('text117.txt', {'Medicamentos': ['clexane']}),
# ('text386.txt', {'Medicamentos': ['transamin 250mg']}),
# ('text105.txt', {'Medicamentos': ['somatropina 12 ui']}),
# ('text46.txt', {'Medicamentos': ['somatropina 12 ui']}),
# ('text417.txt', {'Medicamentos': ['gardenal']}),
# ('text74.txt', {'Medicamentos': ['somatropina']}),
# ('text599.txt', {'Medicamentos': ['prostatectomia']}),
# ('text516.txt', {'Medicamentos': ['ranitidina']}),
# ('text500.txt', {'Medicamentos': ['palbociclibe (ibranc']}),
# ('text233.txt', {'Medicamentos': ['centrum']}),
# ('text343.txt', {'Medicamentos': ['fortini']}),
# ('text261.txt', {'Medicamentos': ['uretrotomia interna']}),
# ('text134.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text316.txt', {'Medicamentos': ['corticoide inalatorio']}),
# ('text278.txt', {'Medicamentos': ['sorafenibe']}),
# ('text365.txt', {'Medicamentos': ['duloxetina']}),
# ('text194.txt', {'Medicamentos': ['amato']}),
# ('text247.txt', {'Medicamentos': ['venetoclax']}),
# ('text553.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text175.txt', {'Medicamentos': ['imantinibe 400mg']}),
# ('text178.txt', {'Medicamentos': ['brentuximabe vedotin']}),
# ('text199.txt', {'Medicamentos': ['laqueadura']}),
# ('text237.txt', {'Medicamentos': ['jakavi']}),
# ('text552.txt', {'Medicamentos': ['mielograma']}),
# ('text64.txt', {'Medicamentos': ['tadalafil 5mg']}),
# ('text401.txt', {'Medicamentos': ['xarelto']}),
# ('text150.txt', {'Medicamentos': ['pertuzumabe', 'pertuzumab,', 'pertuzumabe']}),
# ('text153.txt', {'Medicamentos': ['tomografia']}),
# ('text527.txt', {'Medicamentos': ['azacitidina']}),
# ('text258.txt', {'Medicamentos': ['neocate']}),
# ('text543.txt', {'Medicamentos': ['ansitec']}),
# ('text411.txt', {'Medicamentos': ['temozolamida']}),
# ('text381.txt', {'Medicamentos': ['fosfoetanolamina']}),
# ('text327.txt', {'Medicamentos': ['ritalina']}),
# ('text56.txt', {'Medicamentos': ['bectrum']}),
# ('text37.txt', {'Medicamentos': ['melao de sao caetano']}),
# ('text379.txt', {'Medicamentos': ['risperidon ', 'risperidona']}),
# ('text609.txt', {'Medicamentos': ['timolol']}),
# ('text574.txt', {'Medicamentos': ['embolizacao do aneurisma']}),
# ('text273.txt', {'Medicamentos': ['cinacalcete 30mg']}),
# ('text519.txt', {'Medicamentos': ['pregabalina']}),
# ('text301.txt', {'Medicamentos': ['althera']}),
# ('text571.txt', {'Medicamentos': ['atezolizumab 60mg']}),
# ('text442.txt', {'Medicamentos': ['herniorrafia incisional']}),
# ('text547.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text255.txt', {'Medicamentos': ['risperidona']}),
# ('text493.txt', {'Medicamentos': ['pertuzumabe 420 mg']}),
# ('text83.txt', {'Medicamentos': ['nivolumabe']}),
# ('text485.txt', {'Medicamentos': ['colonoscopia']}),
# ('text359.txt', {'Medicamentos': ['aptamil pepti']}),
# ('text210.txt', {'Medicamentos': ['clofazimina 50mg']}),
# ('text322.txt', {'Medicamentos': ['clonazepan']}),
# ('text501.txt', {'Medicamentos': ['nebileto 5 mg']}),
# ('text349.txt', {'Medicamentos': ['nivolumab,', 'nivolumab(', 'nivolumab ']}),
# ('text230.txt', {'Medicamentos': ['temodal']}),
# ('text435.txt', {'Medicamentos': ['ortopedica']}),
# ('text583.txt', {'Medicamentos': ['tomografia computadorizada']}),
# ('text182.txt', {'Medicamentos': ['rituximabe 500mg']}),
# ('text397.txt', {'Medicamentos': ['cardiaca pediatrica']}),
# ('text195.txt', {'Medicamentos': ['vimizim', 'vimizin', 'vimizim']}),
# ('text293.txt', {'Medicamentos': ['muvinlax']}),
# ('text215.txt', {'Medicamentos': ['ketocal']}),
# ('text330.txt', {'Medicamentos': ['venlafaxina 150mg']}),
# ('text598.txt', {'Medicamentos': ['duloxetina']}),
# ('text205.txt', {'Medicamentos': ['fitas glicemicas']}),
# ('text292.txt', {'Medicamentos': ['fortini']}),
# ('text184.txt', {'Medicamentos': ['espiramicina 500mg']}),
# ('text312.txt', {'Medicamentos': ['dasatinibe']}),
# ('text423.txt', {'Medicamentos': ['losartana']}),
# ('text156.txt', {'Medicamentos': ['enoxaparina']}),
# ('text320.txt', {'Medicamentos': ['zoladez']}),
# ('text362.txt', {'Medicamentos': ['gencitabina']}),
# ('text133.txt', {'Medicamentos': ['avastin (bevacizumabe', 'avastin - bevacizumabe', 'avastin (bevacizumabe']}),
# ('text143.txt', {'Medicamentos': ['pantoprazol']}),
# ('text505.txt', {'Medicamentos': ['enapril 5mg']}),
# ('text86.txt', {'Medicamentos': ['carbamazepina']}),
# ('text164.txt', {'Medicamentos': ['cirurgia de reconstrucao']}),
# ('text225.txt', {'Medicamentos': ['bortezomibe', 'bortezomib ', 'bortezomibe']}),
# ('text262.txt', {'Medicamentos': ['vimizim']}),
# ('text622.txt', {'Medicamentos': ['somatropina']}),
# ('text111.txt', {'Medicamentos': ['cloxazolan']}),
# ('text408.txt', {'Medicamentos': ['xultophy']}),
# ('text231.txt', {'Medicamentos': ['leuprorrelina']}),
# ('text311.txt', {'Medicamentos': ['somatropina']}),
# ('text630.txt', {'Medicamentos': ['mapeamento de retina']}),
# ('text582.txt', {'Medicamentos': ['tomografia computadorizada']}),
# ('text192.txt', {'Medicamentos': ['nivolumab ']}),
# ('text594.txt', {'Medicamentos': ['sirolimu']}),
# ('text403.txt', {'Medicamentos': ['enzalutamida 40mg,']}),
# ('text438.txt', {'Medicamentos': ['laqueadura']}),
# ('text254.txt', {'Medicamentos': ['clobazam']}),
# ('text125.txt', {'Medicamentos': ['esterectomia total']}),
# ('text535.txt', {'Medicamentos': ['catarata']}),
# ('text268.txt', {'Medicamentos': ['aspirador portatil']}),
# ('text151.txt', {'Medicamentos': ['somatropina']}),
# ('text592.txt', {'Medicamentos': ['osteotomia']}),
# ('text639.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text334.txt', {'Medicamentos': ['bevacizumabe 750mg']}),
# ('text314.txt', {'Medicamentos': ['ventilacao nao-invasiva (bipap']}),
# ('text284.txt', {'Medicamentos': ['abiraterona']}),
# ('text510.txt', {'Medicamentos': ['duloxetina']}),
# ('text445.txt', {'Medicamentos': ['rituximab.']}),
# ('text472.txt', {'Medicamentos': ['guincho eletrico freedom']}),
# ('text259.txt', {'Medicamentos': ['bortezomibe']}),
# ('text227.txt', {'Medicamentos': ['secuquinumabe']}),
# ('text646.txt', {'Medicamentos': ['endoscopia digestiva alta']}),
# ('text346.txt', {'Medicamentos': ['avastin']}),
# ('text52.txt', {'Medicamentos': ['fortini']}),
# ('text414.txt', {'Medicamentos': ['luvas', 'luva ', 'luvas']}),
# ('text462.txt', {'Medicamentos': ['ritalina']}),
# ('text256.txt', {'Medicamentos': ['abiraterona']}),
# ('text216.txt', {'Medicamentos': ['rivaroxabana']}),
# ('text339.txt', {'Medicamentos': ['nexavar']}),
# ('text94.txt', {'Medicamentos': ['nivolumab ', 'nivolumabe']}),
# ('text282.txt', {'Medicamentos': ['citrato de tamoxifeno']}),
# ('text620.txt', {'Medicamentos': ['somatropina']}),
# ('text370.txt', {'Medicamentos': ['sildenafila']}),
# ('text380.txt', {'Medicamentos': ['eculizumabe']}),
# ('text57.txt', {'Medicamentos': ['noripurum']}),
# ('text419.txt', {'Medicamentos': ['regorafenibe']}),
# ('text355.txt', {'Medicamentos': ['ultrassonografia']}),
# ('text340.txt', {'Medicamentos': ['paralisia cerebral e autismo']}),
# ('text463.txt', {'Medicamentos': ['cloreto de potassio 10%']}),
# ('text433.txt', {'Medicamentos': ['vascular']}),
# ('text213.txt', {'Medicamentos': ['revascularizacao do membro inferior']}),
# ('text121.txt', {'Medicamentos': ['cardiaca']}),
# ('text218.txt', {'Medicamentos': ['bortezomibe']}),
# ('text439.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text183.txt', {'Medicamentos': ['temozalamida 100 mg']}),
# ('text619.txt', {'Medicamentos': ['vascular']}),
# ('text644.txt', {'Medicamentos': ['ecodopplercardiograma']}),
# ('text601.txt', {'Medicamentos': ['eletroneuromiografia']}),
# ('text290.txt', {'Medicamentos': ['alenia']}),
# ('text299.txt', {'Medicamentos': ['azatioprina 50mg']}),
# ('text568.txt', {'Medicamentos': ['densitometria ossea']}),
# ('text158.txt', {'Medicamentos': ['amitriptilina']}),
# ('text152.txt', {'Medicamentos': ['neocatl']}),
# ('text560.txt', {'Medicamentos': ['neurologica']}),
# ('text508.txt', {'Medicamentos': ['tomografia computadorizada']}),
# ('text142.txt', {'Medicamentos': ['pet-ct']}),
# ('text466.txt', {'Medicamentos': ['cristalino por lio']}),
# ('text48.txt', {'Medicamentos': ['fortini']}),
# ('text375.txt', {'Medicamentos': ['azacitidina 100mg']}),
# ('text586.txt', {'Medicamentos': ['tomografia computadorizada']}),
# ('text531.txt', {'Medicamentos': ['ecg com laudo']}),
# ('text106.txt', {'Medicamentos': ['trastuzumabe']}),
# ('text536.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text530.txt', {'Medicamentos': ['canula de estimulacao']}),
# ('text93.txt', {'Medicamentos': ['mimpara']}),
# ('text135.txt', {'Medicamentos': ['iodo 131']}),
# ('text41.txt', {'Medicamentos': ['pertuzimab (perjeta']}),
# ('text578.txt', {'Medicamentos': ['ecocardiograma']}),
# ('text497.txt', {'Medicamentos': ['bortezomibe']}),
# ('text484.txt', {'Medicamentos': ['transmissor guardian link2']}),
# ('text323.txt', {'Medicamentos': ['trulicity 1,5mg']}),
# ('text294.txt', {'Medicamentos': ['leuprorrelina']}),
# ('text434.txt', {'Medicamentos': ['enzalutamida 40mgr', 'enzalutamida 40mg,']}),
# ('text149.txt', {'Medicamentos': ['renehavis']}),
# ('text570.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text385.txt', {'Medicamentos': ['firazyr']}),
# ('text283.txt', {'Medicamentos': ['lentes de contatos rigidas de desenho']}),
# ('text174.txt', {'Medicamentos': ['oxibutramina 5mg']}),
# ('text204.txt', {'Medicamentos': ['vedolizumabe']}),
# ('text499.txt', {'Medicamentos': ['catarata']}),
# ('text100.txt', {'Medicamentos': ['somatropina']}),
# ('text351.txt', {'Medicamentos': ['ketosteril']}),
# ('text371.txt', {'Medicamentos': ['acido ursodesoxicolico']}),
# ('text542.txt', {'Medicamentos': ['retinografia fluorescente']}),
# ('text200.txt', {'Medicamentos': ['eculizumab ', 'eculizumab.', 'eculizumab ']}),
# ('text476.txt', {'Medicamentos': ['tramadol']}),
# ('text193.txt', {'Medicamentos': ['bortezomibe']}),
# ('text186.txt', {'Medicamentos': ['traumatismo raquimedular - trm']}),
# ('text66.txt', {'Medicamentos': ['gefitinibe (iressa']}),
# ('text406.txt', {'Medicamentos': ['aripiprazol']}),
# ('text584.txt', {'Medicamentos': ['eletroneuromiografia mse']}),
# ('text281.txt', {'Medicamentos': ['ranitidina']}),
# ('text551.txt', {'Medicamentos': ['enzalutamida quando', 'enzalutamida (xtandi', 'enzalutamida radi']}),
# ('text368.txt', {'Medicamentos': ['carvedilol']}),
# ('text155.txt', {'Medicamentos': ['minociclina']}),
# ('text107.txt', {'Medicamentos': ['etoposide']}),
# ('text436.txt', {'Medicamentos': ['vitrectomia']}),
# ('text415.txt', {'Medicamentos': ['tubos de xilocaina em gel']}),
# ('text318.txt', {'Medicamentos': ['cadeira de rodas']}),
# ('text631.txt', {'Medicamentos': ['tomografia de coerencia optica']}),
# ('text190.txt', {'Medicamentos': ['vimizim']}),
# ('text344.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text140.txt', {'Medicamentos': ['maltodextrina']}),
# ('text306.txt', {'Medicamentos': ['lamitor']}),
# ('text467.txt', {'Medicamentos': ['cirurgia ortopedica da coluna vertebral']}),
# ('text67.txt', {'Medicamentos': ['sunitinib 50mg', 'sunitinib 50m ', 'sunitinib 50mg']}),
# ('text267.txt', {'Medicamentos': ['tizanidina 2mg']}),
# ('text576.txt', {'Medicamentos': ['cardiaco']}),
# ('text580.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text487.txt', {'Medicamentos': ['cirurgia bariatrica']}),
# ('text291.txt', {'Medicamentos': ['pregomin pepti']}),
# ('text226.txt', {'Medicamentos': ['sutent 50mg']}),
# ('text128.txt', {'Medicamentos': ['reducao mamaria']}),
# ('text496.txt', {'Medicamentos': ['clofazimina 50mg']}),
# ('text546.txt', {'Medicamentos': ['cintilografia ossea']}),
# ('text412.txt', {'Medicamentos': ['micofenolato de mofetila']}),
# ('text280.txt', {'Medicamentos': ['furosemida']}),
# ('text556.txt', {'Medicamentos': ['fimose']}),
# ('text464.txt', {'Medicamentos': ['fosforo tricalcio']}),
# ('text307.txt', {'Medicamentos': ['oxicarbamazepina']}),
# ('text96.txt', {'Medicamentos': ['neurologica']}),
# ('text270.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text36.txt', {'Medicamentos': ['domperidona 10mg']}),
# ('text353.txt', {'Medicamentos': ['sorafenibe 400mg']}),
# ('text251.txt', {'Medicamentos': ['cabazitaxel']}),
# ('text604.txt', {'Medicamentos': ['campimetria']}),
# ('text539.txt', {'Medicamentos': ['reuquinol']}),
# ('text448.txt', {'Medicamentos': ['pregomin pepti']}),
# ('text451.txt', {'Medicamentos': ['eculizumab ', 'eculizumabe', 'eculizumab ']}),
# ('text502.txt', {'Medicamentos': ['cabozantinibe 60 mg']}),
# ('text116.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text168.txt', {'Medicamentos': ['laqueadura']}),
# ('text422.txt', {'Medicamentos': ['clonazepan']}),
# ('text238.txt', {'Medicamentos': ['prolia 60 mg']}),
# ('text563.txt', {'Medicamentos': ['septoplastia']}),
# ('text275.txt', {'Medicamentos': ['anastrozol']}),
# ('text612.txt', {'Medicamentos': ['angiografia']}),
# ('text76.txt', {'Medicamentos': ['vidaza']}),
# ('text482.txt', {'Medicamentos': ['minimed reservoir 3ml caixa com 10 unidades']}),
# ('text249.txt', {'Medicamentos': ['depura']}),
# ('text444.txt', {'Medicamentos': ['oftalmologica', 'oftalmologico']}),
# ('text627.txt', {'Medicamentos': ['ressonancia magnetica de cranio com contraste']}),
# ('text279.txt', {'Medicamentos': ['somatropina']}),
# ('text561.txt', {'Medicamentos': ['nivolumab - opdivo']}),
# ('text511.txt', {'Medicamentos': ['glucosamina com condroitina']}),
# ('text244.txt', {'Medicamentos': ['prometazina']}),
# ('text593.txt', {'Medicamentos': ['nivolumab (opdivo']}),
# ('text203.txt', {'Medicamentos': ['mimpara 30mg']}),
# ('text426.txt', {'Medicamentos': ['clobazam']}),
# ('text545.txt', {'Medicamentos': ['micofenolato de mofetila 500mg']}),
# ('text562.txt', {'Medicamentos': ['blinatumomabe']}),
# ('text524.txt', {'Medicamentos': ['neozine']}),
# ('text188.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text163.txt', {'Medicamentos': ['durogesic']}),
# ('text376.txt', {'Medicamentos': ['metilfenidato']}),
# ('text503.txt', {'Medicamentos': ['lanreotide 120mg']}),
# ('text641.txt', {'Medicamentos': ['eletroneuromiografia']}),
# ('text197.txt', {'Medicamentos': ['clobazam']}),
# ('text148.txt', {'Medicamentos': ['avastin']}),
# ('text361.txt', {'Medicamentos': ['fascia']}),
# ('text383.txt', {'Medicamentos': ['ribociclibe']}),
# ('text410.txt', {'Medicamentos': ['sutent 50mg']}),
# ('text79.txt', {'Medicamentos': ['azacitidina (vidaza']}),
# ('text393.txt', {'Medicamentos': ['vigabatrina']}),
# ('text621.txt', {'Medicamentos': ['abiraterona']}),
# ('text169.txt', {'Medicamentos': ['hernia discal']}),
# ('text47.txt', {'Medicamentos': ['diazoxido']}),
# ('text166.txt', {'Medicamentos': ['nivolumab']}),
# ('text449.txt', {'Medicamentos': ['pembrolizumabe (keytruda']}),
# ('text537.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text342.txt', {'Medicamentos': ['canabidiol (rs', 'canabidiol ( <', 'canabidiol (rs']}),
# ('text55.txt', {'Medicamentos': ['xarelto 20 mg']}),
# ('text72.txt', {'Medicamentos': ['ribavirina']}),
# ('text303.txt', {'Medicamentos': ['abiraterona']}),
# ('text263.txt', {'Medicamentos': ['rituximab ', 'rituximabe', 'rituximab ', 'rituximabe', 'rituximab ']}),
# ('text154.txt', {'Medicamentos': ['infrantini']}),
# ('text520.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text490.txt', {'Medicamentos': ['aplasia medular']}),
# ('text366.txt', {'Medicamentos': ['fortini']}),
# ('text447.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text285.txt', {'Medicamentos': ['thyrogen']}),
# ('text489.txt', {'Medicamentos': ['ultrassonografia']}),
# ('text235.txt', {'Medicamentos': ['quelatus']}),
# ('text146.txt', {'Medicamentos': ['ritalina']}),
# ('text331.txt', {'Medicamentos': ['abiraterona 250mg']}),
# ('text44.txt', {'Medicamentos': ['coloplast']}),
# ('text84.txt', {'Medicamentos': ['fabrazyme']}),
# ('text579.txt', {'Medicamentos': ['ressonancia magnetica de coluna lombo-sacra sem contraste']}),
# ('text636.txt', {'Medicamentos': ['ressonancia magnetica do joelho']}),
# ('text409.txt', {'Medicamentos': ['spinraza (nusinersen']}),
# ('text477.txt', {'Medicamentos': ['temozolomida']}),
# ('text525.txt', {'Medicamentos': ['fraldas geriatricas']}),
# ('text329.txt', {'Medicamentos': ['abiraterona 250mg']}),
# ('text60.txt', {'Medicamentos': ['avastin (bevacizumabe']}),
# ('text196.txt', {'Medicamentos': ['insulina glargina (lantus']}),
# ('text533.txt', {'Medicamentos': ['ecocardiograma transtoracico']}),
# ('text69.txt', {'Medicamentos': ['dorene']}),
# ('text632.txt', {'Medicamentos': ['lucentis']}),
# ('text513.txt', {'Medicamentos': ['depakote']}),
# ('text465.txt', {'Medicamentos': ['enzalutamida 40mg ', 'enzalutamida 40mg,']}),
# ('text104.txt', {'Medicamentos': ['clexane']}),
# ('text564.txt', {'Medicamentos': ['epres']}),
# ('text115.txt', {'Medicamentos': ['avastin']}),
# ('text633.txt', {'Medicamentos': ['ressonancia magnetica de coluna lombo-sacra']}),
# ('text162.txt', {'Medicamentos': ['ortopedica']}),
# ('text602.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text77.txt', {'Medicamentos': ['ortopedica']}),
# ('text541.txt', {'Medicamentos': ['retinografia ao']}),
# ('text428.txt', {'Medicamentos': ['temodal']}),
# ('text532.txt', {'Medicamentos': ['lucentis']}),
# ('text112.txt', {'Medicamentos': ['mitarzapina 30mg']}),
# ('text271.txt', {'Medicamentos': ['enzalutamida 40mgm']}),
# ('text523.txt', {'Medicamentos': ['pregabalina']}),
# ('text145.txt', {'Medicamentos': ['micofenolato de mofetil']}),
# ('text618.txt', {'Medicamentos': ['protese modular para amputacao transfemoral']}),
# ('text420.txt', {'Medicamentos': ['palbociclibe']}),
# ('text453.txt', {'Medicamentos': ['minociclina']}),
# ('text391.txt', {'Medicamentos': ['aripiprazol']}),
# ('text241.txt', {'Medicamentos': ['ecoendoscopia baixa']}),
# ('text170.txt', {'Medicamentos': ['cadeira de rodas']}),
# ('text554.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text124.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text228.txt', {'Medicamentos': ['aristale 10mg']}),
# ('text544.txt', {'Medicamentos': ['venlafaxina']}),
# ('text101.txt', {'Medicamentos': ['cinacalcete 30mg']}),
# ('text468.txt', {'Medicamentos': ['microfenolato de mofetila']}),
# ('text421.txt', {'Medicamentos': ['ganciclovir 250mg']}),
# ('text269.txt', {'Medicamentos': ['temodal']}),
# ('text418.txt', {'Medicamentos': ['octreotida lar 30mg']}),
# ('text437.txt', {'Medicamentos': ['leuprorrelina 3,75mg']}),
# ('text377.txt', {'Medicamentos': ['sofosbuvir 400mg']}),
# ('text321.txt', {'Medicamentos': ['bevacizumabe']}),
# ('text319.txt', {'Medicamentos': ['somatropina']}),
# ('text367.txt', {'Medicamentos': ['vitrectomia']}),
# ('text384.txt', {'Medicamentos': ['temozolomida']}),
# ('text402.txt', {'Medicamentos': ['procarbazina']}),
# ('text643.txt', {'Medicamentos': ['adalimumabe 40mg']}),
# ('text248.txt', {'Medicamentos': ['somatropina']}),
# ('text566.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text638.txt', {'Medicamentos': ['polissonografia']}),
# ('text243.txt', {'Medicamentos': ['bolsas coletoras']}),
# ('text92.txt', {'Medicamentos': ['enoxaparina']}),
# ('text211.txt', {'Medicamentos': ['ofloxacina 400mg']}),
# ('text424.txt', {'Medicamentos': ['selozok']}),
# ('text492.txt', {'Medicamentos': ['deferiprona']}),
# ('text358.txt', {'Medicamentos': ['timolol']}),
# ('text181.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text369.txt', {'Medicamentos': ['procoralan 7,5mg']}),
# ('text202.txt', {'Medicamentos': ['azatioprina 50mg']}),
# ('text103.txt', {'Medicamentos': ['pregomin pepti']}),
# ('text647.txt', {'Medicamentos': ['toujeo']}),
# ('text68.txt', {'Medicamentos': ['vesomne']}),
# ('text313.txt', {'Medicamentos': ['octreotida lar 30mg']}),
# ('text572.txt', {'Medicamentos': ['brentuximabe - vedotin']}),
# ('text40.txt', {'Medicamentos': ['fluorouracil']}),
# ('text360.txt', {'Medicamentos': ['ureterorrenolitotripsia']}),
# ('text590.txt', {'Medicamentos': ['otoneurologico']}),
# ('text558.txt', {'Medicamentos': ['cateter duplo j']}),
# ('text549.txt', {'Medicamentos': ['ressonancia magnetica de cranio']}),
# ('text389.txt', {'Medicamentos': ['forteo']}),
# ('text289.txt', {'Medicamentos': ['ortopedica', 'ortopedico', 'ortopedica', 'ortopedico', 'ortopedica']}),
# ('text611.txt', {'Medicamentos': ['ressonancia magnetica']}),
# ('text642.txt', {'Medicamentos': ['ressonancia magnetica de coluna lombo-sacra']}),
# ('text144.txt', {'Medicamentos': ['teriparatida 250 mc']}),
# ('text78.txt', {'Medicamentos': ['fabrazyme']}),
# ('text160.txt', {'Medicamentos': ['miogama']}),
# ('text483.txt', {'Medicamentos': ['sistema minimed 640g']}),
# ('text441.txt', {'Medicamentos': ['enoxieparina']}),
# ('text388.txt', {'Medicamentos': ['pediasure']}),
# ('text458.txt', {'Medicamentos': ['bevacizumab ']}),
# ('text507.txt', {'Medicamentos': ['ginecologica']}),
# ('text224.txt', {'Medicamentos': ['trastuzumabe']}),
# ('text161.txt', {'Medicamentos': ['aripiprazol']}),
# ('text504.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text610.txt', {'Medicamentos': ['tomografia computadorizada do torax']}),
# ('text615.txt', {'Medicamentos': ['ioban']}),
# ('text398.txt', {'Medicamentos': ['leuprorrelina 3,75mg']}),
# ('text176.txt', {'Medicamentos': ['endoscopia digestiva']}),
# ('text363.txt', {'Medicamentos': ['sorafenibe 400mg']}),
# ('text469.txt', {'Medicamentos': ['pancreatina']}),
# ('text624.txt', {'Medicamentos': ['hernioplastia']}),
# ('text470.txt', {'Medicamentos': ['amantadina 100mg']}),
# ('text478.txt', {'Medicamentos': ['concardio']}),
# ('text585.txt', {'Medicamentos': ['holter']}),
# ('text242.txt', {'Medicamentos': ['lectrum']}),
# ('text352.txt', {'Medicamentos': ['teriparatida 250 mc']}),
# ('text555.txt', {'Medicamentos': ['catarata']}),
# ('text257.txt', {'Medicamentos': ['cinacalcete 30mg']}),
# ('text123.txt', {'Medicamentos': ['opdivo']}),
# ('text206.txt', {'Medicamentos': ['teste de inclinacao ortostatica']}),
# ('text392.txt', {'Medicamentos': ['denosumabe 1amp sc']}),
# ('text260.txt', {'Medicamentos': ['duloxetina']}),
# ('text374.txt', {'Medicamentos': ['insulina lantus']}),
# ('text88.txt', {'Medicamentos': ['temozolamida 250mg']}),
# ('text473.txt', {'Medicamentos': ['usg doppler de arterias carotidas e vertebrais']}),
# ('text587.txt', {'Medicamentos': ['adenoidectomia']}),
# ('text461.txt', {'Medicamentos': ['cadeira de rodas']}),
# ('text471.txt', {'Medicamentos': ['enzalutamida 40mgi']}),
# ('text326.txt', {'Medicamentos': ['forteo']}),
# ('text512.txt', {'Medicamentos': ['brentuximabe vedotin']}),
# ('text607.txt', {'Medicamentos': ['retinografia']}),
# ('text109.txt', {'Medicamentos': ['somatropina']}),
# ('text98.txt', {'Medicamentos': ['temozolamida']}),
# ('text399.txt', {'Medicamentos': ['clobazam']}),
# ('text51.txt', {'Medicamentos': ['tramadon']}),
# ('text395.txt', {'Medicamentos': ['ribavirina']}),
# ('text606.txt', {'Medicamentos': ['paquimetria']}),
# ('text337.txt', {'Medicamentos': ['doxazosina 2mg']}),
# ('text110.txt', {'Medicamentos': ['fludarabina']}),
# ('text171.txt', {'Medicamentos': ['bortezomibe']}),
# ('text600.txt', {'Medicamentos': ['queatipina']}),
# ('text454.txt', {'Medicamentos': ['galvus 50mg']}),
# ('text557.txt', {'Medicamentos': ['tomografia computadorizada']}),
# ('text189.txt', {'Medicamentos': ['abiraterone 250mg']}),
# ('text635.txt', {'Medicamentos': ['endoscopia digestiva alta']}),
# ('text132.txt', {'Medicamentos': ['pertuzumabe']}),
# ('text474.txt', {'Medicamentos': ['temozolamida']}),
# ('text297.txt', {'Medicamentos': ['bevacizumab)', 'bevacizumabe', 'bevacizumab)']}),
# ('text591.txt', {'Medicamentos': ['pregomin pepti']}),
# ('text223.txt', {'Medicamentos': ['ustequinumabe  ( stelara']}),
# ('text430.txt', {'Medicamentos': ['brometo de tiotropio']}),
# ('text167.txt', {'Medicamentos': ['colangiopancreatografia retrograda endoscopica ( <per']}),
# ('text185.txt', {'Medicamentos': ['somatropina 12 ui']}),
# ('text459.txt', {'Medicamentos': ['synolis v- ']}),
# ('text234.txt', {'Medicamentos': ['provance']}),
# ('text265.txt', {'Medicamentos': ['baclofeno']}),
# ('text387.txt', {'Medicamentos': ['cadeira de rodas']}),
# ('text221.txt', {'Medicamentos': ['voriconazol']}),
# ('text99.txt', {'Medicamentos': ['leuprorrelina 3,75mg']}),
# ('text212.txt', {'Medicamentos': ['endoscopia digestiva alta com pesquisa h-pylori']}),
# ('text232.txt', {'Medicamentos': ['octreotida lar 30mg']}),
# ('text277.txt', {'Medicamentos': ['bevacizumab ', 'bevacizumabe', 'bevacizumabr', 'bevacizumab,', 'bevacizumab ']}),
# ('text460.txt', {'Medicamentos': ['micofenolato de mofetil']}),
# ('text272.txt', {'Medicamentos': ['cinacalcete 30mg']}),
# ('text129.txt', {'Medicamentos': ['novasource senior']}),
# ('text626.txt', {'Medicamentos': ['clozapina']}),
# ('text130.txt', {'Medicamentos': ['aristraz 15 mg']}),
# ('text652.txt', {'Medicamentos': ['ribociclibe']}),
# ('text649.txt', {'Medicamentos': ['ecocardiografia transtoracica']}),
# ('text648.txt', {'Medicamentos': ['cdc', 'cdi', 'cdc', 'cd ', 'cdc']}),
# ('text650.txt', {'Medicamentos': ['vitrectomia posterior via pars plana']}),
# ('text4.txt', {'Medicamentos': ['azacitidina']}),
# ('text6.txt', {'Medicamentos': ['denosumabe 60mg']})

# %%
#dividir os textos
train_data2=[]
for i in range(len(train_data)):
  sentencas=list(preparaTexto(train_data[i][0]))
  
  for j in sentencas:
    
    for k in (nomeDosMedicamentos[i][1].get("Medicamentos")):
      indices=list([])
      if k in j:
        print(k)
        # nEntPars.append((int(z[0]),int(z[1]),"Item"))
        #train_data.append((textoTxt,{'entities':list(nEntPars)}))
        indices.append((int(j.index(k)),int(j.index(k))+len(k),"Item"))
        print(indices,end=" ->")
        print(j[(int(j.index(k))):(int(j.index(k)))+len(k)])
        train_data2.append((j,{'entities':list(indices)}))   
        
      else:
        #print("nome não encontrado na sentenca")
        continue
       
print(len(train_data2))
# Out:
# beclometasona
# [(174, 187, 'Item')] ->beclometasona
# ofev 150mg
# [(502, 513, 'Item')] ->ofev 150mg
# ressonancia magnetica de cranio com contraste e sedacao
# [(188, 243, 'Item')] ->ressonancia magnetica de cranio com contraste e sedacao
# ressonancia magnetica de cranio com contraste e sedacao
# [(109, 164, 'Item')] ->ressonancia magnetica de cranio com contraste e sedacao
# ressonancia magnetica de cranio com contraste e sedacao
# [(80, 135, 'Item')] ->ressonancia magnetica de cranio com contraste e sedacao
# somatropina 12 ui
# [(522, 539, 'Item')] ->somatropina 12 ui
# somatropina 12 ui
# [(376, 393, 'Item')] ->somatropina 12 ui
# somatropina 12 ui
# [(389, 406, 'Item')] ->somatropina 12 ui
# pertuzumabe
# [(662, 673, 'Item')] ->pertuzumabe
# pertuzumabe
# [(177, 188, 'Item')] ->pertuzumabe
# pertuzumabe
# [(183, 194, 'Item')] ->pertuzumabe
# temozolomida
# [(883, 895, 'Item')] ->temozolomida
# temozolomida
# [(355, 367, 'Item')] ->temozolomida
# temozolomida
# [(105, 117, 'Item')] ->temozolomida
# cadeira de rodas
# [(310, 326, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(527, 543, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(136, 152, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(34, 50, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(1295, 1311, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(418, 434, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(324, 340, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(140, 156, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(267, 283, 'Item')] ->cadeira de rodas
# ritalina
# [(146, 154, 'Item')] ->ritalina
# ritalina
# [(115, 123, 'Item')] ->ritalina
# ritalina
# [(362, 370, 'Item')] ->ritalina
# ressonancia magnetica de cranio com contraste e sedacao
# [(299, 354, 'Item')] ->ressonancia magnetica de cranio com contraste e sedacao
# ressonancia magnetica de cranio com contraste e sedacao
# [(185, 240, 'Item')] ->ressonancia magnetica de cranio com contraste e sedacao
# xeralto 20 mg
# [(909, 922, 'Item')] ->xeralto 20 mg
# fabrazyme
# [(162, 171, 'Item')] ->fabrazyme
# fabrazyme
# [(312, 321, 'Item')] ->fabrazyme
# fabrazyme
# [(336, 345, 'Item')] ->fabrazyme
# fabrazyme
# [(297, 306, 'Item')] ->fabrazyme
# fabrazyme
# [(60, 69, 'Item')] ->fabrazyme
# fabrazyme
# [(149, 158, 'Item')] ->fabrazyme
# fabrazyme
# [(138, 147, 'Item')] ->fabrazyme
# fabrazyme
# [(264, 273, 'Item')] ->fabrazyme
# fabrazyme
# [(262, 271, 'Item')] ->fabrazyme
# lucentis
# [(78, 86, 'Item')] ->lucentis
# lucentis
# [(121, 129, 'Item')] ->lucentis
# lucentis
# [(50, 58, 'Item')] ->lucentis
# lucentis
# [(164, 172, 'Item')] ->lucentis
# lucentis
# [(178, 186, 'Item')] ->lucentis
# lucentis
# [(440, 448, 'Item')] ->lucentis
# cardiaca
# [(159, 167, 'Item')] ->cardiaca
# cardiaca
# [(716, 724, 'Item')] ->cardiaca
# infliximabe
# [(411, 422, 'Item')] ->infliximabe
# infliximabe
# [(13, 24, 'Item')] ->infliximabe
# infliximabe
# [(14, 25, 'Item')] ->infliximabe
# infliximab)
# [(31, 42, 'Item')] ->infliximab)
# oxibutinina
# [(0, 11, 'Item')] ->oxibutinina
# oxibutinina
# [(0, 11, 'Item')] ->oxibutinina
# rivaroxabana
# [(196, 208, 'Item')] ->rivaroxabana
# rivaroxabana
# [(119, 131, 'Item')] ->rivaroxabana
# nivolumabe
# [(81, 91, 'Item')] ->nivolumabe
# tiotropio
# [(98, 107, 'Item')] ->tiotropio
# tiotropio
# [(215, 224, 'Item')] ->tiotropio
# tiotropio
# [(140, 149, 'Item')] ->tiotropio
# rituximabe
# [(153, 163, 'Item')] ->rituximabe
# neocate
# [(550, 557, 'Item')] ->neocate
# neocate
# [(593, 600, 'Item')] ->neocate
# alenia
# [(82, 88, 'Item')] ->alenia
# pregomin
# [(356, 364, 'Item')] ->pregomin
# pregomin
# [(200, 208, 'Item')] ->pregomin
# enlite sensor - caixa com 5 unidades
# [(692, 728, 'Item')] ->enlite sensor - caixa com 5 unidades
# benicar 20mg
# [(803, 815, 'Item')] ->benicar 20mg
# benicar 20mg
# [(102, 114, 'Item')] ->benicar 20mg
# brentuximabe 50 mg
# [(143, 161, 'Item')] ->brentuximabe 50 mg
# aparelho optico
# [(292, 307, 'Item')] ->aparelho optico
# aparelho optico
# [(634, 649, 'Item')] ->aparelho optico
# aparelho optico
# [(434, 449, 'Item')] ->aparelho optico
# colonoscopia
# [(292, 304, 'Item')] ->colonoscopia
# colonoscopia
# [(427, 439, 'Item')] ->colonoscopia
# colonoscopia
# [(33, 45, 'Item')] ->colonoscopia
# colonoscopia
# [(60, 72, 'Item')] ->colonoscopia
# colonoscopia
# [(217, 229, 'Item')] ->colonoscopia
# colonoscopia
# [(335, 347, 'Item')] ->colonoscopia
# ressonancia magnetica
# [(133, 154, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(115, 136, 'Item')] ->ressonancia magnetica
# lenvatinibe (lenvima
# [(317, 337, 'Item')] ->lenvatinibe (lenvima
# cardiaca
# [(325, 333, 'Item')] ->cardiaca
# cardiaca
# [(325, 333, 'Item')] ->cardiaca
# cardiaca
# [(848, 856, 'Item')] ->cardiaca
# cardiaca
# [(848, 856, 'Item')] ->cardiaca
# cardiaca
# [(378, 386, 'Item')] ->cardiaca
# cardiaco
# [(188, 196, 'Item')] ->cardiaco
# cardiaca
# [(378, 386, 'Item')] ->cardiaca
# cardiaca
# [(247, 255, 'Item')] ->cardiaca
# cardiaca
# [(247, 255, 'Item')] ->cardiaca
# cardiaca
# [(350, 358, 'Item')] ->cardiaca
# cardiaca
# [(350, 358, 'Item')] ->cardiaca
# cardiaca
# [(749, 757, 'Item')] ->cardiaca
# cardiaca
# [(749, 757, 'Item')] ->cardiaca
# tiotropio
# [(116, 125, 'Item')] ->tiotropio
# tiotropio
# [(312, 321, 'Item')] ->tiotropio
# tiotropio
# [(115, 124, 'Item')] ->tiotropio
# acitretina 10mg
# [(492, 507, 'Item')] ->acitretina 10mg
# acitretina 10mg
# [(242, 257, 'Item')] ->acitretina 10mg
# acitretina 10mg
# [(165, 180, 'Item')] ->acitretina 10mg
# fludarabina
# [(102, 113, 'Item')] ->fludarabina
# ressonancia magnetica
# [(189, 210, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(409, 430, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(155, 176, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(2, 23, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(19, 40, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(15, 36, 'Item')] ->ressonancia magnetica
# ressonancia magnetica de ombro esquerdo
# [(102, 141, 'Item')] ->ressonancia magnetica de ombro esquerdo
# ressonancia magnetica de ombro esquerdo
# [(72, 111, 'Item')] ->ressonancia magnetica de ombro esquerdo
# ressonancia magnetica de ombro esquerdo
# [(189, 228, 'Item')] ->ressonancia magnetica de ombro esquerdo
# ressonancia magnetica
# [(185, 206, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(114, 135, 'Item')] ->ressonancia magnetica
# alenia
# [(116, 122, 'Item')] ->alenia
# pediasure
# [(346, 355, 'Item')] ->pediasure
# pediasure
# [(247, 256, 'Item')] ->pediasure
# pediasure
# [(427, 436, 'Item')] ->pediasure
# dna
# [(137, 140, 'Item')] ->dna
# dna
# [(137, 140, 'Item')] ->dna
# dna
# [(137, 140, 'Item')] ->dna
# dna
# [(517, 520, 'Item')] ->dna
# dna
# [(517, 520, 'Item')] ->dna
# dna
# [(517, 520, 'Item')] ->dna
# anagrelide
# [(45, 55, 'Item')] ->anagrelide
# anagrelide
# [(476, 486, 'Item')] ->anagrelide
# infliximabe
# [(65, 76, 'Item')] ->infliximabe
# infliximabe
# [(57, 68, 'Item')] ->infliximabe
# infliximabe
# [(22, 33, 'Item')] ->infliximabe
# bleomicina
# [(308, 318, 'Item')] ->bleomicina
# abiraterona
# [(308, 319, 'Item')] ->abiraterona
# abiraterona
# [(55, 66, 'Item')] ->abiraterona
# abiraterona
# [(1244, 1255, 'Item')] ->abiraterona
# abiraterona
# [(586, 597, 'Item')] ->abiraterona
# spiriva
# [(370, 377, 'Item')] ->spiriva
# spiriva
# [(198, 205, 'Item')] ->spiriva
# rituximabe
# [(55, 65, 'Item')] ->rituximabe
# ranibizumabe
# [(143, 155, 'Item')] ->ranibizumabe
# ranibizumabe
# [(143, 155, 'Item')] ->ranibizumabe
# ranibizumabe
# [(78, 90, 'Item')] ->ranibizumabe
# ranibizumabe
# [(78, 90, 'Item')] ->ranibizumabe
# ranibizumab
# [(365, 377, 'Item')] ->ranibizumab
# ranibizumab
# [(365, 377, 'Item')] ->ranibizumab
# ranibizumabe
# [(1, 13, 'Item')] ->ranibizumabe
# ranibizumabe
# [(1, 13, 'Item')] ->ranibizumabe
# ranibizumabe
# [(124, 136, 'Item')] ->ranibizumabe
# ranibizumabe
# [(124, 136, 'Item')] ->ranibizumabe
# ranibizumabe
# [(184, 196, 'Item')] ->ranibizumabe
# ranibizumabe
# [(184, 196, 'Item')] ->ranibizumabe
# ranibizumab
# [(121, 133, 'Item')] ->ranibizumab
# ranibizumab
# [(121, 133, 'Item')] ->ranibizumab
# ranibizumab
# [(191, 203, 'Item')] ->ranibizumab
# ranibizumab
# [(191, 203, 'Item')] ->ranibizumab
# alenia
# [(1126, 1132, 'Item')] ->alenia
# alenia
# [(305, 311, 'Item')] ->alenia
# alenia
# [(76, 82, 'Item')] ->alenia
# alenia
# [(354, 360, 'Item')] ->alenia
# alenia
# [(719, 725, 'Item')] ->alenia
# ultrassonografia
# [(110, 126, 'Item')] ->ultrassonografia
# ultrassonografia
# [(222, 238, 'Item')] ->ultrassonografia
# ultrassonografia
# [(152, 168, 'Item')] ->ultrassonografia
# pomada ilex
# [(357, 368, 'Item')] ->pomada ilex
# pomada ilex
# [(162, 173, 'Item')] ->pomada ilex
# pomada ilex
# [(245, 256, 'Item')] ->pomada ilex
# pomada ilex
# [(317, 328, 'Item')] ->pomada ilex
# pomada ilex
# [(215, 226, 'Item')] ->pomada ilex
# pomada ilex
# [(185, 196, 'Item')] ->pomada ilex
# histeroscopia diagnostica
# [(354, 379, 'Item')] ->histeroscopia diagnostica
# histeroscopia diagnostica
# [(187, 212, 'Item')] ->histeroscopia diagnostica
# abiraterona
# [(95, 106, 'Item')] ->abiraterona
# pertuzumabe
# [(680, 691, 'Item')] ->pertuzumabe
# pertuzumabe
# [(39, 50, 'Item')] ->pertuzumabe
# pertuzumabe
# [(22, 33, 'Item')] ->pertuzumabe
# pertuzumabe
# [(117, 128, 'Item')] ->pertuzumabe
# ressonancia magnetica
# [(193, 214, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(115, 136, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(60, 81, 'Item')] ->ressonancia magnetica
# zytiga (abiraterona) 250mg
# [(58, 84, 'Item')] ->zytiga (abiraterona) 250mg
# zytiga (abiraterona) 250mg
# [(100, 126, 'Item')] ->zytiga (abiraterona) 250mg
# keppra 750mg
# [(168, 180, 'Item')] ->keppra 750mg
# vesicula biliar
# [(61, 76, 'Item')] ->vesicula biliar
# aripiprazol
# [(1517, 1528, 'Item')] ->aripiprazol
# temodal
# [(449, 456, 'Item')] ->temodal
# temodal
# [(266, 273, 'Item')] ->temodal
# enoxaparina 40mg,
# [(331, 348, 'Item')] ->enoxaparina 40mg,
# enoxaparina 40mg,
# [(118, 135, 'Item')] ->enoxaparina 40mg,
# enoxaparina 40mg,
# [(203, 220, 'Item')] ->enoxaparina 40mg,
# enoxaparina 40mg,
# [(153, 170, 'Item')] ->enoxaparina 40mg,
# bleomicina
# [(186, 196, 'Item')] ->bleomicina
# bleomicina
# [(186, 196, 'Item')] ->bleomicina
# aplicador do sensor enlite (one press serter
# [(512, 556, 'Item')] ->aplicador do sensor enlite (one press serter
# eletroneuromiografia
# [(114, 134, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(49, 69, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(191, 211, 'Item')] ->eletroneuromiografia
# escitalopram 20 mg
# [(186, 204, 'Item')] ->escitalopram 20 mg
# escitalopram 20 mg
# [(663, 681, 'Item')] ->escitalopram 20 mg
# escitalopram 20 mg
# [(366, 384, 'Item')] ->escitalopram 20 mg
# cystagon
# [(252, 260, 'Item')] ->cystagon
# cystagon
# [(14, 22, 'Item')] ->cystagon
# cystagon
# [(60, 68, 'Item')] ->cystagon
# pregomin pepti
# [(225, 239, 'Item')] ->pregomin pepti
# bortezomib
# [(397, 408, 'Item')] ->bortezomib
# bortezomib
# [(397, 408, 'Item')] ->bortezomib
# bortezomib
# [(397, 408, 'Item')] ->bortezomib
# bortezomibq
# [(495, 506, 'Item')] ->bortezomibq
# bortezomib
# [(192, 203, 'Item')] ->bortezomib
# bortezomib
# [(192, 203, 'Item')] ->bortezomib
# bortezomib
# [(192, 203, 'Item')] ->bortezomib
# bortezomibr
# [(295, 306, 'Item')] ->bortezomibr
# bortezomib
# [(573, 584, 'Item')] ->bortezomib
# bortezomib
# [(573, 584, 'Item')] ->bortezomib
# bortezomib
# [(573, 584, 'Item')] ->bortezomib
# bortezomib
# [(323, 334, 'Item')] ->bortezomib
# bortezomib
# [(323, 334, 'Item')] ->bortezomib
# bortezomib
# [(323, 334, 'Item')] ->bortezomib
# clenia
# [(924, 930, 'Item')] ->clenia
# clenil
# [(782, 788, 'Item')] ->clenil
# pediasure
# [(515, 524, 'Item')] ->pediasure
# pediasure
# [(133, 142, 'Item')] ->pediasure
# pediasure
# [(123, 132, 'Item')] ->pediasure
# pediasure
# [(473, 482, 'Item')] ->pediasure
# pediasure
# [(8, 17, 'Item')] ->pediasure
# pediasure
# [(72, 81, 'Item')] ->pediasure
# pediasure
# [(254, 263, 'Item')] ->pediasure
# biotina
# [(277, 284, 'Item')] ->biotina
# biotina
# [(183, 190, 'Item')] ->biotina
# biotina
# [(326, 333, 'Item')] ->biotina
# carvedilol
# [(98, 108, 'Item')] ->carvedilol
# carvedilol
# [(3589, 3599, 'Item')] ->carvedilol
# carvedilol
# [(736, 746, 'Item')] ->carvedilol
# noripurum
# [(329, 338, 'Item')] ->noripurum
# noripurum
# [(45, 54, 'Item')] ->noripurum
# noripurum
# [(245, 254, 'Item')] ->noripurum
# noripurum
# [(309, 318, 'Item')] ->noripurum
# pertuzumabe
# [(111, 122, 'Item')] ->pertuzumabe
# pertuzumabe
# [(482, 493, 'Item')] ->pertuzumabe
# alentuzumab,
# [(68, 80, 'Item')] ->alentuzumab,
# alentuzumab,
# [(69, 81, 'Item')] ->alentuzumab,
# metotrexado
# [(65, 76, 'Item')] ->metotrexado
# metotrexado
# [(206, 217, 'Item')] ->metotrexado
# clexane
# [(607, 614, 'Item')] ->clexane
# transamin 250mg
# [(650, 665, 'Item')] ->transamin 250mg
# somatropina 12 ui
# [(253, 270, 'Item')] ->somatropina 12 ui
# somatropina 12 ui
# [(2, 19, 'Item')] ->somatropina 12 ui
# somatropina 12 ui
# [(137, 154, 'Item')] ->somatropina 12 ui
# gardenal
# [(21, 29, 'Item')] ->gardenal
# gardenal
# [(145, 153, 'Item')] ->gardenal
# somatropina
# [(427, 438, 'Item')] ->somatropina
# somatropina
# [(162, 173, 'Item')] ->somatropina
# somatropina
# [(412, 423, 'Item')] ->somatropina
# somatropina
# [(96, 107, 'Item')] ->somatropina
# somatropina
# [(86, 97, 'Item')] ->somatropina
# somatropina
# [(54, 65, 'Item')] ->somatropina
# prostatectomia
# [(57, 71, 'Item')] ->prostatectomia
# prostatectomia
# [(131, 145, 'Item')] ->prostatectomia
# prostatectomia
# [(37, 51, 'Item')] ->prostatectomia
# prostatectomia
# [(383, 397, 'Item')] ->prostatectomia
# prostatectomia
# [(57, 71, 'Item')] ->prostatectomia
# prostatectomia
# [(137, 151, 'Item')] ->prostatectomia
# prostatectomia
# [(42, 56, 'Item')] ->prostatectomia
# prostatectomia
# [(21, 35, 'Item')] ->prostatectomia
# prostatectomia
# [(40, 54, 'Item')] ->prostatectomia
# prostatectomia
# [(20, 34, 'Item')] ->prostatectomia
# prostatectomia
# [(81, 95, 'Item')] ->prostatectomia
# prostatectomia
# [(50, 64, 'Item')] ->prostatectomia
# ranitidina
# [(681, 691, 'Item')] ->ranitidina
# ranitidina
# [(672, 682, 'Item')] ->ranitidina
# palbociclibe (ibranc
# [(155, 175, 'Item')] ->palbociclibe (ibranc
# palbociclibe (ibranc
# [(185, 205, 'Item')] ->palbociclibe (ibranc
# palbociclibe (ibranc
# [(154, 174, 'Item')] ->palbociclibe (ibranc
# palbociclibe (ibranc
# [(184, 204, 'Item')] ->palbociclibe (ibranc
# centrum
# [(240, 247, 'Item')] ->centrum
# fortini
# [(319, 326, 'Item')] ->fortini
# uretrotomia interna
# [(77, 96, 'Item')] ->uretrotomia interna
# ressonancia magnetica
# [(596, 617, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(71, 92, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(182, 203, 'Item')] ->ressonancia magnetica
# corticoide inalatorio
# [(686, 707, 'Item')] ->corticoide inalatorio
# sorafenibe
# [(171, 181, 'Item')] ->sorafenibe
# sorafenibe
# [(15, 25, 'Item')] ->sorafenibe
# sorafenibe
# [(41, 51, 'Item')] ->sorafenibe
# sorafenibe
# [(41, 51, 'Item')] ->sorafenibe
# duloxetina
# [(961, 971, 'Item')] ->duloxetina
# duloxetina
# [(167, 177, 'Item')] ->duloxetina
# amato
# [(741, 746, 'Item')] ->amato
# amato
# [(231, 236, 'Item')] ->amato
# amato
# [(110, 115, 'Item')] ->amato
# amato
# [(64, 69, 'Item')] ->amato
# amato
# [(188, 193, 'Item')] ->amato
# venetoclax
# [(147, 157, 'Item')] ->venetoclax
# venetoclax
# [(275, 285, 'Item')] ->venetoclax
# pertuzumabe
# [(277, 288, 'Item')] ->pertuzumabe
# pertuzumabe
# [(263, 274, 'Item')] ->pertuzumabe
# imantinibe 400mg
# [(75, 91, 'Item')] ->imantinibe 400mg
# imantinibe 400mg
# [(59, 75, 'Item')] ->imantinibe 400mg
# brentuximabe vedotin
# [(479, 499, 'Item')] ->brentuximabe vedotin
# laqueadura
# [(378, 388, 'Item')] ->laqueadura
# laqueadura
# [(126, 136, 'Item')] ->laqueadura
# laqueadura
# [(243, 253, 'Item')] ->laqueadura
# laqueadura
# [(379, 389, 'Item')] ->laqueadura
# jakavi
# [(596, 602, 'Item')] ->jakavi
# mielograma
# [(132, 142, 'Item')] ->mielograma
# mielograma
# [(370, 380, 'Item')] ->mielograma
# mielograma
# [(214, 224, 'Item')] ->mielograma
# mielograma
# [(150, 160, 'Item')] ->mielograma
# tadalafil 5mg
# [(179, 192, 'Item')] ->tadalafil 5mg
# xarelto
# [(357, 364, 'Item')] ->xarelto
# pertuzumabe
# [(800, 811, 'Item')] ->pertuzumabe
# pertuzumabe
# [(800, 811, 'Item')] ->pertuzumabe
# pertuzumabe
# [(208, 219, 'Item')] ->pertuzumabe
# pertuzumabe
# [(208, 219, 'Item')] ->pertuzumabe
# pertuzumabe
# [(42, 53, 'Item')] ->pertuzumabe
# pertuzumabe
# [(42, 53, 'Item')] ->pertuzumabe
# pertuzumab,
# [(146, 157, 'Item')] ->pertuzumab,
# pertuzumabe
# [(386, 397, 'Item')] ->pertuzumabe
# pertuzumabe
# [(386, 397, 'Item')] ->pertuzumabe
# pertuzumabe
# [(538, 549, 'Item')] ->pertuzumabe
# pertuzumabe
# [(538, 549, 'Item')] ->pertuzumabe
# pertuzumabe
# [(641, 652, 'Item')] ->pertuzumabe
# pertuzumabe
# [(641, 652, 'Item')] ->pertuzumabe
# tomografia
# [(120, 130, 'Item')] ->tomografia
# azacitidina
# [(528, 539, 'Item')] ->azacitidina
# azacitidina
# [(130, 141, 'Item')] ->azacitidina
# neocate
# [(260, 267, 'Item')] ->neocate
# ansitec
# [(206, 213, 'Item')] ->ansitec
# temozolamida
# [(171, 183, 'Item')] ->temozolamida
# temozolamida
# [(0, 12, 'Item')] ->temozolamida
# temozolamida
# [(557, 569, 'Item')] ->temozolamida
# temozolamida
# [(301, 313, 'Item')] ->temozolamida
# temozolamida
# [(171, 183, 'Item')] ->temozolamida
# temozolamida
# [(315, 327, 'Item')] ->temozolamida
# temozolamida
# [(36, 48, 'Item')] ->temozolamida
# temozolamida
# [(459, 471, 'Item')] ->temozolamida
# temozolamida
# [(36, 48, 'Item')] ->temozolamida
# temozolamida
# [(358, 370, 'Item')] ->temozolamida
# temozolamida
# [(36, 48, 'Item')] ->temozolamida
# temozolamida
# [(98, 110, 'Item')] ->temozolamida
# temozolamida
# [(74, 86, 'Item')] ->temozolamida
# temozolamida
# [(36, 48, 'Item')] ->temozolamida
# fosfoetanolamina
# [(174, 190, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(90, 106, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(42, 58, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(104, 120, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(224, 240, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(43, 59, 'Item')] ->fosfoetanolamina
# fosfoetanolamina
# [(18, 34, 'Item')] ->fosfoetanolamina
# ritalina
# [(356, 364, 'Item')] ->ritalina
# ritalina
# [(15, 23, 'Item')] ->ritalina
# ritalina
# [(224, 232, 'Item')] ->ritalina
# ritalina
# [(207, 215, 'Item')] ->ritalina
# ritalina
# [(170, 178, 'Item')] ->ritalina
# ritalina
# [(356, 364, 'Item')] ->ritalina
# ritalina
# [(15, 23, 'Item')] ->ritalina
# ritalina
# [(170, 178, 'Item')] ->ritalina
# ritalina
# [(176, 184, 'Item')] ->ritalina
# ritalina
# [(207, 215, 'Item')] ->ritalina
# bectrum
# [(68, 75, 'Item')] ->bectrum
# melao de sao caetano
# [(203, 223, 'Item')] ->melao de sao caetano
# melao de sao caetano
# [(169, 189, 'Item')] ->melao de sao caetano
# risperidon
# [(46, 57, 'Item')] ->risperidon
# risperidona
# [(43, 54, 'Item')] ->risperidona
# timolol
# [(4, 11, 'Item')] ->timolol
# embolizacao do aneurisma
# [(61, 85, 'Item')] ->embolizacao do aneurisma
# cinacalcete 30mg
# [(279, 295, 'Item')] ->cinacalcete 30mg
# pregabalina
# [(1013, 1024, 'Item')] ->pregabalina
# althera
# [(99, 106, 'Item')] ->althera
# atezolizumab 60mg
# [(131, 148, 'Item')] ->atezolizumab 60mg
# herniorrafia incisional
# [(99, 122, 'Item')] ->herniorrafia incisional
# herniorrafia incisional
# [(403, 426, 'Item')] ->herniorrafia incisional
# herniorrafia incisional
# [(513, 536, 'Item')] ->herniorrafia incisional
# ressonancia magnetica
# [(109, 130, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(571, 592, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(185, 206, 'Item')] ->ressonancia magnetica
# risperidona
# [(193, 204, 'Item')] ->risperidona
# risperidona
# [(94, 105, 'Item')] ->risperidona
# risperidona
# [(92, 103, 'Item')] ->risperidona
# risperidona
# [(202, 213, 'Item')] ->risperidona
# pertuzumabe 420 mg
# [(229, 247, 'Item')] ->pertuzumabe 420 mg
# nivolumabe
# [(472, 482, 'Item')] ->nivolumabe
# nivolumabe
# [(570, 580, 'Item')] ->nivolumabe
# nivolumabe
# [(214, 224, 'Item')] ->nivolumabe
# colonoscopia
# [(214, 226, 'Item')] ->colonoscopia
# colonoscopia
# [(520, 532, 'Item')] ->colonoscopia
# aptamil pepti
# [(280, 293, 'Item')] ->aptamil pepti
# clofazimina 50mg
# [(90, 106, 'Item')] ->clofazimina 50mg
# clonazepan
# [(543, 553, 'Item')] ->clonazepan
# nebileto 5 mg
# [(121, 134, 'Item')] ->nebileto 5 mg
# nebileto 5 mg
# [(16, 29, 'Item')] ->nebileto 5 mg
# nebileto 5 mg
# [(241, 254, 'Item')] ->nebileto 5 mg
# nebileto 5 mg
# [(361, 374, 'Item')] ->nebileto 5 mg
# nebileto 5 mg
# [(178, 191, 'Item')] ->nebileto 5 mg
# nivolumab,
# [(359, 369, 'Item')] ->nivolumab,
# nivolumab(
# [(227, 237, 'Item')] ->nivolumab(
# nivolumab
# [(248, 258, 'Item')] ->nivolumab
# temodal
# [(181, 188, 'Item')] ->temodal
# temodal
# [(176, 183, 'Item')] ->temodal
# temodal
# [(102, 109, 'Item')] ->temodal
# temodal
# [(167, 174, 'Item')] ->temodal
# temodal
# [(460, 467, 'Item')] ->temodal
# temodal
# [(802, 809, 'Item')] ->temodal
# ortopedica
# [(118, 128, 'Item')] ->ortopedica
# tomografia computadorizada
# [(69, 95, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(415, 441, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(309, 335, 'Item')] ->tomografia computadorizada
# rituximabe 500mg
# [(395, 411, 'Item')] ->rituximabe 500mg
# cardiaca pediatrica
# [(192, 211, 'Item')] ->cardiaca pediatrica
# cardiaca pediatrica
# [(477, 496, 'Item')] ->cardiaca pediatrica
# cardiaca pediatrica
# [(247, 266, 'Item')] ->cardiaca pediatrica
# vimizim
# [(198, 205, 'Item')] ->vimizim
# vimizim
# [(198, 205, 'Item')] ->vimizim
# vimizim
# [(322, 329, 'Item')] ->vimizim
# vimizim
# [(322, 329, 'Item')] ->vimizim
# vimizim
# [(255, 262, 'Item')] ->vimizim
# vimizim
# [(255, 262, 'Item')] ->vimizim
# vimizin
# [(159, 166, 'Item')] ->vimizin
# vimizim
# [(3, 10, 'Item')] ->vimizim
# vimizim
# [(3, 10, 'Item')] ->vimizim
# vimizim
# [(122, 129, 'Item')] ->vimizim
# vimizim
# [(122, 129, 'Item')] ->vimizim
# vimizim
# [(1610, 1617, 'Item')] ->vimizim
# vimizim
# [(1610, 1617, 'Item')] ->vimizim
# muvinlax
# [(402, 410, 'Item')] ->muvinlax
# ketocal
# [(699, 706, 'Item')] ->ketocal
# venlafaxina 150mg
# [(287, 304, 'Item')] ->venlafaxina 150mg
# venlafaxina 150mg
# [(297, 314, 'Item')] ->venlafaxina 150mg
# venlafaxina 150mg
# [(306, 323, 'Item')] ->venlafaxina 150mg
# duloxetina
# [(1, 11, 'Item')] ->duloxetina
# duloxetina
# [(66, 76, 'Item')] ->duloxetina
# duloxetina
# [(257, 267, 'Item')] ->duloxetina
# fitas glicemicas
# [(123, 139, 'Item')] ->fitas glicemicas
# fitas glicemicas
# [(346, 362, 'Item')] ->fitas glicemicas
# fitas glicemicas
# [(158, 174, 'Item')] ->fitas glicemicas
# fortini
# [(134, 141, 'Item')] ->fortini
# fortini
# [(370, 377, 'Item')] ->fortini
# espiramicina 500mg
# [(1813, 1831, 'Item')] ->espiramicina 500mg
# dasatinibe
# [(39, 49, 'Item')] ->dasatinibe
# losartana
# [(616, 625, 'Item')] ->losartana
# enoxaparina
# [(825, 836, 'Item')] ->enoxaparina
# zoladez
# [(309, 316, 'Item')] ->zoladez
# zoladez
# [(499, 506, 'Item')] ->zoladez
# gencitabina
# [(304, 315, 'Item')] ->gencitabina
# gencitabina
# [(396, 407, 'Item')] ->gencitabina
# avastin (bevacizumabe
# [(159, 180, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(159, 180, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(736, 757, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(736, 757, 'Item')] ->avastin (bevacizumabe
# avastin - bevacizumabe
# [(224, 246, 'Item')] ->avastin - bevacizumabe
# avastin (bevacizumabe
# [(307, 328, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(307, 328, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(422, 443, 'Item')] ->avastin (bevacizumabe
# avastin (bevacizumabe
# [(422, 443, 'Item')] ->avastin (bevacizumabe
# pantoprazol
# [(499, 510, 'Item')] ->pantoprazol
# enapril 5mg
# [(1437, 1448, 'Item')] ->enapril 5mg
# carbamazepina
# [(1, 14, 'Item')] ->carbamazepina
# cirurgia de reconstrucao
# [(106, 130, 'Item')] ->cirurgia de reconstrucao
# bortezomibe
# [(271, 282, 'Item')] ->bortezomibe
# bortezomibe
# [(271, 282, 'Item')] ->bortezomibe
# bortezomibe
# [(26, 37, 'Item')] ->bortezomibe
# bortezomibe
# [(26, 37, 'Item')] ->bortezomibe
# bortezomibe
# [(40, 51, 'Item')] ->bortezomibe
# bortezomibe
# [(40, 51, 'Item')] ->bortezomibe
# bortezomib
# [(310, 321, 'Item')] ->bortezomib
# bortezomibe
# [(224, 235, 'Item')] ->bortezomibe
# bortezomibe
# [(224, 235, 'Item')] ->bortezomibe
# vimizim
# [(831, 838, 'Item')] ->vimizim
# vimizim
# [(73, 80, 'Item')] ->vimizim
# vimizim
# [(65, 72, 'Item')] ->vimizim
# vimizim
# [(83, 90, 'Item')] ->vimizim
# vimizim
# [(296, 303, 'Item')] ->vimizim
# vimizim
# [(132, 139, 'Item')] ->vimizim
# vimizim
# [(192, 199, 'Item')] ->vimizim
# somatropina
# [(1, 12, 'Item')] ->somatropina
# somatropina
# [(258, 269, 'Item')] ->somatropina
# cloxazolan
# [(172, 182, 'Item')] ->cloxazolan
# xultophy
# [(151, 159, 'Item')] ->xultophy
# xultophy
# [(582, 590, 'Item')] ->xultophy
# xultophy
# [(117, 125, 'Item')] ->xultophy
# leuprorrelina
# [(562, 575, 'Item')] ->leuprorrelina
# somatropina
# [(71, 82, 'Item')] ->somatropina
# somatropina
# [(2, 13, 'Item')] ->somatropina
# mapeamento de retina
# [(222, 242, 'Item')] ->mapeamento de retina
# mapeamento de retina
# [(616, 636, 'Item')] ->mapeamento de retina
# mapeamento de retina
# [(310, 330, 'Item')] ->mapeamento de retina
# mapeamento de retina
# [(514, 534, 'Item')] ->mapeamento de retina
# mapeamento de retina
# [(282, 302, 'Item')] ->mapeamento de retina
# mapeamento de retina
# [(226, 246, 'Item')] ->mapeamento de retina
# tomografia computadorizada
# [(505, 531, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(380, 406, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(101, 127, 'Item')] ->tomografia computadorizada
# nivolumab
# [(123, 133, 'Item')] ->nivolumab
# nivolumab
# [(1015, 1025, 'Item')] ->nivolumab
# nivolumab
# [(256, 266, 'Item')] ->nivolumab
# sirolimu
# [(188, 196, 'Item')] ->sirolimu
# sirolimu
# [(278, 286, 'Item')] ->sirolimu
# sirolimu
# [(138, 146, 'Item')] ->sirolimu
# sirolimu
# [(536, 544, 'Item')] ->sirolimu
# enzalutamida 40mg,
# [(152, 170, 'Item')] ->enzalutamida 40mg,
# laqueadura
# [(116, 126, 'Item')] ->laqueadura
# laqueadura
# [(399, 409, 'Item')] ->laqueadura
# laqueadura
# [(172, 182, 'Item')] ->laqueadura
# laqueadura
# [(469, 479, 'Item')] ->laqueadura
# laqueadura
# [(711, 721, 'Item')] ->laqueadura
# laqueadura
# [(795, 805, 'Item')] ->laqueadura
# laqueadura
# [(241, 251, 'Item')] ->laqueadura
# clobazam
# [(602, 610, 'Item')] ->clobazam
# clobazam
# [(190, 198, 'Item')] ->clobazam
# esterectomia total
# [(309, 327, 'Item')] ->esterectomia total
# catarata
# [(29, 37, 'Item')] ->catarata
# catarata
# [(105, 113, 'Item')] ->catarata
# catarata
# [(122, 130, 'Item')] ->catarata
# catarata
# [(194, 202, 'Item')] ->catarata
# aspirador portatil
# [(146, 164, 'Item')] ->aspirador portatil
# aspirador portatil
# [(17, 35, 'Item')] ->aspirador portatil
# somatropina
# [(528, 539, 'Item')] ->somatropina
# osteotomia
# [(118, 128, 'Item')] ->osteotomia
# ressonancia magnetica
# [(188, 209, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(116, 137, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(81, 102, 'Item')] ->ressonancia magnetica
# bevacizumabe 750mg
# [(198, 216, 'Item')] ->bevacizumabe 750mg
# ventilacao nao-invasiva (bipap
# [(178, 208, 'Item')] ->ventilacao nao-invasiva (bipap
# ventilacao nao-invasiva (bipap
# [(56, 86, 'Item')] ->ventilacao nao-invasiva (bipap
# abiraterona
# [(75, 86, 'Item')] ->abiraterona
# abiraterona
# [(485, 496, 'Item')] ->abiraterona
# abiraterona
# [(551, 562, 'Item')] ->abiraterona
# abiraterona
# [(574, 585, 'Item')] ->abiraterona
# abiraterona
# [(218, 229, 'Item')] ->abiraterona
# abiraterona
# [(327, 338, 'Item')] ->abiraterona
# abiraterona
# [(86, 97, 'Item')] ->abiraterona
# duloxetina
# [(473, 483, 'Item')] ->duloxetina
# duloxetina
# [(238, 248, 'Item')] ->duloxetina
# duloxetina
# [(467, 477, 'Item')] ->duloxetina
# duloxetina
# [(897, 907, 'Item')] ->duloxetina
# rituximab.
# [(13, 23, 'Item')] ->rituximab.
# guincho eletrico freedom
# [(17, 41, 'Item')] ->guincho eletrico freedom
# guincho eletrico freedom
# [(143, 167, 'Item')] ->guincho eletrico freedom
# guincho eletrico freedom
# [(590, 614, 'Item')] ->guincho eletrico freedom
# guincho eletrico freedom
# [(234, 258, 'Item')] ->guincho eletrico freedom
# guincho eletrico freedom
# [(52, 76, 'Item')] ->guincho eletrico freedom
# bortezomibe
# [(271, 282, 'Item')] ->bortezomibe
# bortezomibe
# [(77, 88, 'Item')] ->bortezomibe
# secuquinumabe
# [(82, 95, 'Item')] ->secuquinumabe
# secuquinumabe
# [(129, 142, 'Item')] ->secuquinumabe
# secuquinumabe
# [(508, 521, 'Item')] ->secuquinumabe
# endoscopia digestiva alta
# [(229, 254, 'Item')] ->endoscopia digestiva alta
# endoscopia digestiva alta
# [(185, 210, 'Item')] ->endoscopia digestiva alta
# endoscopia digestiva alta
# [(30, 55, 'Item')] ->endoscopia digestiva alta
# avastin
# [(158, 165, 'Item')] ->avastin
# avastin
# [(410, 417, 'Item')] ->avastin
# avastin
# [(224, 231, 'Item')] ->avastin
# avastin
# [(186, 193, 'Item')] ->avastin
# fortini
# [(768, 775, 'Item')] ->fortini
# luvas
# [(37, 42, 'Item')] ->luvas
# luva
# [(762, 767, 'Item')] ->luva
# luvas
# [(37, 42, 'Item')] ->luvas
# luvas
# [(52, 57, 'Item')] ->luvas
# luvas
# [(52, 57, 'Item')] ->luvas
# luvas
# [(156, 161, 'Item')] ->luvas
# luvas
# [(156, 161, 'Item')] ->luvas
# luvas
# [(37, 42, 'Item')] ->luvas
# luvas
# [(37, 42, 'Item')] ->luvas
# luvas
# [(16, 21, 'Item')] ->luvas
# luvas
# [(16, 21, 'Item')] ->luvas
# ritalina
# [(1, 9, 'Item')] ->ritalina
# abiraterona
# [(268, 279, 'Item')] ->abiraterona
# abiraterona
# [(103, 114, 'Item')] ->abiraterona
# rivaroxabana
# [(96, 108, 'Item')] ->rivaroxabana
# rivaroxabana
# [(211, 223, 'Item')] ->rivaroxabana
# rivaroxabana
# [(129, 141, 'Item')] ->rivaroxabana
# rivaroxabana
# [(200, 212, 'Item')] ->rivaroxabana
# nexavar
# [(129, 136, 'Item')] ->nexavar
# nexavar
# [(169, 176, 'Item')] ->nexavar
# nexavar
# [(186, 193, 'Item')] ->nexavar
# nivolumab
# [(107, 117, 'Item')] ->nivolumab
# nivolumabe
# [(93, 103, 'Item')] ->nivolumabe
# nivolumabe
# [(3, 13, 'Item')] ->nivolumabe
# nivolumabe
# [(41, 51, 'Item')] ->nivolumabe
# citrato de tamoxifeno
# [(828, 849, 'Item')] ->citrato de tamoxifeno
# citrato de tamoxifeno
# [(81, 102, 'Item')] ->citrato de tamoxifeno
# somatropina
# [(294, 305, 'Item')] ->somatropina
# somatropina
# [(685, 696, 'Item')] ->somatropina
# sildenafila
# [(94, 105, 'Item')] ->sildenafila
# sildenafila
# [(138, 149, 'Item')] ->sildenafila
# sildenafila
# [(176, 187, 'Item')] ->sildenafila
# sildenafila
# [(17, 28, 'Item')] ->sildenafila
# sildenafila
# [(505, 516, 'Item')] ->sildenafila
# eculizumabe
# [(137, 148, 'Item')] ->eculizumabe
# eculizumabe
# [(15, 26, 'Item')] ->eculizumabe
# noripurum
# [(55, 64, 'Item')] ->noripurum
# regorafenibe
# [(117, 129, 'Item')] ->regorafenibe
# regorafenibe
# [(251, 263, 'Item')] ->regorafenibe
# regorafenibe
# [(492, 504, 'Item')] ->regorafenibe
# regorafenibe
# [(642, 654, 'Item')] ->regorafenibe
# regorafenibe
# [(606, 618, 'Item')] ->regorafenibe
# regorafenibe
# [(145, 157, 'Item')] ->regorafenibe
# ultrassonografia
# [(1, 17, 'Item')] ->ultrassonografia
# paralisia cerebral e autismo
# [(104, 132, 'Item')] ->paralisia cerebral e autismo
# paralisia cerebral e autismo
# [(85, 113, 'Item')] ->paralisia cerebral e autismo
# cloreto de potassio 10%
# [(184, 207, 'Item')] ->cloreto de potassio 10%
# vascular
# [(259, 267, 'Item')] ->vascular
# revascularizacao do membro inferior
# [(595, 630, 'Item')] ->revascularizacao do membro inferior
# revascularizacao do membro inferior
# [(113, 148, 'Item')] ->revascularizacao do membro inferior
# revascularizacao do membro inferior
# [(393, 428, 'Item')] ->revascularizacao do membro inferior
# revascularizacao do membro inferior
# [(1452, 1487, 'Item')] ->revascularizacao do membro inferior
# revascularizacao do membro inferior
# [(496, 531, 'Item')] ->revascularizacao do membro inferior
# revascularizacao do membro inferior
# [(146, 181, 'Item')] ->revascularizacao do membro inferior
# cardiaca
# [(461, 469, 'Item')] ->cardiaca
# cardiaca
# [(168, 176, 'Item')] ->cardiaca
# cardiaca
# [(192, 200, 'Item')] ->cardiaca
# cardiaca
# [(347, 355, 'Item')] ->cardiaca
# cardiaca
# [(396, 404, 'Item')] ->cardiaca
# cardiaca
# [(219, 227, 'Item')] ->cardiaca
# bortezomibe
# [(259, 270, 'Item')] ->bortezomibe
# pertuzumabe
# [(244, 255, 'Item')] ->pertuzumabe
# pertuzumabe
# [(241, 252, 'Item')] ->pertuzumabe
# pertuzumabe
# [(910, 921, 'Item')] ->pertuzumabe
# temozalamida 100 mg
# [(255, 274, 'Item')] ->temozalamida 100 mg
# vascular
# [(191, 199, 'Item')] ->vascular
# vascular
# [(122, 130, 'Item')] ->vascular
# ecodopplercardiograma
# [(132, 153, 'Item')] ->ecodopplercardiograma
# ecodopplercardiograma
# [(131, 152, 'Item')] ->ecodopplercardiograma
# ecodopplercardiograma
# [(380, 401, 'Item')] ->ecodopplercardiograma
# eletroneuromiografia
# [(789, 809, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(938, 958, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(87, 107, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(2, 22, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(62, 82, 'Item')] ->eletroneuromiografia
# alenia
# [(364, 370, 'Item')] ->alenia
# alenia
# [(147, 153, 'Item')] ->alenia
# azatioprina 50mg
# [(155, 171, 'Item')] ->azatioprina 50mg
# azatioprina 50mg
# [(113, 129, 'Item')] ->azatioprina 50mg
# densitometria ossea
# [(87, 106, 'Item')] ->densitometria ossea
# densitometria ossea
# [(189, 208, 'Item')] ->densitometria ossea
# densitometria ossea
# [(116, 135, 'Item')] ->densitometria ossea
# amitriptilina
# [(405, 418, 'Item')] ->amitriptilina
# neocatl
# [(175, 182, 'Item')] ->neocatl
# neocatl
# [(102, 109, 'Item')] ->neocatl
# neocatl
# [(88, 95, 'Item')] ->neocatl
# neurologica
# [(159, 170, 'Item')] ->neurologica
# tomografia computadorizada
# [(156, 182, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(92, 118, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(180, 206, 'Item')] ->tomografia computadorizada
# pet-ct
# [(308, 314, 'Item')] ->pet-ct
# cristalino por lio
# [(63, 81, 'Item')] ->cristalino por lio
# fortini
# [(118, 125, 'Item')] ->fortini
# azacitidina 100mg
# [(218, 235, 'Item')] ->azacitidina 100mg
# tomografia computadorizada
# [(470, 496, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(163, 189, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(141, 167, 'Item')] ->tomografia computadorizada
# ecg com laudo
# [(92, 105, 'Item')] ->ecg com laudo
# ecg com laudo
# [(116, 129, 'Item')] ->ecg com laudo
# trastuzumabe
# [(180, 192, 'Item')] ->trastuzumabe
# ressonancia magnetica
# [(110, 131, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(69, 90, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(189, 210, 'Item')] ->ressonancia magnetica
# canula de estimulacao
# [(201, 222, 'Item')] ->canula de estimulacao
# mimpara
# [(101, 108, 'Item')] ->mimpara
# mimpara
# [(282, 289, 'Item')] ->mimpara
# mimpara
# [(462, 469, 'Item')] ->mimpara
# mimpara
# [(44, 51, 'Item')] ->mimpara
# mimpara
# [(2, 9, 'Item')] ->mimpara
# mimpara
# [(1, 8, 'Item')] ->mimpara
# iodo 131
# [(430, 438, 'Item')] ->iodo 131
# pertuzimab (perjeta
# [(216, 235, 'Item')] ->pertuzimab (perjeta
# ecocardiograma
# [(783, 797, 'Item')] ->ecocardiograma
# ecocardiograma
# [(188, 202, 'Item')] ->ecocardiograma
# ecocardiograma
# [(56, 70, 'Item')] ->ecocardiograma
# bortezomibe
# [(168, 179, 'Item')] ->bortezomibe
# transmissor guardian link2
# [(636, 662, 'Item')] ->transmissor guardian link2
# trulicity 1,5mg
# [(371, 386, 'Item')] ->trulicity 1,5mg
# leuprorrelina
# [(183, 196, 'Item')] ->leuprorrelina
# leuprorrelina
# [(158, 171, 'Item')] ->leuprorrelina
# enzalutamida 40mgr
# [(530, 548, 'Item')] ->enzalutamida 40mgr
# enzalutamida 40mg,
# [(283, 301, 'Item')] ->enzalutamida 40mg,
# enzalutamida 40mg,
# [(293, 311, 'Item')] ->enzalutamida 40mg,
# renehavis
# [(98, 107, 'Item')] ->renehavis
# bevacizumabe
# [(434, 446, 'Item')] ->bevacizumabe
# bevacizumabe
# [(199, 211, 'Item')] ->bevacizumabe
# bevacizumabe
# [(991, 1003, 'Item')] ->bevacizumabe
# firazyr
# [(806, 813, 'Item')] ->firazyr
# firazyr
# [(956, 963, 'Item')] ->firazyr
# firazyr
# [(102, 109, 'Item')] ->firazyr
# firazyr
# [(112, 119, 'Item')] ->firazyr
# lentes de contatos rigidas de desenho
# [(41, 78, 'Item')] ->lentes de contatos rigidas de desenho
# lentes de contatos rigidas de desenho
# [(116, 153, 'Item')] ->lentes de contatos rigidas de desenho
# lentes de contatos rigidas de desenho
# [(199, 236, 'Item')] ->lentes de contatos rigidas de desenho
# lentes de contatos rigidas de desenho
# [(363, 400, 'Item')] ->lentes de contatos rigidas de desenho
# lentes de contatos rigidas de desenho
# [(192, 229, 'Item')] ->lentes de contatos rigidas de desenho
# oxibutramina 5mg
# [(605, 621, 'Item')] ->oxibutramina 5mg
# oxibutramina 5mg
# [(388, 404, 'Item')] ->oxibutramina 5mg
# vedolizumabe
# [(549, 561, 'Item')] ->vedolizumabe
# catarata
# [(57, 65, 'Item')] ->catarata
# catarata
# [(475, 483, 'Item')] ->catarata
# catarata
# [(215, 223, 'Item')] ->catarata
# catarata
# [(97, 105, 'Item')] ->catarata
# catarata
# [(13, 21, 'Item')] ->catarata
# catarata
# [(503, 511, 'Item')] ->catarata
# catarata
# [(680, 688, 'Item')] ->catarata
# somatropina
# [(162, 173, 'Item')] ->somatropina
# somatropina
# [(670, 681, 'Item')] ->somatropina
# somatropina
# [(228, 239, 'Item')] ->somatropina
# somatropina
# [(493, 504, 'Item')] ->somatropina
# ketosteril
# [(219, 229, 'Item')] ->ketosteril
# ketosteril
# [(153, 163, 'Item')] ->ketosteril
# ketosteril
# [(993, 1003, 'Item')] ->ketosteril
# acido ursodesoxicolico
# [(1774, 1796, 'Item')] ->acido ursodesoxicolico
# acido ursodesoxicolico
# [(247, 269, 'Item')] ->acido ursodesoxicolico
# acido ursodesoxicolico
# [(670, 692, 'Item')] ->acido ursodesoxicolico
# retinografia fluorescente
# [(214, 239, 'Item')] ->retinografia fluorescente
# eculizumab
# [(318, 329, 'Item')] ->eculizumab
# eculizumab
# [(318, 329, 'Item')] ->eculizumab
# eculizumab
# [(468, 479, 'Item')] ->eculizumab
# eculizumab
# [(468, 479, 'Item')] ->eculizumab
# tramadol
# [(71, 79, 'Item')] ->tramadol
# tramadol
# [(86, 94, 'Item')] ->tramadol
# bortezomibe
# [(340, 351, 'Item')] ->bortezomibe
# traumatismo raquimedular - trm
# [(272, 302, 'Item')] ->traumatismo raquimedular - trm
# gefitinibe (iressa
# [(111, 129, 'Item')] ->gefitinibe (iressa
# aripiprazol
# [(98, 109, 'Item')] ->aripiprazol
# eletroneuromiografia mse
# [(203, 227, 'Item')] ->eletroneuromiografia mse
# ranitidina
# [(571, 581, 'Item')] ->ranitidina
# ranitidina
# [(48, 58, 'Item')] ->ranitidina
# ranitidina
# [(704, 714, 'Item')] ->ranitidina
# enzalutamida quando
# [(55, 74, 'Item')] ->enzalutamida quando
# enzalutamida (xtandi
# [(409, 429, 'Item')] ->enzalutamida (xtandi
# enzalutamida (xtandi
# [(409, 429, 'Item')] ->enzalutamida (xtandi
# enzalutamida radi
# [(31, 48, 'Item')] ->enzalutamida radi
# enzalutamida radi
# [(31, 48, 'Item')] ->enzalutamida radi
# carvedilol
# [(113, 123, 'Item')] ->carvedilol
# carvedilol
# [(189, 199, 'Item')] ->carvedilol
# minociclina
# [(840, 851, 'Item')] ->minociclina
# minociclina
# [(137, 148, 'Item')] ->minociclina
# etoposide
# [(132, 141, 'Item')] ->etoposide
# etoposide
# [(171, 180, 'Item')] ->etoposide
# etoposide
# [(113, 122, 'Item')] ->etoposide
# vitrectomia
# [(125, 136, 'Item')] ->vitrectomia
# tubos de xilocaina em gel
# [(61, 86, 'Item')] ->tubos de xilocaina em gel
# cadeira de rodas
# [(31, 47, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(385, 401, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(145, 161, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(62, 78, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(184, 200, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(71, 87, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(26, 42, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(164, 180, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(160, 176, 'Item')] ->cadeira de rodas
# tomografia de coerencia optica
# [(178, 208, 'Item')] ->tomografia de coerencia optica
# tomografia de coerencia optica
# [(572, 602, 'Item')] ->tomografia de coerencia optica
# tomografia de coerencia optica
# [(238, 268, 'Item')] ->tomografia de coerencia optica
# vimizim
# [(73, 80, 'Item')] ->vimizim
# vimizim
# [(262, 269, 'Item')] ->vimizim
# vimizim
# [(65, 72, 'Item')] ->vimizim
# vimizim
# [(83, 90, 'Item')] ->vimizim
# vimizim
# [(296, 303, 'Item')] ->vimizim
# vimizim
# [(132, 139, 'Item')] ->vimizim
# vimizim
# [(192, 199, 'Item')] ->vimizim
# vimizim
# [(320, 327, 'Item')] ->vimizim
# bevacizumabe
# [(132, 144, 'Item')] ->bevacizumabe
# bevacizumabe
# [(2, 14, 'Item')] ->bevacizumabe
# bevacizumabe
# [(467, 479, 'Item')] ->bevacizumabe
# maltodextrina
# [(386, 399, 'Item')] ->maltodextrina
# maltodextrina
# [(293, 306, 'Item')] ->maltodextrina
# maltodextrina
# [(495, 508, 'Item')] ->maltodextrina
# lamitor
# [(666, 673, 'Item')] ->lamitor
# lamitor
# [(776, 783, 'Item')] ->lamitor
# cirurgia ortopedica da coluna vertebral
# [(567, 606, 'Item')] ->cirurgia ortopedica da coluna vertebral
# cirurgia ortopedica da coluna vertebral
# [(492, 531, 'Item')] ->cirurgia ortopedica da coluna vertebral
# cirurgia ortopedica da coluna vertebral
# [(1230, 1269, 'Item')] ->cirurgia ortopedica da coluna vertebral
# sunitinib 50mg
# [(95, 109, 'Item')] ->sunitinib 50mg
# sunitinib 50mg
# [(95, 109, 'Item')] ->sunitinib 50mg
# sunitinib 50mg
# [(149, 163, 'Item')] ->sunitinib 50mg
# sunitinib 50mg
# [(149, 163, 'Item')] ->sunitinib 50mg
# sunitinib 50m
# [(312, 326, 'Item')] ->sunitinib 50m
# sunitinib 50mg
# [(531, 545, 'Item')] ->sunitinib 50mg
# sunitinib 50mg
# [(531, 545, 'Item')] ->sunitinib 50mg
# tizanidina 2mg
# [(0, 14, 'Item')] ->tizanidina 2mg
# tizanidina 2mg
# [(0, 14, 'Item')] ->tizanidina 2mg
# cardiaco
# [(108, 116, 'Item')] ->cardiaco
# ressonancia magnetica
# [(84, 105, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(189, 210, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(110, 131, 'Item')] ->ressonancia magnetica
# cirurgia bariatrica
# [(462, 481, 'Item')] ->cirurgia bariatrica
# cirurgia bariatrica
# [(115, 134, 'Item')] ->cirurgia bariatrica
# cirurgia bariatrica
# [(100, 119, 'Item')] ->cirurgia bariatrica
# pregomin pepti
# [(162, 176, 'Item')] ->pregomin pepti
# pregomin pepti
# [(955, 969, 'Item')] ->pregomin pepti
# sutent 50mg
# [(232, 243, 'Item')] ->sutent 50mg
# sutent 50mg
# [(146, 157, 'Item')] ->sutent 50mg
# sutent 50mg
# [(386, 397, 'Item')] ->sutent 50mg
# reducao mamaria
# [(60, 75, 'Item')] ->reducao mamaria
# reducao mamaria
# [(656, 671, 'Item')] ->reducao mamaria
# clofazimina 50mg
# [(326, 342, 'Item')] ->clofazimina 50mg
# clofazimina 50mg
# [(164, 180, 'Item')] ->clofazimina 50mg
# cintilografia ossea
# [(320, 339, 'Item')] ->cintilografia ossea
# cintilografia ossea
# [(99, 118, 'Item')] ->cintilografia ossea
# cintilografia ossea
# [(185, 204, 'Item')] ->cintilografia ossea
# micofenolato de mofetila
# [(924, 948, 'Item')] ->micofenolato de mofetila
# furosemida
# [(629, 639, 'Item')] ->furosemida
# furosemida
# [(2, 12, 'Item')] ->furosemida
# furosemida
# [(82, 92, 'Item')] ->furosemida
# furosemida
# [(763, 773, 'Item')] ->furosemida
# fimose
# [(31, 37, 'Item')] ->fimose
# fimose
# [(133, 139, 'Item')] ->fimose
# fimose
# [(176, 182, 'Item')] ->fimose
# fimose
# [(197, 203, 'Item')] ->fimose
# fosforo tricalcio
# [(163, 180, 'Item')] ->fosforo tricalcio
# oxicarbamazepina
# [(614, 630, 'Item')] ->oxicarbamazepina
# oxicarbamazepina
# [(1010, 1026, 'Item')] ->oxicarbamazepina
# oxicarbamazepina
# [(689, 705, 'Item')] ->oxicarbamazepina
# oxicarbamazepina
# [(159, 175, 'Item')] ->oxicarbamazepina
# neurologica
# [(835, 846, 'Item')] ->neurologica
# neurologica
# [(25, 36, 'Item')] ->neurologica
# neurologica
# [(338, 349, 'Item')] ->neurologica
# neurologica
# [(850, 861, 'Item')] ->neurologica
# neurologica
# [(79, 90, 'Item')] ->neurologica
# bevacizumabe
# [(121, 133, 'Item')] ->bevacizumabe
# bevacizumabe
# [(154, 166, 'Item')] ->bevacizumabe
# domperidona 10mg
# [(245, 261, 'Item')] ->domperidona 10mg
# domperidona 10mg
# [(413, 429, 'Item')] ->domperidona 10mg
# sorafenibe 400mg
# [(51, 67, 'Item')] ->sorafenibe 400mg
# cabazitaxel
# [(239, 250, 'Item')] ->cabazitaxel
# cabazitaxel
# [(348, 359, 'Item')] ->cabazitaxel
# campimetria
# [(108, 119, 'Item')] ->campimetria
# campimetria
# [(224, 235, 'Item')] ->campimetria
# reuquinol
# [(401, 410, 'Item')] ->reuquinol
# reuquinol
# [(43, 52, 'Item')] ->reuquinol
# pregomin pepti
# [(615, 629, 'Item')] ->pregomin pepti
# pregomin pepti
# [(191, 205, 'Item')] ->pregomin pepti
# eculizumab
# [(90, 101, 'Item')] ->eculizumab
# eculizumab
# [(90, 101, 'Item')] ->eculizumab
# eculizumabe
# [(58, 69, 'Item')] ->eculizumabe
# eculizumab
# [(21, 32, 'Item')] ->eculizumab
# eculizumab
# [(21, 32, 'Item')] ->eculizumab
# cabozantinibe 60 mg
# [(424, 443, 'Item')] ->cabozantinibe 60 mg
# bevacizumabe
# [(140, 152, 'Item')] ->bevacizumabe
# bevacizumabe
# [(703, 715, 'Item')] ->bevacizumabe
# laqueadura
# [(138, 148, 'Item')] ->laqueadura
# laqueadura
# [(152, 162, 'Item')] ->laqueadura
# laqueadura
# [(767, 777, 'Item')] ->laqueadura
# laqueadura
# [(991, 1001, 'Item')] ->laqueadura
# clonazepan
# [(603, 613, 'Item')] ->clonazepan
# prolia 60 mg
# [(150, 162, 'Item')] ->prolia 60 mg
# septoplastia
# [(197, 209, 'Item')] ->septoplastia
# septoplastia
# [(125, 137, 'Item')] ->septoplastia
# septoplastia
# [(54, 66, 'Item')] ->septoplastia
# anastrozol
# [(73, 83, 'Item')] ->anastrozol
# angiografia
# [(105, 116, 'Item')] ->angiografia
# vidaza
# [(25, 31, 'Item')] ->vidaza
# vidaza
# [(339, 345, 'Item')] ->vidaza
# vidaza
# [(793, 799, 'Item')] ->vidaza
# vidaza
# [(710, 716, 'Item')] ->vidaza
# minimed reservoir 3ml caixa com 10 unidades
# [(838, 881, 'Item')] ->minimed reservoir 3ml caixa com 10 unidades
# depura
# [(260, 266, 'Item')] ->depura
# depura
# [(562, 568, 'Item')] ->depura
# depura
# [(335, 341, 'Item')] ->depura
# oftalmologica
# [(112, 125, 'Item')] ->oftalmologica
# oftalmologico
# [(54, 67, 'Item')] ->oftalmologico
# oftalmologico
# [(48, 61, 'Item')] ->oftalmologico
# oftalmologico
# [(485, 498, 'Item')] ->oftalmologico
# oftalmologico
# [(57, 70, 'Item')] ->oftalmologico
# ressonancia magnetica de cranio com contraste
# [(38, 83, 'Item')] ->ressonancia magnetica de cranio com contraste
# ressonancia magnetica de cranio com contraste
# [(185, 230, 'Item')] ->ressonancia magnetica de cranio com contraste
# ressonancia magnetica de cranio com contraste
# [(113, 158, 'Item')] ->ressonancia magnetica de cranio com contraste
# somatropina
# [(51, 62, 'Item')] ->somatropina
# somatropina
# [(16, 27, 'Item')] ->somatropina
# somatropina
# [(40, 51, 'Item')] ->somatropina
# somatropina
# [(100, 111, 'Item')] ->somatropina
# somatropina
# [(58, 69, 'Item')] ->somatropina
# nivolumab - opdivo
# [(0, 18, 'Item')] ->nivolumab - opdivo
# glucosamina com condroitina
# [(611, 638, 'Item')] ->glucosamina com condroitina
# glucosamina com condroitina
# [(1029, 1056, 'Item')] ->glucosamina com condroitina
# glucosamina com condroitina
# [(490, 517, 'Item')] ->glucosamina com condroitina
# prometazina
# [(859, 870, 'Item')] ->prometazina
# nivolumab (opdivo
# [(578, 595, 'Item')] ->nivolumab (opdivo
# mimpara 30mg
# [(546, 558, 'Item')] ->mimpara 30mg
# mimpara 30mg
# [(179, 191, 'Item')] ->mimpara 30mg
# clobazam
# [(12, 20, 'Item')] ->clobazam
# micofenolato de mofetila 500mg
# [(209, 239, 'Item')] ->micofenolato de mofetila 500mg
# blinatumomabe
# [(381, 394, 'Item')] ->blinatumomabe
# blinatumomabe
# [(316, 329, 'Item')] ->blinatumomabe
# blinatumomabe
# [(248, 261, 'Item')] ->blinatumomabe
# neozine
# [(417, 424, 'Item')] ->neozine
# bevacizumabe
# [(110, 122, 'Item')] ->bevacizumabe
# durogesic
# [(151, 160, 'Item')] ->durogesic
# durogesic
# [(152, 161, 'Item')] ->durogesic
# durogesic
# [(230, 239, 'Item')] ->durogesic
# metilfenidato
# [(410, 423, 'Item')] ->metilfenidato
# metilfenidato
# [(165, 178, 'Item')] ->metilfenidato
# metilfenidato
# [(174, 187, 'Item')] ->metilfenidato
# metilfenidato
# [(158, 171, 'Item')] ->metilfenidato
# lanreotide 120mg
# [(166, 182, 'Item')] ->lanreotide 120mg
# eletroneuromiografia
# [(156, 176, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(157, 177, 'Item')] ->eletroneuromiografia
# eletroneuromiografia
# [(234, 254, 'Item')] ->eletroneuromiografia
# clobazam
# [(191, 199, 'Item')] ->clobazam
# clobazam
# [(86, 94, 'Item')] ->clobazam
# avastin
# [(440, 447, 'Item')] ->avastin
# avastin
# [(1180, 1187, 'Item')] ->avastin
# fascia
# [(23, 29, 'Item')] ->fascia
# ribociclibe
# [(522, 533, 'Item')] ->ribociclibe
# ribociclibe
# [(134, 145, 'Item')] ->ribociclibe
# ribociclibe
# [(82, 93, 'Item')] ->ribociclibe
# ribociclibe
# [(130, 141, 'Item')] ->ribociclibe
# ribociclibe
# [(79, 90, 'Item')] ->ribociclibe
# ribociclibe
# [(94, 105, 'Item')] ->ribociclibe
# ribociclibe
# [(66, 77, 'Item')] ->ribociclibe
# ribociclibe
# [(932, 943, 'Item')] ->ribociclibe
# ribociclibe
# [(140, 151, 'Item')] ->ribociclibe
# ribociclibe
# [(41, 52, 'Item')] ->ribociclibe
# ribociclibe
# [(296, 307, 'Item')] ->ribociclibe
# ribociclibe
# [(132, 143, 'Item')] ->ribociclibe
# ribociclibe
# [(153, 164, 'Item')] ->ribociclibe
# ribociclibe
# [(44, 55, 'Item')] ->ribociclibe
# sutent 50mg
# [(1340, 1351, 'Item')] ->sutent 50mg
# azacitidina (vidaza
# [(425, 444, 'Item')] ->azacitidina (vidaza
# vigabatrina
# [(284, 295, 'Item')] ->vigabatrina
# abiraterona
# [(534, 545, 'Item')] ->abiraterona
# hernia discal
# [(473, 486, 'Item')] ->hernia discal
# diazoxido
# [(392, 401, 'Item')] ->diazoxido
# diazoxido
# [(120, 129, 'Item')] ->diazoxido
# diazoxido
# [(36, 45, 'Item')] ->diazoxido
# nivolumab
# [(104, 113, 'Item')] ->nivolumab
# nivolumab
# [(273, 282, 'Item')] ->nivolumab
# nivolumab
# [(435, 444, 'Item')] ->nivolumab
# nivolumab
# [(206, 215, 'Item')] ->nivolumab
# nivolumab
# [(503, 512, 'Item')] ->nivolumab
# nivolumab
# [(78, 87, 'Item')] ->nivolumab
# nivolumab
# [(580, 589, 'Item')] ->nivolumab
# nivolumab
# [(167, 176, 'Item')] ->nivolumab
# pembrolizumabe (keytruda
# [(486, 510, 'Item')] ->pembrolizumabe (keytruda
# ressonancia magnetica
# [(116, 137, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(71, 92, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(189, 210, 'Item')] ->ressonancia magnetica
# canabidiol (rs
# [(282, 296, 'Item')] ->canabidiol (rs
# canabidiol (rs
# [(282, 296, 'Item')] ->canabidiol (rs
# canabidiol (rs
# [(306, 320, 'Item')] ->canabidiol (rs
# canabidiol (rs
# [(306, 320, 'Item')] ->canabidiol (rs
# xarelto 20 mg
# [(195, 208, 'Item')] ->xarelto 20 mg
# ribavirina
# [(729, 739, 'Item')] ->ribavirina
# ribavirina
# ...
# ressonancia magnetica
# [(557, 578, 'Item')] ->ressonancia magnetica
# polissonografia
# [(114, 129, 'Item')] ->polissonografia
# polissonografia
# [(88, 103, 'Item')] ->polissonografia
# polissonografia
# [(188, 203, 'Item')] ->polissonografia
# bolsas coletoras
# [(794, 810, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(362, 378, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(433, 449, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(205, 221, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(1240, 1256, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(73, 89, 'Item')] ->bolsas coletoras
# bolsas coletoras
# [(435, 451, 'Item')] ->bolsas coletoras
# enoxaparina
# [(103, 114, 'Item')] ->enoxaparina
# ofloxacina 400mg
# [(108, 124, 'Item')] ->ofloxacina 400mg
# selozok
# [(588, 595, 'Item')] ->selozok
# deferiprona
# [(85, 96, 'Item')] ->deferiprona
# timolol
# [(107, 114, 'Item')] ->timolol
# timolol
# [(133, 140, 'Item')] ->timolol
# timolol
# [(198, 205, 'Item')] ->timolol
# pertuzumabe
# [(630, 641, 'Item')] ->pertuzumabe
# pertuzumabe
# [(210, 221, 'Item')] ->pertuzumabe
# procoralan 7,5mg
# [(133, 149, 'Item')] ->procoralan 7,5mg
# azatioprina 50mg
# [(89, 105, 'Item')] ->azatioprina 50mg
# azatioprina 50mg
# [(91, 107, 'Item')] ->azatioprina 50mg
# pregomin pepti
# [(350, 364, 'Item')] ->pregomin pepti
# toujeo
# [(1110, 1116, 'Item')] ->toujeo
# vesomne
# [(912, 919, 'Item')] ->vesomne
# vesomne
# [(131, 138, 'Item')] ->vesomne
# octreotida lar 30mg
# [(140, 159, 'Item')] ->octreotida lar 30mg
# brentuximabe - vedotin
# [(243, 265, 'Item')] ->brentuximabe - vedotin
# fluorouracil
# [(164, 176, 'Item')] ->fluorouracil
# fluorouracil
# [(156, 168, 'Item')] ->fluorouracil
# ureterorrenolitotripsia
# [(895, 918, 'Item')] ->ureterorrenolitotripsia
# ureterorrenolitotripsia
# [(475, 498, 'Item')] ->ureterorrenolitotripsia
# ureterorrenolitotripsia
# [(85, 108, 'Item')] ->ureterorrenolitotripsia
# otoneurologico
# [(534, 548, 'Item')] ->otoneurologico
# otoneurologico
# [(412, 426, 'Item')] ->otoneurologico
# otoneurologico
# [(119, 133, 'Item')] ->otoneurologico
# otoneurologico
# [(70, 84, 'Item')] ->otoneurologico
# otoneurologico
# [(124, 138, 'Item')] ->otoneurologico
# cateter duplo j
# [(39, 54, 'Item')] ->cateter duplo j
# ressonancia magnetica de cranio
# [(185, 216, 'Item')] ->ressonancia magnetica de cranio
# ressonancia magnetica de cranio
# [(114, 145, 'Item')] ->ressonancia magnetica de cranio
# ressonancia magnetica de cranio
# [(98, 129, 'Item')] ->ressonancia magnetica de cranio
# forteo
# [(1009, 1015, 'Item')] ->forteo
# ortopedica
# [(476, 486, 'Item')] ->ortopedica
# ortopedica
# [(476, 486, 'Item')] ->ortopedica
# ortopedica
# [(476, 486, 'Item')] ->ortopedica
# ortopedica
# [(299, 309, 'Item')] ->ortopedica
# ortopedica
# [(299, 309, 'Item')] ->ortopedica
# ortopedica
# [(299, 309, 'Item')] ->ortopedica
# ortopedica
# [(326, 336, 'Item')] ->ortopedica
# ortopedico
# [(230, 240, 'Item')] ->ortopedico
# ortopedica
# [(326, 336, 'Item')] ->ortopedica
# ortopedico
# [(230, 240, 'Item')] ->ortopedico
# ortopedica
# [(326, 336, 'Item')] ->ortopedica
# ortopedica
# [(502, 512, 'Item')] ->ortopedica
# ortopedica
# [(502, 512, 'Item')] ->ortopedica
# ortopedica
# [(502, 512, 'Item')] ->ortopedica
# ortopedica
# [(739, 749, 'Item')] ->ortopedica
# ortopedica
# [(739, 749, 'Item')] ->ortopedica
# ortopedica
# [(739, 749, 'Item')] ->ortopedica
# ortopedica
# [(222, 232, 'Item')] ->ortopedica
# ortopedica
# [(222, 232, 'Item')] ->ortopedica
# ortopedica
# [(222, 232, 'Item')] ->ortopedica
# ortopedica
# [(113, 123, 'Item')] ->ortopedica
# ortopedica
# [(113, 123, 'Item')] ->ortopedica
# ortopedica
# [(113, 123, 'Item')] ->ortopedica
# ortopedica
# [(471, 481, 'Item')] ->ortopedica
# ortopedica
# [(471, 481, 'Item')] ->ortopedica
# ortopedica
# [(471, 481, 'Item')] ->ortopedica
# ortopedica
# [(799, 809, 'Item')] ->ortopedica
# ortopedico
# [(418, 428, 'Item')] ->ortopedico
# ortopedica
# [(799, 809, 'Item')] ->ortopedica
# ortopedico
# [(418, 428, 'Item')] ->ortopedico
# ortopedica
# [(799, 809, 'Item')] ->ortopedica
# ortopedica
# [(170, 180, 'Item')] ->ortopedica
# ortopedica
# [(170, 180, 'Item')] ->ortopedica
# ortopedica
# [(170, 180, 'Item')] ->ortopedica
# ortopedica
# [(669, 679, 'Item')] ->ortopedica
# ortopedica
# [(669, 679, 'Item')] ->ortopedica
# ortopedica
# [(669, 679, 'Item')] ->ortopedica
# ressonancia magnetica
# [(102, 123, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(188, 209, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(185, 206, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(821, 842, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(131, 152, 'Item')] ->ressonancia magnetica
# ressonancia magnetica
# [(226, 247, 'Item')] ->ressonancia magnetica
# ressonancia magnetica de coluna lombo-sacra
# [(91, 134, 'Item')] ->ressonancia magnetica de coluna lombo-sacra
# ressonancia magnetica de coluna lombo-sacra
# [(189, 232, 'Item')] ->ressonancia magnetica de coluna lombo-sacra
# teriparatida 250 mc
# [(371, 390, 'Item')] ->teriparatida 250 mc
# teriparatida 250 mc
# [(301, 320, 'Item')] ->teriparatida 250 mc
# fabrazyme
# [(162, 171, 'Item')] ->fabrazyme
# fabrazyme
# [(135, 144, 'Item')] ->fabrazyme
# fabrazyme
# [(312, 321, 'Item')] ->fabrazyme
# miogama
# [(185, 192, 'Item')] ->miogama
# miogama
# [(426, 433, 'Item')] ->miogama
# sistema minimed 640g
# [(1521, 1541, 'Item')] ->sistema minimed 640g
# enoxieparina
# [(440, 452, 'Item')] ->enoxieparina
# pediasure
# [(240, 249, 'Item')] ->pediasure
# pediasure
# [(153, 162, 'Item')] ->pediasure
# pediasure
# [(84, 93, 'Item')] ->pediasure
# bevacizumab
# [(210, 222, 'Item')] ->bevacizumab
# ginecologica
# [(542, 554, 'Item')] ->ginecologica
# ginecologica
# [(298, 310, 'Item')] ->ginecologica
# ginecologica
# [(52, 64, 'Item')] ->ginecologica
# ginecologica
# [(111, 123, 'Item')] ->ginecologica
# trastuzumabe
# [(154, 166, 'Item')] ->trastuzumabe
# trastuzumabe
# [(1015, 1027, 'Item')] ->trastuzumabe
# trastuzumabe
# [(1122, 1134, 'Item')] ->trastuzumabe
# aripiprazol
# [(405, 416, 'Item')] ->aripiprazol
# pertuzumabe
# [(587, 598, 'Item')] ->pertuzumabe
# pertuzumabe
# [(158, 169, 'Item')] ->pertuzumabe
# tomografia computadorizada do torax
# [(188, 223, 'Item')] ->tomografia computadorizada do torax
# tomografia computadorizada do torax
# [(72, 107, 'Item')] ->tomografia computadorizada do torax
# tomografia computadorizada do torax
# [(116, 151, 'Item')] ->tomografia computadorizada do torax
# ioban
# [(1072, 1077, 'Item')] ->ioban
# leuprorrelina 3,75mg
# [(206, 226, 'Item')] ->leuprorrelina 3,75mg
# endoscopia digestiva
# [(253, 273, 'Item')] ->endoscopia digestiva
# endoscopia digestiva
# [(202, 222, 'Item')] ->endoscopia digestiva
# sorafenibe 400mg
# [(116, 132, 'Item')] ->sorafenibe 400mg
# pancreatina
# [(220, 231, 'Item')] ->pancreatina
# pancreatina
# [(824, 835, 'Item')] ->pancreatina
# hernioplastia
# [(125, 138, 'Item')] ->hernioplastia
# hernioplastia
# [(41, 54, 'Item')] ->hernioplastia
# amantadina 100mg
# [(134, 150, 'Item')] ->amantadina 100mg
# amantadina 100mg
# [(374, 390, 'Item')] ->amantadina 100mg
# amantadina 100mg
# [(224, 240, 'Item')] ->amantadina 100mg
# amantadina 100mg
# [(122, 138, 'Item')] ->amantadina 100mg
# concardio
# [(405, 414, 'Item')] ->concardio
# holter
# [(115, 121, 'Item')] ->holter
# holter
# [(45, 51, 'Item')] ->holter
# holter
# [(1845, 1851, 'Item')] ->holter
# lectrum
# [(473, 480, 'Item')] ->lectrum
# lectrum
# [(495, 502, 'Item')] ->lectrum
# teriparatida 250 mc
# [(631, 650, 'Item')] ->teriparatida 250 mc
# catarata
# [(29, 37, 'Item')] ->catarata
# catarata
# [(125, 133, 'Item')] ->catarata
# cinacalcete 30mg
# [(304, 320, 'Item')] ->cinacalcete 30mg
# cinacalcete 30mg
# [(512, 528, 'Item')] ->cinacalcete 30mg
# opdivo
# [(178, 184, 'Item')] ->opdivo
# opdivo
# [(87, 93, 'Item')] ->opdivo
# opdivo
# [(382, 388, 'Item')] ->opdivo
# opdivo
# [(19, 25, 'Item')] ->opdivo
# teste de inclinacao ortostatica
# [(318, 349, 'Item')] ->teste de inclinacao ortostatica
# teste de inclinacao ortostatica
# [(238, 269, 'Item')] ->teste de inclinacao ortostatica
# denosumabe 1amp sc
# [(158, 176, 'Item')] ->denosumabe 1amp sc
# denosumabe 1amp sc
# [(410, 428, 'Item')] ->denosumabe 1amp sc
# denosumabe 1amp sc
# [(129, 147, 'Item')] ->denosumabe 1amp sc
# duloxetina
# [(153, 163, 'Item')] ->duloxetina
# insulina lantus
# [(174, 189, 'Item')] ->insulina lantus
# insulina lantus
# [(517, 532, 'Item')] ->insulina lantus
# insulina lantus
# [(537, 552, 'Item')] ->insulina lantus
# temozolamida 250mg
# [(428, 446, 'Item')] ->temozolamida 250mg
# temozolamida 250mg
# [(358, 376, 'Item')] ->temozolamida 250mg
# temozolamida 250mg
# [(799, 817, 'Item')] ->temozolamida 250mg
# usg doppler de arterias carotidas e vertebrais
# [(98, 144, 'Item')] ->usg doppler de arterias carotidas e vertebrais
# usg doppler de arterias carotidas e vertebrais
# [(113, 159, 'Item')] ->usg doppler de arterias carotidas e vertebrais
# adenoidectomia
# [(7, 21, 'Item')] ->adenoidectomia
# adenoidectomia
# [(748, 762, 'Item')] ->adenoidectomia
# adenoidectomia
# [(124, 138, 'Item')] ->adenoidectomia
# cadeira de rodas
# [(587, 603, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(19, 35, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(168, 184, 'Item')] ->cadeira de rodas
# cadeira de rodas
# [(153, 169, 'Item')] ->cadeira de rodas
# enzalutamida 40mgi
# [(129, 147, 'Item')] ->enzalutamida 40mgi
# forteo
# [(218, 224, 'Item')] ->forteo
# forteo
# [(32, 38, 'Item')] ->forteo
# forteo
# [(33, 39, 'Item')] ->forteo
# forteo
# [(34, 40, 'Item')] ->forteo
# forteo
# [(50, 56, 'Item')] ->forteo
# brentuximabe vedotin
# [(479, 499, 'Item')] ->brentuximabe vedotin
# retinografia
# [(145, 157, 'Item')] ->retinografia
# retinografia
# [(261, 273, 'Item')] ->retinografia
# somatropina
# [(115, 126, 'Item')] ->somatropina
# somatropina
# [(195, 206, 'Item')] ->somatropina
# somatropina
# [(24, 35, 'Item')] ->somatropina
# temozolamida
# [(28, 40, 'Item')] ->temozolamida
# clobazam
# [(148, 156, 'Item')] ->clobazam
# clobazam
# [(166, 174, 'Item')] ->clobazam
# tramadon
# [(120, 128, 'Item')] ->tramadon
# tramadon
# [(596, 604, 'Item')] ->tramadon
# ribavirina
# [(25, 35, 'Item')] ->ribavirina
# ribavirina
# [(123, 133, 'Item')] ->ribavirina
# ribavirina
# [(1215, 1225, 'Item')] ->ribavirina
# paquimetria
# [(160, 171, 'Item')] ->paquimetria
# paquimetria
# [(276, 287, 'Item')] ->paquimetria
# doxazosina 2mg
# [(227, 241, 'Item')] ->doxazosina 2mg
# doxazosina 2mg
# [(9, 23, 'Item')] ->doxazosina 2mg
# doxazosina 2mg
# [(339, 353, 'Item')] ->doxazosina 2mg
# fludarabina
# [(127, 138, 'Item')] ->fludarabina
# fludarabina
# [(88, 99, 'Item')] ->fludarabina
# fludarabina
# [(253, 264, 'Item')] ->fludarabina
# fludarabina
# [(139, 150, 'Item')] ->fludarabina
# bortezomibe
# [(254, 265, 'Item')] ->bortezomibe
# bortezomibe
# [(237, 248, 'Item')] ->bortezomibe
# bortezomibe
# [(93, 104, 'Item')] ->bortezomibe
# bortezomibe
# [(82, 93, 'Item')] ->bortezomibe
# queatipina
# [(87, 97, 'Item')] ->queatipina
# queatipina
# [(203, 213, 'Item')] ->queatipina
# galvus 50mg
# [(874, 885, 'Item')] ->galvus 50mg
# galvus 50mg
# [(222, 233, 'Item')] ->galvus 50mg
# tomografia computadorizada
# [(105, 131, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(189, 215, 'Item')] ->tomografia computadorizada
# tomografia computadorizada
# [(90, 116, 'Item')] ->tomografia computadorizada
# abiraterone 250mg
# [(483, 500, 'Item')] ->abiraterone 250mg
# endoscopia digestiva alta
# [(88, 113, 'Item')] ->endoscopia digestiva alta
# endoscopia digestiva alta
# [(377, 402, 'Item')] ->endoscopia digestiva alta
# endoscopia digestiva alta
# [(115, 140, 'Item')] ->endoscopia digestiva alta
# endoscopia digestiva alta
# [(189, 214, 'Item')] ->endoscopia digestiva alta
# pertuzumabe
# [(136, 147, 'Item')] ->pertuzumabe
# pertuzumabe
# [(653, 664, 'Item')] ->pertuzumabe
# pertuzumabe
# [(104, 115, 'Item')] ->pertuzumabe
# temozolamida
# [(335, 347, 'Item')] ->temozolamida
# bevacizumab)
# [(69, 81, 'Item')] ->bevacizumab)
# bevacizumab)
# [(69, 81, 'Item')] ->bevacizumab)
# bevacizumabe
# [(266, 278, 'Item')] ->bevacizumabe
# bevacizumabe
# [(521, 533, 'Item')] ->bevacizumabe
# bevacizumab)
# [(38, 50, 'Item')] ->bevacizumab)
# bevacizumab)
# [(38, 50, 'Item')] ->bevacizumab)
# pregomin pepti
# [(1376, 1390, 'Item')] ->pregomin pepti
# pregomin pepti
# [(1295, 1309, 'Item')] ->pregomin pepti
# pregomin pepti
# [(325, 339, 'Item')] ->pregomin pepti
# pregomin pepti
# [(29, 43, 'Item')] ->pregomin pepti
# pregomin pepti
# [(89, 103, 'Item')] ->pregomin pepti
# pregomin pepti
# [(166, 180, 'Item')] ->pregomin pepti
# pregomin pepti
# [(88, 102, 'Item')] ->pregomin pepti
# brometo de tiotropio
# [(425, 445, 'Item')] ->brometo de tiotropio
# somatropina 12 ui
# [(230, 247, 'Item')] ->somatropina 12 ui
# synolis v-
# [(825, 836, 'Item')] ->synolis v-
# provance
# [(636, 644, 'Item')] ->provance
# baclofeno
# [(0, 9, 'Item')] ->baclofeno
# baclofeno
# [(0, 9, 'Item')] ->baclofeno
# baclofeno
# [(0, 9, 'Item')] ->baclofeno
# cadeira de rodas
# [(559, 575, 'Item')] ->cadeira de rodas
# voriconazol
# [(160, 171, 'Item')] ->voriconazol
# leuprorrelina 3,75mg
# [(643, 663, 'Item')] ->leuprorrelina 3,75mg
# endoscopia digestiva alta com pesquisa h-pylori
# [(110, 157, 'Item')] ->endoscopia digestiva alta com pesquisa h-pylori
# octreotida lar 30mg
# [(1047, 1066, 'Item')] ->octreotida lar 30mg
# octreotida lar 30mg
# [(1406, 1425, 'Item')] ->octreotida lar 30mg
# bevacizumab
# [(1610, 1622, 'Item')] ->bevacizumab
# bevacizumab
# [(1610, 1622, 'Item')] ->bevacizumab
# bevacizumabe
# [(593, 605, 'Item')] ->bevacizumabe
# bevacizumabr
# [(121, 133, 'Item')] ->bevacizumabr
# bevacizumab,
# [(106, 118, 'Item')] ->bevacizumab,
# bevacizumab
# [(39, 51, 'Item')] ->bevacizumab
# bevacizumab
# [(39, 51, 'Item')] ->bevacizumab
# micofenolato de mofetil
# [(128, 151, 'Item')] ->micofenolato de mofetil
# micofenolato de mofetil
# [(300, 323, 'Item')] ->micofenolato de mofetil
# cinacalcete 30mg
# [(159, 175, 'Item')] ->cinacalcete 30mg
# novasource senior
# [(155, 172, 'Item')] ->novasource senior
# clozapina
# [(1396, 1405, 'Item')] ->clozapina
# aristraz 15 mg
# [(192, 206, 'Item')] ->aristraz 15 mg
# aristraz 15 mg
# [(710, 724, 'Item')] ->aristraz 15 mg
# aristraz 15 mg
# [(160, 174, 'Item')] ->aristraz 15 mg
# ribociclibe
# [(892, 903, 'Item')] ->ribociclibe
# ribociclibe
# [(240, 251, 'Item')] ->ribociclibe
# ribociclibe
# [(330, 341, 'Item')] ->ribociclibe
# ribociclibe
# [(304, 315, 'Item')] ->ribociclibe
# ribociclibe
# [(599, 610, 'Item')] ->ribociclibe
# ribociclibe
# [(128, 139, 'Item')] ->ribociclibe
# ribociclibe
# [(139, 150, 'Item')] ->ribociclibe
# ecocardiografia transtoracica
# [(114, 143, 'Item')] ->ecocardiografia transtoracica
# ecocardiografia transtoracica
# [(114, 143, 'Item')] ->ecocardiografia transtoracica
# ecocardiografia transtoracica
# [(187, 216, 'Item')] ->ecocardiografia transtoracica
# ecocardiografia transtoracica
# [(111, 140, 'Item')] ->ecocardiografia transtoracica
# ecocardiografia transtoracica
# [(111, 140, 'Item')] ->ecocardiografia transtoracica
# ecocardiografia transtoracica
# [(187, 216, 'Item')] ->ecocardiografia transtoracica
# cdc
# [(177, 180, 'Item')] ->cdc
# cdc
# [(177, 180, 'Item')] ->cdc
# cdc
# [(177, 180, 'Item')] ->cdc
# cdc
# [(296, 299, 'Item')] ->cdc
# cdc
# [(296, 299, 'Item')] ->cdc
# cdc
# [(296, 299, 'Item')] ->cdc
# cdi
# [(188, 191, 'Item')] ->cdi
# cdi
# [(315, 318, 'Item')] ->cdi
# cdi
# [(252, 255, 'Item')] ->cdi
# cdc
# [(14, 17, 'Item')] ->cdc
# cdc
# [(14, 17, 'Item')] ->cdc
# cdc
# [(14, 17, 'Item')] ->cdc
# cd
# [(327, 330, 'Item')] ->cd
# cd
# [(43, 46, 'Item')] ->cd
# cdc
# [(13, 16, 'Item')] ->cdc
# cdc
# [(13, 16, 'Item')] ->cdc
# cdc
# [(13, 16, 'Item')] ->cdc
# vitrectomia posterior via pars plana
# [(29, 65, 'Item')] ->vitrectomia posterior via pars plana
# vitrectomia posterior via pars plana
# [(35, 71, 'Item')] ->vitrectomia posterior via pars plana
# vitrectomia posterior via pars plana
# [(198, 234, 'Item')] ->vitrectomia posterior via pars plana
# vitrectomia posterior via pars plana
# [(117, 153, 'Item')] ->vitrectomia posterior via pars plana
# vitrectomia posterior via pars plana
# [(106, 142, 'Item')] ->vitrectomia posterior via pars plana
# azacitidina
# [(75, 86, 'Item')] ->azacitidina
# azacitidina
# [(365, 376, 'Item')] ->azacitidina
# azacitidina
# [(197, 208, 'Item')] ->azacitidina
# azacitidina
# [(901, 912, 'Item')] ->azacitidina
# azacitidina
# [(5, 16, 'Item')] ->azacitidina
# azacitidina
# [(94, 105, 'Item')] ->azacitidina
# azacitidina
# [(369, 380, 'Item')] ->azacitidina
# azacitidina
# [(534, 545, 'Item')] ->azacitidina
# azacitidina
# [(42, 53, 'Item')] ->azacitidina
# azacitidina
# [(22, 33, 'Item')] ->azacitidina
# azacitidina
# [(11, 22, 'Item')] ->azacitidina
# azacitidina
# [(246, 257, 'Item')] ->azacitidina
# denosumabe 60mg
# [(690, 705, 'Item')] ->denosumabe 60mg
# denosumabe 60mg
# [(756, 771, 'Item')] ->denosumabe 60mg
# 1428

# %%
print(train_data2[0][1])
print(train_data2[1][1])
print(train_data2[2][1])
impListaRange2(train_data2,5)
#{'entities': [(2794, 2802, 'Item'), (22366, 22374, 'Item'), (29318, 29326, 'Item')]}

print(train_data2)
# Out:
# {'entities': [(174, 187, 'Item')]}
# {'entities': [(502, 513, 'Item')]}
# {'entities': [(188, 243, 'Item')]}
# ('dos fatos e fundamentos juridicos o autor em virtude de estar acometido por doenca pulmonar obstrutiva cronica ( ), necessita utilizar a combinacao dos farmacos formoterol + beclometasona 12/400 (02 vezes por dia) e tiotropico 2,5mg (02 jatos por dia),conforme relatorio medico, a fim de evitar insuficiencia respiratoria e, consequentemente, o risco de obito', {'entities': [(174, 187, 'Item')]}),
# (' /50 e /83,uma vez nao dispondo de meios para prover as despesas do processo sem prejuizo do sustento proprio ouda familia; c) seja o estado de pernambuco citado, por meio de perm sc (art. 247, perm sc ), na pessoade seu representante legal, para contestar o feito, sob pena de aplicacao dos efeitos da revelia; d) perm sc o deferimento da perm sc , conforme faculta o inciso e perm sc do artigo294 do , condenando a empresa re, a cobrir o ; , para assegurar um tratamento de forma adequada, tendo comoofev 150mg de 12/12 horasfinalidade tratar o disturbio que acomete o autor da presente acao no prazo de 48(quarenta e oito) horas,com fixacao de multa diaria em caso de descumprimento da ordem judicial a ser arbitrada por esse juizo,nao inferior a r$ ,00 (mil reais)', {'entities': [(502, 513, 'Item')]}),
# ('assim, a parte autora pleiteia medida de urgencia, a ser concedida liminarmente, para que o demandado empreenda todos os esforcos e promova as medidas necessarias para a realizacao de uma ressonancia magnetica de cranio com contraste e sedacao conforme prescricao medica, sem demora, para que tenha tratamento adequado', {'entities': [(188, 243, 'Item')]}),
# (' esta mais do que claro - e expressamente declarado em receituario medico - que a parte necessita de uma uma ressonancia magnetica de cranio com contraste e sedacao conforme prescricao medica', {'entities': [(109, 164, 'Item')]}),
# (' fatos a parte autora possui cefaleia diaria e persistente, necessitando de uma ressonancia magnetica de cranio com contraste e sedacao , com urgencia', {'entities': [(80, 135, 'Item')]})[('dos fatos e fundamentos juridicos o autor em virtude de estar acometido por doenca pulmonar obstrutiva cronica ( ), necessita utilizar a combinacao dos farmacos formoterol + beclometasona 12/400 (02 vezes por dia) e tiotropico 2,5mg (02 jatos por dia),conforme relatorio medico, a fim de evitar insuficiencia respiratoria e, consequentemente, o risco de obito', {'entities': [(174, 187, 'Item')]}), (' /50 e /83,uma vez nao dispondo de meios para prover as despesas do processo sem prejuizo do sustento proprio ouda familia; c) seja o estado de pernambuco citado, por meio de perm sc (art. 247, perm sc ), na pessoade seu representante legal, para contestar o feito, sob pena de aplicacao dos efeitos da revelia; d) perm sc o deferimento da perm sc , conforme faculta o inciso e perm sc do artigo294 do , condenando a empresa re, a cobrir o ; , para assegurar um tratamento de forma adequada, tendo comoofev 150mg de 12/12 horasfinalidade tratar o disturbio que acomete o autor da presente acao no prazo de 48(quarenta e oito) horas,com fixacao de multa diaria em caso de descumprimento da ordem judicial a ser arbitrada por esse juizo,nao inferior a r$ ,00 (mil reais)', {'entities': [(502, 513, 'Item')]}), ('assim, a parte autora pleiteia medida de urgencia, a ser concedida liminarmente, para que o demandado empreenda todos os esforcos e promova as medidas necessarias para a realizacao de uma ressonancia magnetica de cranio com contraste e sedacao conforme prescricao medica, sem demora, para que tenha tratamento adequado', {'entities': [(188, 243, 'Item')]}), (' esta mais do que claro - e expressamente declarado em receituario medico - que a parte necessita de uma uma ressonancia magnetica de cranio com contraste e sedacao conforme prescricao medica', {'entities': [(109, 164, 'Item')]}), (' fatos a parte autora possui cefaleia diaria e persistente, necessitando de uma ressonancia magnetica de cranio com contraste e sedacao , com urgencia', {'entities': [(80, 135, 'Item')]}), (' a multa independe de requerimento da parte e podera ser aplicada nafase de conhecimento, em tutela provisoria ou na sentenca, ou na fase deexecucao, desde que seja suficiente e compativel com a obrigacao e que sedetermine prazo razoavel para cumprimento do preceito.(...) conforme explanacao supra, apos ser intensamente investigado, o autor foradiagnosticado com baixa estatura por ser pequeno para a idade gestacional ( ), tendo como recomendacao medica para o restabelecimento da sua saude a utilizacao dosfarmacos mg somatropina 12 ui/2ml (ou somatropina 4ui/ml), por prazoeindeterminado', {'entities': [(522, 539, 'Item')]}), ('entrementes, a solicitacao fora negada sob o argumento de que; doc.03as medicacoes em questao nao sao fornecidas para o tratamento da patologia do (), desconsiderando a recomendacao da medica responsavel pelo seu pelo exposto, o demandante necessita iniciar, em carater de urgencia, o tratamento vital ao controle do seu quadro clinico atraves da utilizacao das medicacoes mg somatropina 12 ui/2ml (ou somatropina 4ui/ml), por prazoeindeterminado, nos termos solicitados pelo medico, em consonancia com laudo e prescricaodos medicamentos anexados', {'entities': [(376, 393, 'Item')]}), ('pelo exposto, estando presentes a comprovacao da necessidade dos farmacos prescritos pela medica que o acompanha, bem como o dever imposto ao poder publico em prestar assistencia a saude de todos oscidadaos, vem o demandante buscar a tutela jurisdicional do estado, atraves deste , para que seja determinado que o estado de pernambuco proceda com ofornecimento/custeio das medicacoes mg e somatropina 12 ui/2ml(ou somatropina 4ui/ml), por prazo indeterminado,em conformidade com a narrativafatica e juridica supracitada, bem como toda a documentacao acostada a presente pecavestibular', {'en ...

# %% [markdown]
# *Training*
#
# You can start the training once you completed the second step. Just copy the text and paste into TRAIN_DATA variable in train.py. Run the training…

# %%
import spacy
import random


TRAIN_DATA = train_data2


def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    # add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
    return nlp


prdnlp = train_spacy(TRAIN_DATA, 30)

# Save our trained Model
#modelfile = input("Enter your Model Name: ")
prdnlp.to_disk("Poli_IA_SES")
# Out:
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:639: UserWarning: [W033] Training a new parser or NER using a model with no lexeme normalization table. This may degrade the performance of the model to some degree. If this is intentional or the language you're using doesn't have a normalization table, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed. The languages with lexeme normalization tables are currently: da, de, el, en, id, lb, pt, ru, sr, ta, th.
#   **kwargs
# Statring iteration 0
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " mplantacao de card oversor desf br lador (cd )par..." with entities "[(43, 46, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " - oficio no / )temendo pela saude de sua filha, a..." with entities "[(492, 507, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos: o menor, com 13 anos, com baixa estatura e..." with entities "[(230, 247, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " e) caso o requerido nao cumpra, incontinenti, a o..." with entities "[(403, 413, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "1.preliminar de prova pre-constituida rejeitada.2 ..." with entities "[(137, 154, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "da de urgencia antecipada6.1 requisitos no caso em..." with entities "[(1610, 1622, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " destarte,eincontesteaobrigacaoatribuidaaomunicipi..." with entities "[(196, 211, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " -se que o jatemodal(temozolamida)realizou tratame..." with entities "[(13, 20, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " o vimizim(r) e indicado como terapia de reposicao..." with entities "[(3, 10, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "10- ), com metastases pulmonares,sintomaticas das ..." with entities "[(216, 235, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " tj-sp - apelacao apl sp (tj-sp) data de publicaca..." with entities "[(326, 336, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "(...)"( -agr /rs, , ministro , dj )".assim, todos ..." with entities "[(159, 180, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " , residente na , 89, bairro de pedra redonda, nes..." with entities "[(172, 182, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "pelo exposto, estando presentes a comprovacao da n..." with entities "[(389, 406, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " medicamento rituximab.portador de publico" with entities "[(13, 23, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "e ainda, conforme tabela da anvisa em anexo, cada ..." with entities "[(60, 69, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "do direito a saude - postulado constitucional os f..." with entities "[(776, 783, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " caso o referido farmaco nao seja fornecido em cur..." with entities "[(643, 663, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos o autor, atualmente com 81 anos de idade, e..." with entities "[(293, 311, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "deproblemasalergicos;queacriancatemalergiaaprotein..." with entities "[(175, 182, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "os relatorios medicos em anexo, subscritos pelo pr..." with entities "[(262, 271, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "paciente de severa incontinencia urinaria, adquiri..." with entities "[(57, 71, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "2/17 demandante, o medico assistente indicou o uso..." with entities "[(75, 86, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos a autora, atualmente com 55 anos de idade, ..." with entities "[(241, 252, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ministra eliana calmon, ,julgado em , ) 2/17 segun..." with entities "[(397, 408, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " , oqual encaminhou a autora para realizar cirurgi..." with entities "[(52, 64, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " da antec pacao de tutela considerando-se que o re..." with entities "[(103, 114, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "(reenec / , dasilva, quarta camara civel, julgado ..." with entities "[(222, 232, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "percebe-se, por meio de uma simplespesquisa na int..." with entities "[(121, 133, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " vi - do pedido diante do exposto, requer o minist..." with entities "[(924, 930, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " neste contexto, a bula do medicamento bevacizumab..." with entities "[(39, 51, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos o autor, com apenas tres meses de idade, po..." with entities "[(253, 273, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "disponivelem capturado em .https://www.ativosaude...." with entities "[(60, 72, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ocorre que o medicamento vidaza(r) ( perm sc ),ape..." with entities "[(25, 31, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "fonte: http://www.ultrafarma.com.br/produto/detalh..." with entities "[(55, 64, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "em virtude de seu quadro clinico, deve fazer uso d..." with entities "[(155, 175, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a certificacao digital pertence a: neusa lundgren ..." with entities "[(340, 351, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " "o homem pode criar o melhor sistema de justica, ..." with entities "[(170, 180, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "necessita ser submetida com urgencia ao uso ao tra..." with entities "[(168, 180, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " desprovido.(tj-sp - ai: - , : , :18/02/ , 9a cama..." with entities "[(312, 321, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " da parte demandada para comparecer a audiencia pa..." with entities "[(111, 129, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " isso, requer o , com fulcro no art.300do , arts. ..." with entities "[(203, 220, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "e -membro , para este, medicamento essencial , que..." with entities "[(611, 638, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "[4]acontece que, em verdade, ha priorizacao de gas..." with entities "[(435, 444, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "para tratamento da enfermidade acima descrita foi ..." with entities "[(162, 171, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "assinado eletronicamente por: raissa de oliveira ..." with entities "[(686, 707, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " conforme se infere do receituario medico, bem com..." with entities "[(247, 256, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "para tratamento da enfermidade acima descrita foi ..." with entities "[(163, 172, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " iv - pedi diante do exposto, pede inicialmente a ..." with entities "[(213, 223, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " : a menor, com baixa estatura extrema, e acompanh..." with entities "[(253, 270, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "portadoradeencefalopatia pediasure 400m , ou nutre..." with entities "[(61, 68, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "tais condicoes encontram-se presentes no caso conc..." with entities "[(433, 449, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " /83, e posteriormente modificacoes, requererem os..." with entities "[(669, 679, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "1 1 : https://www.araujo.com.br/forteo-colter-pen-..." with entities "[(32, 38, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "assim, a parte autora pleiteia medida de urgencia,..." with entities "[(185, 206, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "[5]o primeiro requisito esta substanciado na concl..." with entities "[(530, 548, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " pedi : diante de todo o exposto, a :requer a) a c..." with entities "[(549, 561, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assim, a parte autora pleiteia medida de urgencia..." with entities "[(188, 209, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "do o exposto, a :requera) os beneficios da gratuid..." with entities "[(434, 449, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "no que concerne ao , o laudo medico, declarando a ..." with entities "[(162, 173, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " por seu genitor , em desfavor da uniao, objetivan..." with entities "[(83, 90, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " tendo em mira a intolerancia a lactose, a autora ..." with entities "[(99, 106, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "6) pedi com base dos fatos e argumentos de direito..." with entities "[(217, 226, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " medica.medicamento avastin.preservacao do direito..." with entities "[(20, 27, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "sendo assim necessita do medicamento transcrito pe..." with entities "[(89, 105, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "vislumbra-se que o direito da parte autora esta am..." with entities "[(299, 320, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " b) a concessao, da tutela de urgencia, a fim de d..." with entities "[(150, 162, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a certificacao digital pertence a: carmem de melo ..." with entities "[(405, 416, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " pessoasdestituidasderecursosfinanceiros-direitoav..." with entities "[(961, 971, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " , .(355:14)os medicamentos atualmente registrados..." with entities "[(191, 203, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos a autora, atualmente com 60 anos de idade, ..." with entities "[(199, 211, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos de 02 (dois) anos de idade foi diagnosticad..." with entities "[(109, 122, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " dos fatos a autora, atualmente com , apresenta di..." with entities "[(260, 272, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "por esse motivo, foi solicitado o farmaco poranagr..." with entities "[(45, 55, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ja faz uso de cystagoncomprimido 150mg e 50mg, ten..." with entities "[(14, 22, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "conforme medica em anexo, sendo imprescindivel par..." with entities "[(98, 109, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "da competenc a da perm sc esclarecer que compete a..." with entities "[(409, 429, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "7- a condenacao da demandada ao pagamento de uma i..." with entities "[(330, 341, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "o tratamento especifico com enzima combinante esta..." with entities "[(262, 269, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos a parte autora possui cefaleia refrataria a..." with entities "[(101, 127, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "i - de instrumento interposto contra decisao que, ..." with entities "[(192, 199, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " ratificam ser dever do estado preservar e garanti..." with entities "[(299, 309, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "leila, , que esta medicacao e disponivel na secret..." with entities "[(358, 376, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos o demandante, atualmente com 59 anos de ida..." with entities "[(327, 338, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "assim, a parte autora pleiteia medida de urgencia,..." with entities "[(185, 204, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "priscilaandrade , que ainda acrescenta pedido de a..." with entities "[(198, 205, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assistida esta gestante de 36 semanas e segue int..." with entities "[(378, 388, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "apos administracao oral de 14c-enzalutamida radiom..." with entities "[(31, 48, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "fonte: https://www.pharmak.com.br/rapamune-1mg-cai..." with entities "[(278, 286, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "e -membro , para este, medicamento essencial , que..." with entities "[(411, 422, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ante todo o exposto, deve ser concedida liminar a ..." with entities "[(215, 224, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " ocorre que desde 09 de outubro de , autor nao tem..." with entities "[(75, 91, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " a multa independe de requerimento da parte e pode..." with entities "[(634, 649, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " a multa independe de requerimento da parte e pode..." with entities "[(522, 539, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " do - direito a saude - da - garantia constitucion..." with entities "[(66, 76, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assinado eletronicamente por: michael marques car..." with entities "[(257, 267, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "b) a concessao, da tutela antecipatoria, com a max..." with entities "[(166, 174, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " a requerente e portadora de estagio clinico a, c ..." with entities "[(226, 237, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "dos requerimentos ante todo o exposto, requer a pa..." with entities "[(468, 479, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a parte autora apelou alegando ser portador de doe..." with entities "[(296, 303, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " dos de todo o exposto, respeitosamente requer: a)..." with entities "[(256, 266, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " (crm-pe ), a saber: 1) 60 mg, uso continuo 01 via..." with entities "[(186, 204, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "https://www.farmadelivery.com.br/forteo-colter-pen..." with entities "[(33, 39, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " nao se deve esquecer de vista que o paciente e fi..." with entities "[(418, 428, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " numero de doentes afetados pela hemoglobinuria pa..." with entities "[(318, 329, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " isto porque o rituximab e especificamente utiliza..." with entities "[(15, 25, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assinado eletronicamente por: dias ribeiro de lav..." with entities "[(1774, 1796, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " -se que o medico informa que nao ha genericos ou ..." with entities "[(107, 119, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " a inercia quanto ao fornecimento para o requerent..." with entities "[(135, 144, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " pedi diante do exposto, o demandante vem requerer..." with entities "[(573, 584, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "nao resta alternativa aesse a jurisdicao, no intui..." with entities "[(217, 229, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "alem disso, cerca de um terco dospacientes tratado..." with entities "[(121, 133, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "consta do laudo pericial, elaborado por medico leg..." with entities "[(327, 330, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "portanto, a autora veio socorrer-se atraves da via..." with entities "[(184, 204, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "tribunal de de pernambuco - processo judicial elet..." with entities "[(892, 903, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "entrementes, a solicitacao fora negada sob o argum..." with entities "[(376, 393, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# ...
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assinado eletronicamente por: erico douglas passo..." with entities "[(309, 316, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "sem duvida que com o passar dos dias seucopia de t..." with entities "[(393, 428, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "por unanimidade, negou-se provimento ao recurso de..." with entities "[(440, 448, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a certificacao digital pertence a: joao paulo gued..." with entities "[(365, 377, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " fatos a parte autora possui fatores de risco para..." with entities "[(98, 144, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " ) - pedi diante de todo o exposto, respeitosament..." with entities "[(825, 836, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "juizo, na medida em que o estado de pernambuco, na..." with entities "[(280, 293, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " ,porsetratardebemirrefutavelvalioso,qualsejaodire..." with entities "[(165, 180, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "10; 40 pacotes de gaze; 03 caixas de luvas para pr..." with entities "[(762, 767, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "1.trata-se de apelacoes civeis de ilegitimidade da..." with entities "[(339, 345, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "no caso em tela, por se tratar de bem irrefutavel ..." with entities "[(1406, 1425, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " - pedi pelo exposto, :a) , desde ja, da "gratuida..." with entities "[(503, 512, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " 15/16 do exposto, o demandante vem requerer:a) a ..." with entities "[(593, 605, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "necessita ser submetida com urgencia ao uso do med..." with entities "[(58, 69, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " pedi diante do exposto, o demandante vem requerer..." with entities "[(586, 597, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "e certo que esses entes que integramo sus podem e ..." with entities "[(883, 895, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "o autor, ora agravado, e portador de cancer (adeno..." with entities "[(140, 152, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a certificacao digital pertence a: , https://pje.t..." with entities "[(530, 541, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " esta mais do que claro aqui que o autor recorre a..." with entities "[(490, 517, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "evidencia-se a urgencia para concessao do tratamen..." with entities "[(495, 506, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "sendo assim, o autor necessita mudar o seu tratame..." with entities "[(90, 106, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " excelentissimosenhorjuizdedireitodacomarcadecabro..." with entities "[(859, 870, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "nao se pode olvidar, por todas as razoes supra, a ..." with entities "[(358, 366, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " trata-se de agravo de instrumento interposto cont..." with entities "[(310, 321, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "obrigacao de .infliximabe 100mg" with entities "[(14, 25, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "raphaelsantos bruno (crm-pe ), (crm-pe ) e -pe ) e..." with entities "[(123, 133, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "assinado eletronicamente por: - 05/10/ 10:33:18 ht..." with entities "[(319, 326, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assinado eletronicamente por: - 25/09/ 15:48:29 h..." with entities "[(316, 329, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " conhecido para nao -se de recurso especial interp..." with entities "[(485, 498, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "interessante, ressaltar que a ses, nao se dignou s..." with entities "[(116, 153, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ate por isso e tao crucial seguir otratamento e as..." with entities "[(300, 323, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "i - fatosa autora e portadora historico de diabete..." with entities "[(222, 233, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "afirma que o estado clinico doagravado tem perfil ..." with entities "[(159, 170, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " conforme se infere do receituario medico, bem com..." with entities "[(293, 306, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "a certificacao digital pertence a: emanoel nasaren..." with entities "[(263, 272, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " assinado eletronicamente por: de moraes roldao - ..." with entities "[(1396, 1405, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " 5-do desinteresse inicial na autocomposicao diant..." with entities "[(767, 777, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text " seja julgado, ao final, integralmente procedente ..." with entities "[(196, 208, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# /usr/local/lib/python3.6/dist-packages/spacy/language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "em virtude de seu quadro clinico, deve fazer uso d..." with entities "[(154, 174, 'Item')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   gold = GoldParse(doc, **gold)

# %%
import spacy
nlp = spacy.load('Poli_IA_SES')

# %%
from os import chdir, getcwd, listdir
path= r'/content/drive/My Drive/ner_itens_medicamentos/TesteFinal/'
listaNumTF=[]
listaDeArqEntTF=[]
listaDeArqTextTF=[]
chdir(path)
print(getcwd()) #print caminho 

for c in listdir(): #listdir são os arquivos dentro da pasta  
 if "text" in str(c) and "entities" not in str(c):
   listaNumTF.append(int(c[4:c.index(".")])) #add numero dos textos 



for n in listaNumTF: #listdir são os arquivos dentro 
  listaDeArqTextTF.append("text"+str(n)+".txt") #add numero dos textos 
  listaDeArqEntTF.append("text"+str(n)+"_entities.txt")

#listadetestes="198 295 382 608 187 80 127 62 506 529 59 315 628 35 274 222 452 58 613 629 324 73 345 42 113 616 180 61 446 416 651 165 172 614 82 70 95 348 288 347 455 605 137 208 114 431 39 91 534 28 120 43 122 332 108 538 405 309 305 521 450 286 87 357 518 605 3 325 364 250 113 639 429 70 488 514 456 209 38 595 49 157 126 335 522 324 102 53 97 333 534 589 219 65 475 173 179 264 625 378 494 127 629 645 345 341 567 147 338 317 637 310 157 396 565 400 246 407 577 378 528 640 325 217 581 538 159 550 191 14"
#listadetestes=listadeteste.replace(" ",",")


print(len(listaNumTF))

# %%
for x in range(5):
#for x in range(len(listaNum)):
  print("o texto de numero %s é o %s e suas entidades estão em %s" %(listaNumTF[x],listaDeArqTextTF[x],listaDeArqEntTF[x]))

# %%
data=[]
for t in range(len(listaNumTF)):
  #if t>650:
   # break
  textoTxtTF=(open(path+listaDeArqTextTF[t],"r").read())
 #textoTxt.append(()
  textoEntCompTF=open(path+listaDeArqEntTF[t],"r")
  for x in textoEntCompTF:
    y=x[:x.index("\n")]
    z=y.split(",")
    nEntPars.append((int(z[0]),int(z[1]),"texto"))
  data.append((textoTxtTF,{'entities':list(nEntPars)}))
  nEntPars.clear()
  
#print(data)
print(data[0][0])

# %%
#Test your text
#test_text = input("Enter your testing text: ")
peticao = prdnlp(data[0][0])
for ent in peticao.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

# %%
#peticao = nlp()

# %%
from spacy import displacy
displacy.render(peticao, style = 'ent', jupyter = True) #imprime o texto com um render nas palavras rotuladas

# %%
peticao.ents #verificando as entidades (palavras)

# %%
for ent in peticao.ents: #imprime as palavras junto com seus rotulos
  print(ent.text, ent.label_)

# %%
[token for token in peticao] #imprime token por token (item do texto)

# %%
[(token.orth_, token.pos_) for token in peticao] #Analise de classes gramaticais

# %% [markdown]
# Agora
# Já está no github
#
# Próximos passos
# Refinar o código
# Estudar formas mais eficientes de executar o código
#
# Pensando alto
# Implementar um sistema web front-end básico
